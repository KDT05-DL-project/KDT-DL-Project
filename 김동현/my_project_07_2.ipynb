# %%
# 모듈로딩
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn           
import torch.nn.functional as F 
import torch.optim as optim
import torchmetrics.functional as metrics
import torchmetrics.functional.classification as metrics
import sklearn.metrics as skm

from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

# %%
featureDF = pd.read_pickle('./DATA/feature2.pkl')
targetDF = pd.read_pickle('./DATA/target2.pkl')

# %%
def plot_fish(image_data):
    image = image_data.reshape(45, 59)
    plt.imshow(image, cmap = 'binary')
    plt.axis('off')

some_fish = featureDF.iloc[0].values
plot_fish(some_fish)
plt.show()

# %%
some_fish.shape
# Out:
# (2655,)

# %%
# 학습을 위해 타겟 데이터를 시리즈로 변경
targetSR = targetDF.squeeze()
type(targetSR)
# Out:
# pandas.core.series.Series

# %%
# shape 확인
print(f'featureDF => {featureDF.shape}, targetSR => {targetSR.shape}')
# Out:
# featureDF => (9000, 2655), targetSR => (9000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(featureDF, targetSR, test_size = 90, random_state = 42, stratify = targetSR)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 810, random_state = 42, stratify = y_train)

# %%
# 데이터의 Tensor 변환
class DLDataset(Dataset):

    # 초기화 콜백 함수(callback function)
    def __init__(self, x_data, y_data):
        super().__init__()
        # x, y 데이터 => ndarray
        x_data = x_data.values if isinstance(x_data, pd.DataFrame) else x_data
        y_data = y_data.values if isinstance(y_data, pd.Series) else y_data

        # ndarray => tensor
        self.feature = torch.FloatTensor(x_data)
        self.target = torch.LongTensor(y_data)  # 타겟을 원핫인코딩하면 FloatTensor 사용
        print('[target & target shape]', self.target.shape, self.target.ndim)
    
    # 데이터셋의 개수 체크 콜백 함수(callback function)
    def __len__(self):
        return self.target.shape[0]
    
    # 특정 인덱스 데이터 + 라벨 반환 콜백 함수(callback function)
    def __getitem__(self, index):
        return self.feature[index], self.target[index]

# %%
trainDS = DLDataset(X_train, y_train)
validDS = DLDataset(X_val, y_val)
testDS = DLDataset(X_test, y_test)
# Out:
# [target & target shape] torch.Size([8100]) 1
# [target & target shape] torch.Size([810]) 1
# [target & target shape] torch.Size([90]) 1

# %%
validDS.feature.shape
# Out:
# torch.Size([810, 2655])

# %%
batch_size = 50
trainDL = DataLoader(trainDS, batch_size = batch_size, shuffle = True, drop_last = True)
validDL = DataLoader(validDS, batch_size = batch_size, shuffle = True, drop_last = True)
testDL = DataLoader(testDS, batch_size = batch_size, shuffle = True, drop_last = True)

# %%
len(trainDL), len(validDL), len(testDL)
# Out:
# (162, 16, 1)

# %%
# Epoch당 반복 단위
print(f'batch_size = {batch_size}')
print(f'trainDL => {len(trainDL)}개, validDL => {len(validDL)}개, testDL => {len(testDL)}개')
# Out:
# batch_size = 50
# trainDL => 162개, validDL => 16개, testDL => 1개

# %% [markdown]
# ### Dropout 적용, Weight Initialization 미적용 <hr>

# %%
class FishModel(nn.Module):
    
    # 모델 구성 요소 초기화 
    def __init__(self, in_dim, out_dim, nodes_list = []):
        super().__init__()
        nodes_list.insert(0, in_dim)
        nodes_list.append(out_dim)
        layer_num = len(nodes_list) - 1
        layers = []
        for i in range(layer_num):
            if i <= layer_num - 2:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))
                layers.append(nn.BatchNorm1d(num_features = nodes_list[i+1]))
                layers.append(nn.ReLU())
                layers.append(nn.Dropout())    
            else:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))

        self.layers = nn.ModuleList(layers)
        
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
CLASSES = 9

# %%
# 모델 인스턴스
IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
print(f'IN : {IN_DIM}, OUT : {OUT_DIM}')
# Out:
# IN : 2655, OUT : 9

# %%
### ===> 학습 진행함수 
def training(epoch):
    # 학습모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화 
    model.train()
    
    # 배치크기 만큼 학습 진행 및 저장
    train_report=[[], [], []]
    for idx, (feature, target)  in enumerate(trainDL):
        # 배치크기만큼의 학습 데이터 준비
        feature, target = feature.to(DEVICE), target.to(DEVICE)
        
        # 학습
        pre_traget = model(feature)
        
        # 손실계산
        loss = LOSS_FN(pre_traget, target)
        train_report[0].append(loss)
        
        # 성능 평가
        acc = metrics.accuracy(pre_traget, target, task='multiclass', num_classes = CLASSES)
        train_report[1].append(acc)
        
        f1 = metrics.f1_score(pre_traget, target, task='multiclass', num_classes = CLASSES)
        train_report[2].append(f1)
        
        # W,b업데이트
        OPTIMIZER.zero_grad()
        loss.backward()
        OPTIMIZER.step()
        
        if not idx%50: print('.', end='')
    
    # 에포크 단위로 학습 모델 저장
    # torch.save(model, './model/my_model.pt')
    
    # 에포크 단위 학습 진행 메시지 출력
    loss_score = (sum(train_report[0])/batch_size).item()
    acc_score = (sum(train_report[1])/batch_size).item()
    f1_score = (sum(train_report[2])/batch_size).item() 
    print(f'\n[{epoch+1} Train ] Loss ==> {loss_score:.3f} Acc ==> {acc_score:.3f} F1 ==> {f1_score:.3f}')
    
    return loss_score, acc_score, f1_score

# %%
### ===> 검증 및 테스트 진행함수 
def testing(epoch, kind='valid'):
    # 학습모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화 
    model.eval()
        
    with torch.no_grad():
        # 배치크기 만큼 학습 진행 및 저장
        test_report=[[], [], []]
        for idx, (feature, target) in enumerate(trainDL):
            # 배치크기만큼의 학습 데이터 준비
            feature, target = feature.to(DEVICE), target.to(DEVICE)

            # 학습
            pre_traget = model(feature)

            # 손실계산
            loss = LOSS_FN(pre_traget, target)
            test_report[0].append(loss)
            
            # 성능 평가 
            acc = metrics.accuracy(pre_traget, target, task='multiclass', num_classes = CLASSES)
            test_report[1].append(acc)
            
            f1 = metrics.f1_score(pre_traget, target, task='multiclass', num_classes = CLASSES)
            test_report[2].append(f1)
            
            #if not idx%50: print('.', end='')

    testing_type = 'Valid' if kind == 'valid' else 'Test'
        
    # 에포크 단위 학습 진행 메시지 출력
    loss_score = (sum(test_report[0])/batch_size).item()
    acc_score = (sum(test_report[1])/batch_size).item()
    f1_score = (sum(test_report[2])/batch_size).item() 
    print(f'[{epoch+1} {testing_type} ] Loss ==> {loss_score:.3f} Acc ==> {acc_score:.3f} F1 ==> {f1_score:.3f}\n')
    
    return loss_score, acc_score, f1_score

# %% [markdown]
# #### hidden layer 7개

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 증가

# %%
layer_list1 = [[2**(j+4) for j in range(i+1)] for i in range(7)]
layer_list1
# Out:
# [[16],
#  [16, 32],
#  [16, 32, 64],
#  [16, 32, 64, 128],
#  [16, 32, 64, 128, 256],
#  [16, 32, 64, 128, 256, 512],
#  [16, 32, 64, 128, 256, 512, 1024]]

# %%
layer_list1 = [[2**(j+4) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list1:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)
    

    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model2/my_model1.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# [Epoch 1/30] .
# ...
# [1 Train ] Loss ==> 6.188 Acc ==> 0.902 F1 ==> 0.902
# [1 Valid ] Loss ==> 5.320 Acc ==> 1.552 F1 ==> 1.552
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.398 Acc ==> 1.167 F1 ==> 1.167
# [2 Valid ] Loss ==> 4.663 Acc ==> 1.719 F1 ==> 1.719
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.021 Acc ==> 1.262 F1 ==> 1.262
# [3 Valid ] Loss ==> 4.236 Acc ==> 1.804 F1 ==> 1.804
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 4.785 Acc ==> 1.339 F1 ==> 1.339
# [4 Valid ] Loss ==> 4.058 Acc ==> 1.897 F1 ==> 1.897
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 4.704 Acc ==> 1.360 F1 ==> 1.360
# [5 Valid ] Loss ==> 3.910 Acc ==> 1.952 F1 ==> 1.952
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 4.603 Acc ==> 1.381 F1 ==> 1.381
# [6 Valid ] Loss ==> 3.770 Acc ==> 1.954 F1 ==> 1.954
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 4.483 Acc ==> 1.438 F1 ==> 1.438
# [7 Valid ] Loss ==> 3.649 Acc ==> 1.985 F1 ==> 1.985
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 4.438 Acc ==> 1.462 F1 ==> 1.462
# [8 Valid ] Loss ==> 3.570 Acc ==> 2.019 F1 ==> 2.019
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 4.332 Acc ==> 1.498 F1 ==> 1.498
# [9 Valid ] Loss ==> 3.502 Acc ==> 2.100 F1 ==> 2.100
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 4.290 Acc ==> 1.519 F1 ==> 1.519
# [10 Valid ] Loss ==> 3.373 Acc ==> 2.153 F1 ==> 2.153
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 4.272 Acc ==> 1.502 F1 ==> 1.502
# [11 Valid ] Loss ==> 3.288 Acc ==> 2.155 F1 ==> 2.155
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 4.242 Acc ==> 1.521 F1 ==> 1.521
# [12 Valid ] Loss ==> 3.283 Acc ==> 2.182 F1 ==> 2.182
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 4.126 Acc ==> 1.562 F1 ==> 1.562
# [13 Valid ] Loss ==> 3.184 Acc ==> 2.224 F1 ==> 2.224
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 4.130 Acc ==> 1.576 F1 ==> 1.576
# [14 Valid ] Loss ==> 3.100 Acc ==> 2.248 F1 ==> 2.248
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 4.032 Acc ==> 1.590 F1 ==> 1.590
# [15 Valid ] Loss ==> 3.035 Acc ==> 2.318 F1 ==> 2.318
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 4.003 Acc ==> 1.610 F1 ==> 1.610
# [16 Valid ] Loss ==> 3.070 Acc ==> 2.298 F1 ==> 2.298
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 3.978 Acc ==> 1.638 F1 ==> 1.638
# [17 Valid ] Loss ==> 2.955 Acc ==> 2.316 F1 ==> 2.316
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 3.990 Acc ==> 1.646 F1 ==> 1.646
# [18 Valid ] Loss ==> 2.987 Acc ==> 2.320 F1 ==> 2.320
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 3.998 Acc ==> 1.622 F1 ==> 1.622
# [19 Valid ] Loss ==> 2.848 Acc ==> 2.316 F1 ==> 2.316
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 3.906 Acc ==> 1.648 F1 ==> 1.648
# [20 Valid ] Loss ==> 2.763 Acc ==> 2.384 F1 ==> 2.384
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 3.846 Acc ==> 1.671 F1 ==> 1.671
# [21 Valid ] Loss ==> 2.849 Acc ==> 2.385 F1 ==> 2.385
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 3.820 Acc ==> 1.687 F1 ==> 1.687
# [22 Valid ] Loss ==> 2.709 Acc ==> 2.351 F1 ==> 2.351
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 3.790 Acc ==> 1.692 F1 ==> 1.692
# [23 Valid ] Loss ==> 2.702 Acc ==> 2.416 F1 ==> 2.416
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 3.758 Acc ==> 1.709 F1 ==> 1.709
# [24 Valid ] Loss ==> 2.641 Acc ==> 2.463 F1 ==> 2.463
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 3.753 Acc ==> 1.702 F1 ==> 1.702
# [25 Valid ] Loss ==> 2.583 Acc ==> 2.448 F1 ==> 2.448
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 3.710 Acc ==> 1.727 F1 ==> 1.727
# [26 Valid ] Loss ==> 2.535 Acc ==> 2.486 F1 ==> 2.486
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 3.701 Acc ==> 1.733 F1 ==> 1.733
# [27 Valid ] Loss ==> 2.495 Acc ==> 2.468 F1 ==> 2.468
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 3.685 Acc ==> 1.739 F1 ==> 1.739
# [28 Valid ] Loss ==> 2.481 Acc ==> 2.495 F1 ==> 2.495
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 3.667 Acc ==> 1.750 F1 ==> 1.750
# [29 Valid ] Loss ==> 2.518 Acc ==> 2.480 F1 ==> 2.480
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 3.592 Acc ==> 1.782 F1 ==> 1.782
# [30 Valid ] Loss ==> 2.398 Acc ==> 2.574 F1 ==> 2.574
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.591 Acc ==> 0.730 F1 ==> 0.730
# [1 Valid ] Loss ==> 5.634 Acc ==> 1.244 F1 ==> 1.244
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.727 Acc ==> 0.947 F1 ==> 0.947
# [2 Valid ] Loss ==> 4.900 Acc ==> 1.493 F1 ==> 1.493
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.398 Acc ==> 1.064 F1 ==> 1.064
# [3 Valid ] Loss ==> 4.634 Acc ==> 1.570 F1 ==> 1.570
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 5.155 Acc ==> 1.127 F1 ==> 1.127
# [4 Valid ] Loss ==> 4.470 Acc ==> 1.556 F1 ==> 1.556
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 5.044 Acc ==> 1.170 F1 ==> 1.170
# [5 Valid ] Loss ==> 4.292 Acc ==> 1.604 F1 ==> 1.604
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 4.976 Acc ==> 1.167 F1 ==> 1.167
# [6 Valid ] Loss ==> 4.229 Acc ==> 1.694 F1 ==> 1.694
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 4.870 Acc ==> 1.226 F1 ==> 1.226
# [7 Valid ] Loss ==> 4.190 Acc ==> 1.717 F1 ==> 1.717
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 4.858 Acc ==> 1.232 F1 ==> 1.232
# [8 Valid ] Loss ==> 4.083 Acc ==> 1.705 F1 ==> 1.705
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 4.822 Acc ==> 1.242 F1 ==> 1.242
# [9 Valid ] Loss ==> 4.057 Acc ==> 1.783 F1 ==> 1.783
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 4.755 Acc ==> 1.289 F1 ==> 1.289
# [10 Valid ] Loss ==> 4.001 Acc ==> 1.741 F1 ==> 1.741
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 4.745 Acc ==> 1.291 F1 ==> 1.291
# [11 Valid ] Loss ==> 3.962 Acc ==> 1.796 F1 ==> 1.796
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 4.664 Acc ==> 1.321 F1 ==> 1.321
# [12 Valid ] Loss ==> 3.899 Acc ==> 1.868 F1 ==> 1.868
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 4.653 Acc ==> 1.308 F1 ==> 1.308
# [13 Valid ] Loss ==> 3.861 Acc ==> 1.833 F1 ==> 1.833
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 4.640 Acc ==> 1.318 F1 ==> 1.318
# [14 Valid ] Loss ==> 3.826 Acc ==> 1.848 F1 ==> 1.848
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 4.581 Acc ==> 1.362 F1 ==> 1.362
# [15 Valid ] Loss ==> 3.804 Acc ==> 1.898 F1 ==> 1.898
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 4.585 Acc ==> 1.359 F1 ==> 1.359
# [16 Valid ] Loss ==> 3.761 Acc ==> 1.904 F1 ==> 1.904
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 4.548 Acc ==> 1.382 F1 ==> 1.382
# [17 Valid ] Loss ==> 3.740 Acc ==> 1.942 F1 ==> 1.942
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 4.503 Acc ==> 1.404 F1 ==> 1.404
# [18 Valid ] Loss ==> 3.678 Acc ==> 1.940 F1 ==> 1.940
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 4.493 Acc ==> 1.380 F1 ==> 1.380
# [19 Valid ] Loss ==> 3.614 Acc ==> 2.022 F1 ==> 2.022
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 4.521 Acc ==> 1.400 F1 ==> 1.400
# [20 Valid ] Loss ==> 3.672 Acc ==> 1.909 F1 ==> 1.909
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 4.464 Acc ==> 1.404 F1 ==> 1.404
# [21 Valid ] Loss ==> 3.587 Acc ==> 2.049 F1 ==> 2.049
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 4.460 Acc ==> 1.430 F1 ==> 1.430
# [22 Valid ] Loss ==> 3.557 Acc ==> 2.020 F1 ==> 2.020
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 4.448 Acc ==> 1.408 F1 ==> 1.408
# [23 Valid ] Loss ==> 3.571 Acc ==> 1.976 F1 ==> 1.976
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 4.377 Acc ==> 1.456 F1 ==> 1.456
# [24 Valid ] Loss ==> 3.531 Acc ==> 2.020 F1 ==> 2.020
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 4.394 Acc ==> 1.442 F1 ==> 1.442
# [25 Valid ] Loss ==> 3.465 Acc ==> 2.064 F1 ==> 2.064
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 4.374 Acc ==> 1.442 F1 ==> 1.442
# [26 Valid ] Loss ==> 3.455 Acc ==> 2.072 F1 ==> 2.072
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 4.386 Acc ==> 1.423 F1 ==> 1.423
# [27 Valid ] Loss ==> 3.490 Acc ==> 2.060 F1 ==> 2.060
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 4.384 Acc ==> 1.437 F1 ==> 1.437
# [28 Valid ] Loss ==> 3.437 Acc ==> 2.022 F1 ==> 2.022
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 4.339 Acc ==> 1.443 F1 ==> 1.443
# [29 Valid ] Loss ==> 3.472 Acc ==> 2.041 F1 ==> 2.041
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 4.328 Acc ==> 1.491 F1 ==> 1.491
# [30 Valid ] Loss ==> 3.407 Acc ==> 2.054 F1 ==> 2.054
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.873 Acc ==> 0.549 F1 ==> 0.549
# [1 Valid ] Loss ==> 6.036 Acc ==> 0.827 F1 ==> 0.827
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.995 Acc ==> 0.770 F1 ==> 0.770
# [2 Valid ] Loss ==> 5.501 Acc ==> 0.968 F1 ==> 0.968
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.617 Acc ==> 0.854 F1 ==> 0.854
# [3 Valid ] Loss ==> 5.181 Acc ==> 1.138 F1 ==> 1.138
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 5.437 Acc ==> 0.910 F1 ==> 0.910
# [4 Valid ] Loss ==> 4.998 Acc ==> 1.201 F1 ==> 1.201
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 5.280 Acc ==> 0.978 F1 ==> 0.978
# [5 Valid ] Loss ==> 4.796 Acc ==> 1.278 F1 ==> 1.278
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 5.190 Acc ==> 1.022 F1 ==> 1.022
# [6 Valid ] Loss ==> 4.639 Acc ==> 1.361 F1 ==> 1.361
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 5.103 Acc ==> 1.067 F1 ==> 1.067
# [7 Valid ] Loss ==> 4.660 Acc ==> 1.308 F1 ==> 1.308
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 5.050 Acc ==> 1.077 F1 ==> 1.077
# [8 Valid ] Loss ==> 4.461 Acc ==> 1.309 F1 ==> 1.309
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 5.003 Acc ==> 1.099 F1 ==> 1.099
# [9 Valid ] Loss ==> 4.384 Acc ==> 1.514 F1 ==> 1.514
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 5.004 Acc ==> 1.117 F1 ==> 1.117
# [10 Valid ] Loss ==> 4.307 Acc ==> 1.514 F1 ==> 1.514
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 4.906 Acc ==> 1.143 F1 ==> 1.143
# [11 Valid ] Loss ==> 4.321 Acc ==> 1.421 F1 ==> 1.421
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 4.918 Acc ==> 1.135 F1 ==> 1.135
# [12 Valid ] Loss ==> 4.288 Acc ==> 1.468 F1 ==> 1.468
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 4.851 Acc ==> 1.182 F1 ==> 1.182
# [13 Valid ] Loss ==> 4.225 Acc ==> 1.541 F1 ==> 1.541
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 4.797 Acc ==> 1.217 F1 ==> 1.217
# [14 Valid ] Loss ==> 4.113 Acc ==> 1.593 F1 ==> 1.593
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 4.779 Acc ==> 1.211 F1 ==> 1.211
# [15 Valid ] Loss ==> 4.122 Acc ==> 1.564 F1 ==> 1.564
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 4.788 Acc ==> 1.220 F1 ==> 1.220
# [16 Valid ] Loss ==> 4.119 Acc ==> 1.571 F1 ==> 1.571
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 4.747 Acc ==> 1.243 F1 ==> 1.243
# [17 Valid ] Loss ==> 4.020 Acc ==> 1.591 F1 ==> 1.591
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 4.695 Acc ==> 1.249 F1 ==> 1.249
# [18 Valid ] Loss ==> 4.064 Acc ==> 1.561 F1 ==> 1.561
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 4.716 Acc ==> 1.246 F1 ==> 1.246
# [19 Valid ] Loss ==> 3.995 Acc ==> 1.630 F1 ==> 1.630
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 4.688 Acc ==> 1.269 F1 ==> 1.269
# [20 Valid ] Loss ==> 4.026 Acc ==> 1.568 F1 ==> 1.568
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 4.707 Acc ==> 1.230 F1 ==> 1.230
# [21 Valid ] Loss ==> 3.951 Acc ==> 1.621 F1 ==> 1.621
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 4.578 Acc ==> 1.328 F1 ==> 1.328
# [22 Valid ] Loss ==> 3.873 Acc ==> 1.692 F1 ==> 1.692
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 4.623 Acc ==> 1.288 F1 ==> 1.288
# [23 Valid ] Loss ==> 3.924 Acc ==> 1.658 F1 ==> 1.658
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 4.598 Acc ==> 1.297 F1 ==> 1.297
# [24 Valid ] Loss ==> 3.933 Acc ==> 1.674 F1 ==> 1.674
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 4.635 Acc ==> 1.304 F1 ==> 1.304
# [25 Valid ] Loss ==> 3.916 Acc ==> 1.690 F1 ==> 1.690
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 4.582 Acc ==> 1.332 F1 ==> 1.332
# [26 Valid ] Loss ==> 3.929 Acc ==> 1.625 F1 ==> 1.625
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 4.580 Acc ==> 1.316 F1 ==> 1.316
# [27 Valid ] Loss ==> 3.866 Acc ==> 1.734 F1 ==> 1.734
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 4.580 Acc ==> 1.305 F1 ==> 1.305
# [28 Valid ] Loss ==> 3.815 Acc ==> 1.732 F1 ==> 1.732
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 4.505 Acc ==> 1.322 F1 ==> 1.322
# [29 Valid ] Loss ==> 3.745 Acc ==> 1.769 F1 ==> 1.769
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 4.529 Acc ==> 1.349 F1 ==> 1.349
# [30 Valid ] Loss ==> 3.853 Acc ==> 1.723 F1 ==> 1.723
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.785 Acc ==> 0.583 F1 ==> 0.583
# [1 Valid ] Loss ==> 6.162 Acc ==> 0.678 F1 ==> 0.678
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.865 Acc ==> 0.771 F1 ==> 0.771
# [2 Valid ] Loss ==> 5.699 Acc ==> 0.911 F1 ==> 0.911
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.531 Acc ==> 0.864 F1 ==> 0.864
# [3 Valid ] Loss ==> 5.422 Acc ==> 1.008 F1 ==> 1.008
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 5.396 Acc ==> 0.955 F1 ==> 0.955
# [4 Valid ] Loss ==> 5.168 Acc ==> 1.034 F1 ==> 1.034
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 5.215 Acc ==> 0.990 F1 ==> 0.990
# [5 Valid ] Loss ==> 4.988 Acc ==> 1.149 F1 ==> 1.149
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 5.177 Acc ==> 1.024 F1 ==> 1.024
# [6 Valid ] Loss ==> 5.071 Acc ==> 1.057 F1 ==> 1.057
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 5.101 Acc ==> 1.003 F1 ==> 1.003
# [7 Valid ] Loss ==> 4.778 Acc ==> 1.185 F1 ==> 1.185
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 5.064 Acc ==> 1.051 F1 ==> 1.051
# [8 Valid ] Loss ==> 4.913 Acc ==> 1.128 F1 ==> 1.128
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 5.042 Acc ==> 1.068 F1 ==> 1.068
# [9 Valid ] Loss ==> 5.007 Acc ==> 1.021 F1 ==> 1.021
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 5.009 Acc ==> 1.098 F1 ==> 1.098
# [10 Valid ] Loss ==> 4.619 Acc ==> 1.332 F1 ==> 1.332
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 4.951 Acc ==> 1.100 F1 ==> 1.100
# [11 Valid ] Loss ==> 4.774 Acc ==> 1.242 F1 ==> 1.242
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 4.951 Acc ==> 1.106 F1 ==> 1.106
# [12 Valid ] Loss ==> 4.703 Acc ==> 1.154 F1 ==> 1.154
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 4.974 Acc ==> 1.092 F1 ==> 1.092
# [13 Valid ] Loss ==> 4.571 Acc ==> 1.358 F1 ==> 1.358
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 4.944 Acc ==> 1.127 F1 ==> 1.127
# [14 Valid ] Loss ==> 4.599 Acc ==> 1.281 F1 ==> 1.281
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 4.876 Acc ==> 1.136 F1 ==> 1.136
# [15 Valid ] Loss ==> 4.548 Acc ==> 1.383 F1 ==> 1.383
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 4.898 Acc ==> 1.124 F1 ==> 1.124
# [16 Valid ] Loss ==> 4.479 Acc ==> 1.406 F1 ==> 1.406
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 4.890 Acc ==> 1.159 F1 ==> 1.159
# [17 Valid ] Loss ==> 4.494 Acc ==> 1.304 F1 ==> 1.304
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 4.813 Acc ==> 1.164 F1 ==> 1.164
# [18 Valid ] Loss ==> 4.447 Acc ==> 1.400 F1 ==> 1.400
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 4.795 Acc ==> 1.156 F1 ==> 1.156
# [19 Valid ] Loss ==> 4.451 Acc ==> 1.451 F1 ==> 1.451
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 4.803 Acc ==> 1.159 F1 ==> 1.159
# [20 Valid ] Loss ==> 4.462 Acc ==> 1.439 F1 ==> 1.439
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 4.809 Acc ==> 1.160 F1 ==> 1.160
# [21 Valid ] Loss ==> 4.528 Acc ==> 1.420 F1 ==> 1.420
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 4.773 Acc ==> 1.208 F1 ==> 1.208
# [22 Valid ] Loss ==> 4.401 Acc ==> 1.452 F1 ==> 1.452
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 4.780 Acc ==> 1.202 F1 ==> 1.202
# [23 Valid ] Loss ==> 4.276 Acc ==> 1.495 F1 ==> 1.495
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 4.750 Acc ==> 1.184 F1 ==> 1.184
# [24 Valid ] Loss ==> 4.273 Acc ==> 1.464 F1 ==> 1.464
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 4.720 Acc ==> 1.212 F1 ==> 1.212
# [25 Valid ] Loss ==> 4.353 Acc ==> 1.412 F1 ==> 1.412
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 4.690 Acc ==> 1.228 F1 ==> 1.228
# [26 Valid ] Loss ==> 4.239 Acc ==> 1.371 F1 ==> 1.371
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 4.793 Acc ==> 1.173 F1 ==> 1.173
# [27 Valid ] Loss ==> 4.336 Acc ==> 1.473 F1 ==> 1.473
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 4.685 Acc ==> 1.228 F1 ==> 1.228
# [28 Valid ] Loss ==> 4.302 Acc ==> 1.548 F1 ==> 1.548
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 4.749 Acc ==> 1.198 F1 ==> 1.198
# [29 Valid ] Loss ==> 4.318 Acc ==> 1.481 F1 ==> 1.481
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 4.638 Acc ==> 1.244 F1 ==> 1.244
# [30 Valid ] Loss ==> 4.165 Acc ==> 1.468 F1 ==> 1.468
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.662 Acc ==> 0.586 F1 ==> 0.586
# [1 Valid ] Loss ==> 6.758 Acc ==> 0.517 F1 ==> 0.517
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.831 Acc ==> 0.754 F1 ==> 0.754
# [2 Valid ] Loss ==> 6.969 Acc ==> 0.450 F1 ==> 0.450
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.632 Acc ==> 0.814 F1 ==> 0.814
# [3 Valid ] Loss ==> 6.766 Acc ==> 0.430 F1 ==> 0.430
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 5.518 Acc ==> 0.836 F1 ==> 0.836
# [4 Valid ] Loss ==> 6.717 Acc ==> 0.456 F1 ==> 0.456
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 5.479 Acc ==> 0.847 F1 ==> 0.847
# [5 Valid ] Loss ==> 6.637 Acc ==> 0.471 F1 ==> 0.471
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 5.397 Acc ==> 0.864 F1 ==> 0.864
# [6 Valid ] Loss ==> 6.719 Acc ==> 0.494 F1 ==> 0.494
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 5.304 Acc ==> 0.894 F1 ==> 0.894
# [7 Valid ] Loss ==> 6.800 Acc ==> 0.490 F1 ==> 0.490
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 5.310 Acc ==> 0.866 F1 ==> 0.866
# [8 Valid ] Loss ==> 6.076 Acc ==> 0.655 F1 ==> 0.655
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 5.255 Acc ==> 0.906 F1 ==> 0.906
# [9 Valid ] Loss ==> 6.277 Acc ==> 0.677 F1 ==> 0.677
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 5.246 Acc ==> 0.914 F1 ==> 0.914
# [10 Valid ] Loss ==> 6.454 Acc ==> 0.589 F1 ==> 0.589
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 5.209 Acc ==> 0.922 F1 ==> 0.922
# [11 Valid ] Loss ==> 6.460 Acc ==> 0.614 F1 ==> 0.614
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 5.160 Acc ==> 0.934 F1 ==> 0.934
# [12 Valid ] Loss ==> 5.899 Acc ==> 0.770 F1 ==> 0.770
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 5.144 Acc ==> 0.928 F1 ==> 0.928
# [13 Valid ] Loss ==> 5.816 Acc ==> 0.780 F1 ==> 0.780
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 5.130 Acc ==> 0.954 F1 ==> 0.954
# [14 Valid ] Loss ==> 6.260 Acc ==> 0.645 F1 ==> 0.645
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 5.136 Acc ==> 0.974 F1 ==> 0.974
# [15 Valid ] Loss ==> 5.612 Acc ==> 0.760 F1 ==> 0.760
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 5.050 Acc ==> 1.005 F1 ==> 1.005
# [16 Valid ] Loss ==> 5.867 Acc ==> 0.731 F1 ==> 0.731
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 5.025 Acc ==> 1.025 F1 ==> 1.025
# [17 Valid ] Loss ==> 5.883 Acc ==> 0.730 F1 ==> 0.730
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 4.997 Acc ==> 1.017 F1 ==> 1.017
# [18 Valid ] Loss ==> 5.877 Acc ==> 0.793 F1 ==> 0.793
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 5.024 Acc ==> 1.024 F1 ==> 1.024
# [19 Valid ] Loss ==> 5.505 Acc ==> 0.855 F1 ==> 0.855
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 4.987 Acc ==> 1.032 F1 ==> 1.032
# [20 Valid ] Loss ==> 5.726 Acc ==> 0.791 F1 ==> 0.791
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 4.963 Acc ==> 1.032 F1 ==> 1.032
# [21 Valid ] Loss ==> 5.694 Acc ==> 0.778 F1 ==> 0.778
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 4.989 Acc ==> 1.022 F1 ==> 1.022
# [22 Valid ] Loss ==> 5.665 Acc ==> 0.930 F1 ==> 0.930
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 4.979 Acc ==> 1.037 F1 ==> 1.037
# [23 Valid ] Loss ==> 5.533 Acc ==> 0.888 F1 ==> 0.888
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 5.006 Acc ==> 1.050 F1 ==> 1.050
# [24 Valid ] Loss ==> 5.385 Acc ==> 0.978 F1 ==> 0.978
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 4.947 Acc ==> 1.051 F1 ==> 1.051
# [25 Valid ] Loss ==> 5.369 Acc ==> 1.005 F1 ==> 1.005
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 4.938 Acc ==> 1.072 F1 ==> 1.072
# [26 Valid ] Loss ==> 5.332 Acc ==> 0.990 F1 ==> 0.990
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 4.914 Acc ==> 1.047 F1 ==> 1.047
# [27 Valid ] Loss ==> 5.401 Acc ==> 0.983 F1 ==> 0.983
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 4.942 Acc ==> 1.062 F1 ==> 1.062
# [28 Valid ] Loss ==> 5.255 Acc ==> 1.094 F1 ==> 1.094
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 4.902 Acc ==> 1.069 F1 ==> 1.069
# [29 Valid ] Loss ==> 5.169 Acc ==> 1.132 F1 ==> 1.132
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 4.885 Acc ==> 1.121 F1 ==> 1.121
# [30 Valid ] Loss ==> 5.271 Acc ==> 1.088 F1 ==> 1.088
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.493 Acc ==> 0.626 F1 ==> 0.626
# [1 Valid ] Loss ==> 8.014 Acc ==> 0.364 F1 ==> 0.364
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.823 Acc ==> 0.730 F1 ==> 0.730
# [2 Valid ] Loss ==> 8.365 Acc ==> 0.368 F1 ==> 0.368
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.638 Acc ==> 0.780 F1 ==> 0.780
# [3 Valid ] Loss ==> 8.599 Acc ==> 0.381 F1 ==> 0.381
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 5.602 Acc ==> 0.790 F1 ==> 0.790
# [4 Valid ] Loss ==> 8.921 Acc ==> 0.362 F1 ==> 0.362
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 5.523 Acc ==> 0.802 F1 ==> 0.802
# [5 Valid ] Loss ==> 8.907 Acc ==> 0.374 F1 ==> 0.374
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 5.459 Acc ==> 0.844 F1 ==> 0.844
# [6 Valid ] Loss ==> 8.821 Acc ==> 0.386 F1 ==> 0.386
#
# Early stopping at epoch 5
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.693 Acc ==> 0.606 F1 ==> 0.606
# [1 Valid ] Loss ==> 9.246 Acc ==> 0.360 F1 ==> 0.360
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.960 Acc ==> 0.726 F1 ==> 0.726
# [2 Valid ] Loss ==> 9.517 Acc ==> 0.360 F1 ==> 0.360
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.751 Acc ==> 0.755 F1 ==> 0.755
# [3 Valid ] Loss ==> 9.807 Acc ==> 0.360 F1 ==> 0.360
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 5.712 Acc ==> 0.801 F1 ==> 0.801
# [4 Valid ] Loss ==> 9.027 Acc ==> 0.360 F1 ==> 0.360
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 5.679 Acc ==> 0.776 F1 ==> 0.776
# [5 Valid ] Loss ==> 8.949 Acc ==> 0.360 F1 ==> 0.360
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 5.565 Acc ==> 0.804 F1 ==> 0.804
# [6 Valid ] Loss ==> 9.365 Acc ==> 0.364 F1 ==> 0.364
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 5.558 Acc ==> 0.803 F1 ==> 0.803
# [7 Valid ] Loss ==> 8.548 Acc ==> 0.364 F1 ==> 0.364
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 5.504 Acc ==> 0.845 F1 ==> 0.845
# [8 Valid ] Loss ==> 8.784 Acc ==> 0.364 F1 ==> 0.364
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 5.471 Acc ==> 0.842 F1 ==> 0.842
# [9 Valid ] Loss ==> 9.174 Acc ==> 0.363 F1 ==> 0.363
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 5.431 Acc ==> 0.854 F1 ==> 0.854
# [10 Valid ] Loss ==> 8.950 Acc ==> 0.364 F1 ==> 0.364
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 5.426 Acc ==> 0.887 F1 ==> 0.887
# [11 Valid ] Loss ==> 8.768 Acc ==> 0.384 F1 ==> 0.384
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 5.400 Acc ==> 0.859 F1 ==> 0.859
# [12 Valid ] Loss ==> 7.967 Acc ==> 0.372 F1 ==> 0.372
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 5.375 Acc ==> 0.843 F1 ==> 0.843
# [13 Valid ] Loss ==> 8.062 Acc ==> 0.389 F1 ==> 0.389
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 5.336 Acc ==> 0.866 F1 ==> 0.866
# [14 Valid ] Loss ==> 7.921 Acc ==> 0.383 F1 ==> 0.383
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 5.329 Acc ==> 0.904 F1 ==> 0.904
# [15 Valid ] Loss ==> 8.147 Acc ==> 0.402 F1 ==> 0.402
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 5.288 Acc ==> 0.907 F1 ==> 0.907
# [16 Valid ] Loss ==> 7.975 Acc ==> 0.376 F1 ==> 0.376
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 5.258 Acc ==> 0.936 F1 ==> 0.936
# [17 Valid ] Loss ==> 7.839 Acc ==> 0.393 F1 ==> 0.393
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 5.256 Acc ==> 0.896 F1 ==> 0.896
# [18 Valid ] Loss ==> 7.781 Acc ==> 0.398 F1 ==> 0.398
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 5.272 Acc ==> 0.922 F1 ==> 0.922
# [19 Valid ] Loss ==> 7.553 Acc ==> 0.432 F1 ==> 0.432
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 5.212 Acc ==> 0.930 F1 ==> 0.930
# [20 Valid ] Loss ==> 7.682 Acc ==> 0.407 F1 ==> 0.407
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 5.204 Acc ==> 0.951 F1 ==> 0.951
# [21 Valid ] Loss ==> 7.216 Acc ==> 0.450 F1 ==> 0.450
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 5.217 Acc ==> 0.937 F1 ==> 0.937
# [22 Valid ] Loss ==> 7.343 Acc ==> 0.439 F1 ==> 0.439
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 5.212 Acc ==> 0.947 F1 ==> 0.947
# [23 Valid ] Loss ==> 7.769 Acc ==> 0.410 F1 ==> 0.410
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 5.216 Acc ==> 0.926 F1 ==> 0.926
# [24 Valid ] Loss ==> 7.190 Acc ==> 0.424 F1 ==> 0.424
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 5.172 Acc ==> 0.939 F1 ==> 0.939
# [25 Valid ] Loss ==> 7.745 Acc ==> 0.407 F1 ==> 0.407
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 5.155 Acc ==> 0.936 F1 ==> 0.936
# [26 Valid ] Loss ==> 7.566 Acc ==> 0.410 F1 ==> 0.410
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 5.138 Acc ==> 0.965 F1 ==> 0.965
# [27 Valid ] Loss ==> 7.532 Acc ==> 0.414 F1 ==> 0.414
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 5.109 Acc ==> 0.965 F1 ==> 0.965
# [28 Valid ] Loss ==> 7.387 Acc ==> 0.437 F1 ==> 0.437
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 5.100 Acc ==> 0.987 F1 ==> 0.987
# [29 Valid ] Loss ==> 6.848 Acc ==> 0.472 F1 ==> 0.472
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 5.143 Acc ==> 0.939 F1 ==> 0.939
# [30 Valid ] Loss ==> 6.886 Acc ==> 0.441 F1 ==> 0.441
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 감소

# %%
layer_list2 = [[2**(10-j) for j in range(i+1)] for i in range(7)]
layer_list2
# Out:
# [[1024],
#  [1024, 512],
#  [1024, 512, 256],
#  [1024, 512, 256, 128],
#  [1024, 512, 256, 128, 64],
#  [1024, 512, 256, 128, 64, 32],
#  [1024, 512, 256, 128, 64, 32, 16]]

# %%
layer_list2 = [[2**(10-j) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list2:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)
    
    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model2/my_model2.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.279 Acc ==> 1.560 F1 ==> 1.560
# [1 Valid ] Loss ==> 3.114 Acc ==> 2.058 F1 ==> 2.058
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.452 Acc ==> 1.891 F1 ==> 1.891
# [2 Valid ] Loss ==> 2.725 Acc ==> 2.204 F1 ==> 2.204
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.106 Acc ==> 2.042 F1 ==> 2.042
# [3 Valid ] Loss ==> 2.414 Acc ==> 2.350 F1 ==> 2.350
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.831 Acc ==> 2.160 F1 ==> 2.160
# [4 Valid ] Loss ==> 2.137 Acc ==> 2.457 F1 ==> 2.457
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.611 Acc ==> 2.244 F1 ==> 2.244
# [5 Valid ] Loss ==> 1.950 Acc ==> 2.560 F1 ==> 2.560
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.387 Acc ==> 2.331 F1 ==> 2.331
# [6 Valid ] Loss ==> 1.687 Acc ==> 2.655 F1 ==> 2.655
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.240 Acc ==> 2.397 F1 ==> 2.397
# [7 Valid ] Loss ==> 1.584 Acc ==> 2.668 F1 ==> 2.668
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.020 Acc ==> 2.488 F1 ==> 2.488
# [8 Valid ] Loss ==> 1.340 Acc ==> 2.818 F1 ==> 2.818
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.939 Acc ==> 2.525 F1 ==> 2.525
# [9 Valid ] Loss ==> 1.140 Acc ==> 2.882 F1 ==> 2.882
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.797 Acc ==> 2.562 F1 ==> 2.562
# [10 Valid ] Loss ==> 1.032 Acc ==> 2.938 F1 ==> 2.938
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.641 Acc ==> 2.630 F1 ==> 2.630
# [11 Valid ] Loss ==> 0.979 Acc ==> 2.969 F1 ==> 2.969
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.491 Acc ==> 2.697 F1 ==> 2.697
# [12 Valid ] Loss ==> 0.845 Acc ==> 3.001 F1 ==> 3.001
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.383 Acc ==> 2.729 F1 ==> 2.729
# [13 Valid ] Loss ==> 0.856 Acc ==> 2.986 F1 ==> 2.986
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.285 Acc ==> 2.782 F1 ==> 2.782
# [14 Valid ] Loss ==> 0.682 Acc ==> 3.044 F1 ==> 3.044
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.241 Acc ==> 2.790 F1 ==> 2.790
# [15 Valid ] Loss ==> 0.657 Acc ==> 3.058 F1 ==> 3.058
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.183 Acc ==> 2.800 F1 ==> 2.800
# [16 Valid ] Loss ==> 0.594 Acc ==> 3.064 F1 ==> 3.064
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.136 Acc ==> 2.813 F1 ==> 2.813
# [17 Valid ] Loss ==> 0.591 Acc ==> 3.064 F1 ==> 3.064
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.015 Acc ==> 2.865 F1 ==> 2.865
# [18 Valid ] Loss ==> 0.473 Acc ==> 3.116 F1 ==> 3.116
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.905 Acc ==> 2.898 F1 ==> 2.898
# [19 Valid ] Loss ==> 0.416 Acc ==> 3.141 F1 ==> 3.141
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.900 Acc ==> 2.911 F1 ==> 2.911
# [20 Valid ] Loss ==> 0.356 Acc ==> 3.166 F1 ==> 3.166
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.810 Acc ==> 2.948 F1 ==> 2.948
# [21 Valid ] Loss ==> 0.276 Acc ==> 3.188 F1 ==> 3.188
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.799 Acc ==> 2.960 F1 ==> 2.960
# [22 Valid ] Loss ==> 0.287 Acc ==> 3.187 F1 ==> 3.187
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.761 Acc ==> 2.968 F1 ==> 2.968
# [23 Valid ] Loss ==> 0.349 Acc ==> 3.146 F1 ==> 3.146
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.709 Acc ==> 2.987 F1 ==> 2.987
# [24 Valid ] Loss ==> 0.257 Acc ==> 3.183 F1 ==> 3.183
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.647 Acc ==> 3.016 F1 ==> 3.016
# [25 Valid ] Loss ==> 0.283 Acc ==> 3.170 F1 ==> 3.170
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.677 Acc ==> 2.992 F1 ==> 2.992
# [26 Valid ] Loss ==> 0.207 Acc ==> 3.203 F1 ==> 3.203
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.616 Acc ==> 3.021 F1 ==> 3.021
# [27 Valid ] Loss ==> 0.185 Acc ==> 3.209 F1 ==> 3.209
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.572 Acc ==> 3.037 F1 ==> 3.037
# [28 Valid ] Loss ==> 0.147 Acc ==> 3.220 F1 ==> 3.220
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.584 Acc ==> 3.036 F1 ==> 3.036
# [29 Valid ] Loss ==> 0.140 Acc ==> 3.216 F1 ==> 3.216
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.561 Acc ==> 3.047 F1 ==> 3.047
# [30 Valid ] Loss ==> 0.165 Acc ==> 3.209 F1 ==> 3.209
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.453 Acc ==> 1.480 F1 ==> 1.480
# [1 Valid ] Loss ==> 3.280 Acc ==> 2.004 F1 ==> 2.004
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.698 Acc ==> 1.794 F1 ==> 1.794
# [2 Valid ] Loss ==> 2.879 Acc ==> 2.156 F1 ==> 2.156
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.385 Acc ==> 1.918 F1 ==> 1.918
# [3 Valid ] Loss ==> 2.550 Acc ==> 2.284 F1 ==> 2.284
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.085 Acc ==> 2.074 F1 ==> 2.074
# [4 Valid ] Loss ==> 2.325 Acc ==> 2.383 F1 ==> 2.383
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.853 Acc ==> 2.150 F1 ==> 2.150
# [5 Valid ] Loss ==> 2.100 Acc ==> 2.497 F1 ==> 2.497
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.679 Acc ==> 2.214 F1 ==> 2.214
# [6 Valid ] Loss ==> 1.871 Acc ==> 2.573 F1 ==> 2.573
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.473 Acc ==> 2.303 F1 ==> 2.303
# [7 Valid ] Loss ==> 1.716 Acc ==> 2.636 F1 ==> 2.636
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.387 Acc ==> 2.336 F1 ==> 2.336
# [8 Valid ] Loss ==> 1.490 Acc ==> 2.731 F1 ==> 2.731
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.196 Acc ==> 2.424 F1 ==> 2.424
# [9 Valid ] Loss ==> 1.449 Acc ==> 2.748 F1 ==> 2.748
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.097 Acc ==> 2.456 F1 ==> 2.456
# [10 Valid ] Loss ==> 1.288 Acc ==> 2.816 F1 ==> 2.816
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.014 Acc ==> 2.488 F1 ==> 2.488
# [11 Valid ] Loss ==> 1.141 Acc ==> 2.863 F1 ==> 2.863
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.878 Acc ==> 2.546 F1 ==> 2.546
# [12 Valid ] Loss ==> 1.058 Acc ==> 2.882 F1 ==> 2.882
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.682 Acc ==> 2.610 F1 ==> 2.610
# [13 Valid ] Loss ==> 0.883 Acc ==> 2.959 F1 ==> 2.959
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.662 Acc ==> 2.624 F1 ==> 2.624
# [14 Valid ] Loss ==> 0.825 Acc ==> 2.984 F1 ==> 2.984
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.592 Acc ==> 2.661 F1 ==> 2.661
# [15 Valid ] Loss ==> 0.790 Acc ==> 2.986 F1 ==> 2.986
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.510 Acc ==> 2.688 F1 ==> 2.688
# [16 Valid ] Loss ==> 0.699 Acc ==> 3.026 F1 ==> 3.026
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.420 Acc ==> 2.721 F1 ==> 2.721
# [17 Valid ] Loss ==> 0.672 Acc ==> 3.029 F1 ==> 3.029
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.350 Acc ==> 2.744 F1 ==> 2.744
# [18 Valid ] Loss ==> 0.582 Acc ==> 3.090 F1 ==> 3.090
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.360 Acc ==> 2.738 F1 ==> 2.738
# [19 Valid ] Loss ==> 0.594 Acc ==> 3.041 F1 ==> 3.041
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.266 Acc ==> 2.762 F1 ==> 2.762
# [20 Valid ] Loss ==> 0.472 Acc ==> 3.112 F1 ==> 3.112
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.187 Acc ==> 2.796 F1 ==> 2.796
# [21 Valid ] Loss ==> 0.431 Acc ==> 3.116 F1 ==> 3.116
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.109 Acc ==> 2.827 F1 ==> 2.827
# [22 Valid ] Loss ==> 0.422 Acc ==> 3.112 F1 ==> 3.112
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.074 Acc ==> 2.843 F1 ==> 2.843
# [23 Valid ] Loss ==> 0.371 Acc ==> 3.149 F1 ==> 3.149
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.033 Acc ==> 2.859 F1 ==> 2.859
# [24 Valid ] Loss ==> 0.386 Acc ==> 3.136 F1 ==> 3.136
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.000 Acc ==> 2.877 F1 ==> 2.877
# [25 Valid ] Loss ==> 0.326 Acc ==> 3.153 F1 ==> 3.153
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.951 Acc ==> 2.886 F1 ==> 2.886
# [26 Valid ] Loss ==> 0.270 Acc ==> 3.172 F1 ==> 3.172
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.869 Acc ==> 2.925 F1 ==> 2.925
# [27 Valid ] Loss ==> 0.312 Acc ==> 3.157 F1 ==> 3.157
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.841 Acc ==> 2.934 F1 ==> 2.934
# [28 Valid ] Loss ==> 0.276 Acc ==> 3.166 F1 ==> 3.166
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.843 Acc ==> 2.925 F1 ==> 2.925
# [29 Valid ] Loss ==> 0.214 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.890 Acc ==> 2.914 F1 ==> 2.914
# [30 Valid ] Loss ==> 0.233 Acc ==> 3.176 F1 ==> 3.176
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.824 Acc ==> 1.352 F1 ==> 1.352
# [1 Valid ] Loss ==> 3.544 Acc ==> 1.877 F1 ==> 1.877
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.964 Acc ==> 1.691 F1 ==> 1.691
# [2 Valid ] Loss ==> 3.100 Acc ==> 2.074 F1 ==> 2.074
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.599 Acc ==> 1.834 F1 ==> 1.834
# [3 Valid ] Loss ==> 2.824 Acc ==> 2.162 F1 ==> 2.162
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.347 Acc ==> 1.947 F1 ==> 1.947
# [4 Valid ] Loss ==> 2.522 Acc ==> 2.318 F1 ==> 2.318
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.180 Acc ==> 2.028 F1 ==> 2.028
# [5 Valid ] Loss ==> 2.302 Acc ==> 2.410 F1 ==> 2.410
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 3.008 Acc ==> 2.066 F1 ==> 2.066
# [6 Valid ] Loss ==> 2.147 Acc ==> 2.476 F1 ==> 2.476
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.815 Acc ==> 2.174 F1 ==> 2.174
# [7 Valid ] Loss ==> 1.879 Acc ==> 2.591 F1 ==> 2.591
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.696 Acc ==> 2.244 F1 ==> 2.244
# [8 Valid ] Loss ==> 1.796 Acc ==> 2.627 F1 ==> 2.627
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.537 Acc ==> 2.296 F1 ==> 2.296
# [9 Valid ] Loss ==> 1.633 Acc ==> 2.689 F1 ==> 2.689
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.416 Acc ==> 2.324 F1 ==> 2.324
# [10 Valid ] Loss ==> 1.561 Acc ==> 2.690 F1 ==> 2.690
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.349 Acc ==> 2.378 F1 ==> 2.378
# [11 Valid ] Loss ==> 1.431 Acc ==> 2.752 F1 ==> 2.752
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.211 Acc ==> 2.428 F1 ==> 2.428
# [12 Valid ] Loss ==> 1.294 Acc ==> 2.801 F1 ==> 2.801
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 2.127 Acc ==> 2.456 F1 ==> 2.456
# [13 Valid ] Loss ==> 1.191 Acc ==> 2.836 F1 ==> 2.836
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 2.009 Acc ==> 2.502 F1 ==> 2.502
# [14 Valid ] Loss ==> 1.129 Acc ==> 2.870 F1 ==> 2.870
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.899 Acc ==> 2.540 F1 ==> 2.540
# [15 Valid ] Loss ==> 0.979 Acc ==> 2.930 F1 ==> 2.930
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.867 Acc ==> 2.546 F1 ==> 2.546
# [16 Valid ] Loss ==> 0.940 Acc ==> 2.918 F1 ==> 2.918
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.702 Acc ==> 2.616 F1 ==> 2.616
# [17 Valid ] Loss ==> 0.870 Acc ==> 2.955 F1 ==> 2.955
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.674 Acc ==> 2.633 F1 ==> 2.633
# [18 Valid ] Loss ==> 0.809 Acc ==> 2.990 F1 ==> 2.990
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.596 Acc ==> 2.663 F1 ==> 2.663
# [19 Valid ] Loss ==> 0.725 Acc ==> 3.012 F1 ==> 3.012
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.502 Acc ==> 2.703 F1 ==> 2.703
# [20 Valid ] Loss ==> 0.695 Acc ==> 3.040 F1 ==> 3.040
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.488 Acc ==> 2.688 F1 ==> 2.688
# [21 Valid ] Loss ==> 0.587 Acc ==> 3.064 F1 ==> 3.064
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.391 Acc ==> 2.742 F1 ==> 2.742
# [22 Valid ] Loss ==> 0.513 Acc ==> 3.084 F1 ==> 3.084
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.334 Acc ==> 2.753 F1 ==> 2.753
# [23 Valid ] Loss ==> 0.466 Acc ==> 3.114 F1 ==> 3.114
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.303 Acc ==> 2.778 F1 ==> 2.778
# [24 Valid ] Loss ==> 0.485 Acc ==> 3.111 F1 ==> 3.111
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.298 Acc ==> 2.767 F1 ==> 2.767
# [25 Valid ] Loss ==> 0.443 Acc ==> 3.106 F1 ==> 3.106
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.172 Acc ==> 2.817 F1 ==> 2.817
# [26 Valid ] Loss ==> 0.369 Acc ==> 3.141 F1 ==> 3.141
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.229 Acc ==> 2.805 F1 ==> 2.805
# [27 Valid ] Loss ==> 0.368 Acc ==> 3.139 F1 ==> 3.139
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.111 Acc ==> 2.838 F1 ==> 2.838
# [28 Valid ] Loss ==> 0.349 Acc ==> 3.142 F1 ==> 3.142
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.099 Acc ==> 2.856 F1 ==> 2.856
# [29 Valid ] Loss ==> 0.283 Acc ==> 3.173 F1 ==> 3.173
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.020 Acc ==> 2.874 F1 ==> 2.874
# [30 Valid ] Loss ==> 0.298 Acc ==> 3.160 F1 ==> 3.160
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.416 Acc ==> 1.082 F1 ==> 1.082
# [1 Valid ] Loss ==> 3.994 Acc ==> 1.705 F1 ==> 1.705
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 4.360 Acc ==> 1.488 F1 ==> 1.488
# [2 Valid ] Loss ==> 3.525 Acc ==> 1.886 F1 ==> 1.886
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.981 Acc ==> 1.676 F1 ==> 1.676
# [3 Valid ] Loss ==> 3.103 Acc ==> 2.099 F1 ==> 2.099
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.757 Acc ==> 1.790 F1 ==> 1.790
# [4 Valid ] Loss ==> 2.877 Acc ==> 2.166 F1 ==> 2.166
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.563 Acc ==> 1.885 F1 ==> 1.885
# [5 Valid ] Loss ==> 2.737 Acc ==> 2.224 F1 ==> 2.224
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 3.441 Acc ==> 1.946 F1 ==> 1.946
# [6 Valid ] Loss ==> 2.491 Acc ==> 2.370 F1 ==> 2.370
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 3.262 Acc ==> 2.008 F1 ==> 2.008
# [7 Valid ] Loss ==> 2.329 Acc ==> 2.432 F1 ==> 2.432
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 3.033 Acc ==> 2.128 F1 ==> 2.128
# [8 Valid ] Loss ==> 2.149 Acc ==> 2.472 F1 ==> 2.472
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.988 Acc ==> 2.151 F1 ==> 2.151
# [9 Valid ] Loss ==> 1.989 Acc ==> 2.566 F1 ==> 2.566
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.817 Acc ==> 2.223 F1 ==> 2.223
# [10 Valid ] Loss ==> 1.890 Acc ==> 2.608 F1 ==> 2.608
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.709 Acc ==> 2.258 F1 ==> 2.258
# [11 Valid ] Loss ==> 1.792 Acc ==> 2.637 F1 ==> 2.637
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.710 Acc ==> 2.272 F1 ==> 2.272
# [12 Valid ] Loss ==> 1.639 Acc ==> 2.722 F1 ==> 2.722
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 2.509 Acc ==> 2.349 F1 ==> 2.349
# [13 Valid ] Loss ==> 1.513 Acc ==> 2.744 F1 ==> 2.744
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 2.405 Acc ==> 2.400 F1 ==> 2.400
# [14 Valid ] Loss ==> 1.492 Acc ==> 2.725 F1 ==> 2.725
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 2.276 Acc ==> 2.419 F1 ==> 2.419
# [15 Valid ] Loss ==> 1.306 Acc ==> 2.815 F1 ==> 2.815
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 2.269 Acc ==> 2.446 F1 ==> 2.446
# [16 Valid ] Loss ==> 1.246 Acc ==> 2.833 F1 ==> 2.833
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 2.201 Acc ==> 2.452 F1 ==> 2.452
# [17 Valid ] Loss ==> 1.186 Acc ==> 2.845 F1 ==> 2.845
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 2.069 Acc ==> 2.506 F1 ==> 2.506
# [18 Valid ] Loss ==> 1.170 Acc ==> 2.839 F1 ==> 2.839
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 2.010 Acc ==> 2.524 F1 ==> 2.524
# [19 Valid ] Loss ==> 1.017 Acc ==> 2.918 F1 ==> 2.918
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 2.015 Acc ==> 2.532 F1 ==> 2.532
# [20 Valid ] Loss ==> 0.980 Acc ==> 2.924 F1 ==> 2.924
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.964 Acc ==> 2.550 F1 ==> 2.550
# [21 Valid ] Loss ==> 0.892 Acc ==> 2.952 F1 ==> 2.952
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.852 Acc ==> 2.580 F1 ==> 2.580
# [22 Valid ] Loss ==> 0.822 Acc ==> 2.997 F1 ==> 2.997
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.777 Acc ==> 2.631 F1 ==> 2.631
# [23 Valid ] Loss ==> 0.803 Acc ==> 3.004 F1 ==> 3.004
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.721 Acc ==> 2.650 F1 ==> 2.650
# [24 Valid ] Loss ==> 0.752 Acc ==> 3.007 F1 ==> 3.007
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.640 Acc ==> 2.664 F1 ==> 2.664
# [25 Valid ] Loss ==> 0.718 Acc ==> 3.029 F1 ==> 3.029
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.578 Acc ==> 2.706 F1 ==> 2.706
# [26 Valid ] Loss ==> 0.610 Acc ==> 3.061 F1 ==> 3.061
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.486 Acc ==> 2.732 F1 ==> 2.732
# [27 Valid ] Loss ==> 0.548 Acc ==> 3.096 F1 ==> 3.096
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.478 Acc ==> 2.712 F1 ==> 2.712
# [28 Valid ] Loss ==> 0.525 Acc ==> 3.087 F1 ==> 3.087
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.463 Acc ==> 2.741 F1 ==> 2.741
# [29 Valid ] Loss ==> 0.503 Acc ==> 3.091 F1 ==> 3.091
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.421 Acc ==> 2.756 F1 ==> 2.756
# [30 Valid ] Loss ==> 0.495 Acc ==> 3.087 F1 ==> 3.087
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.186 Acc ==> 0.818 F1 ==> 0.818
# [1 Valid ] Loss ==> 4.914 Acc ==> 1.348 F1 ==> 1.348
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.045 Acc ==> 1.160 F1 ==> 1.160
# [2 Valid ] Loss ==> 4.212 Acc ==> 1.571 F1 ==> 1.571
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 4.660 Acc ==> 1.329 F1 ==> 1.329
# [3 Valid ] Loss ==> 3.926 Acc ==> 1.717 F1 ==> 1.717
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 4.397 Acc ==> 1.452 F1 ==> 1.452
# [4 Valid ] Loss ==> 3.690 Acc ==> 1.859 F1 ==> 1.859
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 4.218 Acc ==> 1.559 F1 ==> 1.559
# [5 Valid ] Loss ==> 3.414 Acc ==> 1.966 F1 ==> 1.966
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 4.035 Acc ==> 1.663 F1 ==> 1.663
# [6 Valid ] Loss ==> 3.187 Acc ==> 2.044 F1 ==> 2.044
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 3.877 Acc ==> 1.776 F1 ==> 1.776
# [7 Valid ] Loss ==> 2.993 Acc ==> 2.139 F1 ==> 2.139
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 3.795 Acc ==> 1.802 F1 ==> 1.802
# [8 Valid ] Loss ==> 2.852 Acc ==> 2.244 F1 ==> 2.244
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 3.627 Acc ==> 1.883 F1 ==> 1.883
# [9 Valid ] Loss ==> 2.654 Acc ==> 2.314 F1 ==> 2.314
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 3.522 Acc ==> 1.923 F1 ==> 1.923
# [10 Valid ] Loss ==> 2.665 Acc ==> 2.307 F1 ==> 2.307
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 3.488 Acc ==> 1.952 F1 ==> 1.952
# [11 Valid ] Loss ==> 2.426 Acc ==> 2.424 F1 ==> 2.424
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 3.277 Acc ==> 2.023 F1 ==> 2.023
# [12 Valid ] Loss ==> 2.355 Acc ==> 2.423 F1 ==> 2.423
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 3.224 Acc ==> 2.064 F1 ==> 2.064
# [13 Valid ] Loss ==> 2.289 Acc ==> 2.469 F1 ==> 2.469
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 3.184 Acc ==> 2.099 F1 ==> 2.099
# [14 Valid ] Loss ==> 2.106 Acc ==> 2.542 F1 ==> 2.542
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 3.107 Acc ==> 2.147 F1 ==> 2.147
# [15 Valid ] Loss ==> 2.031 Acc ==> 2.584 F1 ==> 2.584
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 2.971 Acc ==> 2.206 F1 ==> 2.206
# [16 Valid ] Loss ==> 1.906 Acc ==> 2.604 F1 ==> 2.604
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 2.914 Acc ==> 2.218 F1 ==> 2.218
# [17 Valid ] Loss ==> 1.860 Acc ==> 2.642 F1 ==> 2.642
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 2.798 Acc ==> 2.280 F1 ==> 2.280
# [18 Valid ] Loss ==> 1.696 Acc ==> 2.695 F1 ==> 2.695
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 2.806 Acc ==> 2.284 F1 ==> 2.284
# [19 Valid ] Loss ==> 1.687 Acc ==> 2.688 F1 ==> 2.688
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 2.719 Acc ==> 2.314 F1 ==> 2.314
# [20 Valid ] Loss ==> 1.598 Acc ==> 2.741 F1 ==> 2.741
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 2.583 Acc ==> 2.365 F1 ==> 2.365
# [21 Valid ] Loss ==> 1.526 Acc ==> 2.766 F1 ==> 2.766
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 2.535 Acc ==> 2.382 F1 ==> 2.382
# [22 Valid ] Loss ==> 1.467 Acc ==> 2.793 F1 ==> 2.793
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 2.536 Acc ==> 2.378 F1 ==> 2.378
# [23 Valid ] Loss ==> 1.378 Acc ==> 2.820 F1 ==> 2.820
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 2.393 Acc ==> 2.439 F1 ==> 2.439
# [24 Valid ] Loss ==> 1.269 Acc ==> 2.857 F1 ==> 2.857
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 2.350 Acc ==> 2.485 F1 ==> 2.485
# [25 Valid ] Loss ==> 1.213 Acc ==> 2.878 F1 ==> 2.878
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 2.343 Acc ==> 2.474 F1 ==> 2.474
# [26 Valid ] Loss ==> 1.216 Acc ==> 2.877 F1 ==> 2.877
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 2.221 Acc ==> 2.512 F1 ==> 2.512
# [27 Valid ] Loss ==> 1.147 Acc ==> 2.884 F1 ==> 2.884
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 2.226 Acc ==> 2.531 F1 ==> 2.531
# [28 Valid ] Loss ==> 1.029 Acc ==> 2.929 F1 ==> 2.929
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 2.140 Acc ==> 2.544 F1 ==> 2.544
# [29 Valid ] Loss ==> 0.994 Acc ==> 2.940 F1 ==> 2.940
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 2.082 Acc ==> 2.562 F1 ==> 2.562
# [30 Valid ] Loss ==> 0.969 Acc ==> 2.948 F1 ==> 2.948
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.809 Acc ==> 0.616 F1 ==> 0.616
# [1 Valid ] Loss ==> 5.858 Acc ==> 1.117 F1 ==> 1.117
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 5.647 Acc ==> 0.946 F1 ==> 0.946
# [2 Valid ] Loss ==> 4.800 Acc ==> 1.435 F1 ==> 1.435
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.171 Acc ==> 1.074 F1 ==> 1.074
# [3 Valid ] Loss ==> 4.400 Acc ==> 1.562 F1 ==> 1.562
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 4.877 Acc ==> 1.207 F1 ==> 1.207
# [4 Valid ] Loss ==> 4.177 Acc ==> 1.606 F1 ==> 1.606
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 4.766 Acc ==> 1.238 F1 ==> 1.238
# [5 Valid ] Loss ==> 4.024 Acc ==> 1.676 F1 ==> 1.676
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 4.653 Acc ==> 1.326 F1 ==> 1.326
# [6 Valid ] Loss ==> 3.950 Acc ==> 1.630 F1 ==> 1.630
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 4.507 Acc ==> 1.368 F1 ==> 1.368
# [7 Valid ] Loss ==> 3.772 Acc ==> 1.749 F1 ==> 1.749
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 4.411 Acc ==> 1.405 F1 ==> 1.405
# [8 Valid ] Loss ==> 3.621 Acc ==> 1.793 F1 ==> 1.793
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 4.405 Acc ==> 1.454 F1 ==> 1.454
# [9 Valid ] Loss ==> 3.570 Acc ==> 1.863 F1 ==> 1.863
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 4.303 Acc ==> 1.497 F1 ==> 1.497
# [10 Valid ] Loss ==> 3.493 Acc ==> 1.844 F1 ==> 1.844
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 4.191 Acc ==> 1.537 F1 ==> 1.537
# [11 Valid ] Loss ==> 3.388 Acc ==> 1.943 F1 ==> 1.943
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 4.151 Acc ==> 1.551 F1 ==> 1.551
# [12 Valid ] Loss ==> 3.223 Acc ==> 1.964 F1 ==> 1.964
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 4.068 Acc ==> 1.592 F1 ==> 1.592
# [13 Valid ] Loss ==> 3.217 Acc ==> 1.978 F1 ==> 1.978
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 3.961 Acc ==> 1.648 F1 ==> 1.648
# [14 Valid ] Loss ==> 3.091 Acc ==> 1.990 F1 ==> 1.990
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 3.970 Acc ==> 1.657 F1 ==> 1.657
# [15 Valid ] Loss ==> 3.077 Acc ==> 1.987 F1 ==> 1.987
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 3.898 Acc ==> 1.721 F1 ==> 1.721
# [16 Valid ] Loss ==> 2.988 Acc ==> 2.076 F1 ==> 2.076
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 3.836 Acc ==> 1.726 F1 ==> 1.726
# [17 Valid ] Loss ==> 2.922 Acc ==> 2.098 F1 ==> 2.098
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 3.790 Acc ==> 1.726 F1 ==> 1.726
# [18 Valid ] Loss ==> 2.948 Acc ==> 2.015 F1 ==> 2.015
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 3.715 Acc ==> 1.759 F1 ==> 1.759
# [19 Valid ] Loss ==> 2.782 Acc ==> 2.146 F1 ==> 2.146
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 3.657 Acc ==> 1.794 F1 ==> 1.794
# [20 Valid ] Loss ==> 2.740 Acc ==> 2.146 F1 ==> 2.146
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 3.647 Acc ==> 1.804 F1 ==> 1.804
# [21 Valid ] Loss ==> 2.670 Acc ==> 2.190 F1 ==> 2.190
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 3.559 Acc ==> 1.852 F1 ==> 1.852
# [22 Valid ] Loss ==> 2.653 Acc ==> 2.150 F1 ==> 2.150
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 3.532 Acc ==> 1.856 F1 ==> 1.856
# [23 Valid ] Loss ==> 2.591 Acc ==> 2.243 F1 ==> 2.243
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 3.537 Acc ==> 1.859 F1 ==> 1.859
# [24 Valid ] Loss ==> 2.569 Acc ==> 2.230 F1 ==> 2.230
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 3.469 Acc ==> 1.863 F1 ==> 1.863
# [25 Valid ] Loss ==> 2.495 Acc ==> 2.287 F1 ==> 2.287
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 3.414 Acc ==> 1.901 F1 ==> 1.901
# [26 Valid ] Loss ==> 2.374 Acc ==> 2.310 F1 ==> 2.310
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 3.410 Acc ==> 1.863 F1 ==> 1.863
# [27 Valid ] Loss ==> 2.352 Acc ==> 2.310 F1 ==> 2.310
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 3.325 Acc ==> 1.942 F1 ==> 1.942
# [28 Valid ] Loss ==> 2.357 Acc ==> 2.304 F1 ==> 2.304
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 3.367 Acc ==> 1.896 F1 ==> 1.896
# [29 Valid ] Loss ==> 2.329 Acc ==> 2.330 F1 ==> 2.330
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 3.332 Acc ==> 1.922 F1 ==> 1.922
# [30 Valid ] Loss ==> 2.267 Acc ==> 2.363 F1 ==> 2.363
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 6.986 Acc ==> 0.505 F1 ==> 0.505
# [1 Valid ] Loss ==> 6.750 Acc ==> 0.592 F1 ==> 0.592
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 6.347 Acc ==> 0.645 F1 ==> 0.645
# [2 Valid ] Loss ==> 6.286 Acc ==> 0.727 F1 ==> 0.727
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 5.969 Acc ==> 0.714 F1 ==> 0.714
# [3 Valid ] Loss ==> 5.663 Acc ==> 0.893 F1 ==> 0.893
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 5.755 Acc ==> 0.771 F1 ==> 0.771
# [4 Valid ] Loss ==> 5.363 Acc ==> 0.990 F1 ==> 0.990
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 5.558 Acc ==> 0.824 F1 ==> 0.824
# [5 Valid ] Loss ==> 5.343 Acc ==> 0.998 F1 ==> 0.998
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 5.464 Acc ==> 0.896 F1 ==> 0.896
# [6 Valid ] Loss ==> 5.087 Acc ==> 1.121 F1 ==> 1.121
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 5.302 Acc ==> 0.946 F1 ==> 0.946
# [7 Valid ] Loss ==> 4.769 Acc ==> 1.228 F1 ==> 1.228
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 5.223 Acc ==> 1.001 F1 ==> 1.001
# [8 Valid ] Loss ==> 4.656 Acc ==> 1.308 F1 ==> 1.308
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 5.115 Acc ==> 1.051 F1 ==> 1.051
# [9 Valid ] Loss ==> 4.529 Acc ==> 1.334 F1 ==> 1.334
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 5.000 Acc ==> 1.065 F1 ==> 1.065
# [10 Valid ] Loss ==> 4.421 Acc ==> 1.339 F1 ==> 1.339
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 4.982 Acc ==> 1.071 F1 ==> 1.071
# [11 Valid ] Loss ==> 4.361 Acc ==> 1.442 F1 ==> 1.442
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 4.909 Acc ==> 1.112 F1 ==> 1.112
# [12 Valid ] Loss ==> 4.290 Acc ==> 1.460 F1 ==> 1.460
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 4.850 Acc ==> 1.142 F1 ==> 1.142
# [13 Valid ] Loss ==> 4.290 Acc ==> 1.419 F1 ==> 1.419
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 4.815 Acc ==> 1.165 F1 ==> 1.165
# [14 Valid ] Loss ==> 4.162 Acc ==> 1.522 F1 ==> 1.522
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 4.745 Acc ==> 1.207 F1 ==> 1.207
# [15 Valid ] Loss ==> 4.096 Acc ==> 1.516 F1 ==> 1.516
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 4.760 Acc ==> 1.189 F1 ==> 1.189
# [16 Valid ] Loss ==> 4.065 Acc ==> 1.479 F1 ==> 1.479
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 4.715 Acc ==> 1.177 F1 ==> 1.177
# [17 Valid ] Loss ==> 4.047 Acc ==> 1.582 F1 ==> 1.582
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 4.620 Acc ==> 1.220 F1 ==> 1.220
# [18 Valid ] Loss ==> 3.941 Acc ==> 1.616 F1 ==> 1.616
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 4.685 Acc ==> 1.226 F1 ==> 1.226
# [19 Valid ] Loss ==> 3.970 Acc ==> 1.572 F1 ==> 1.572
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 4.627 Acc ==> 1.222 F1 ==> 1.222
# [20 Valid ] Loss ==> 3.975 Acc ==> 1.526 F1 ==> 1.526
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 4.578 Acc ==> 1.228 F1 ==> 1.228
# [21 Valid ] Loss ==> 3.865 Acc ==> 1.627 F1 ==> 1.627
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 4.512 Acc ==> 1.302 F1 ==> 1.302
# [22 Valid ] Loss ==> 3.775 Acc ==> 1.616 F1 ==> 1.616
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 4.518 Acc ==> 1.269 F1 ==> 1.269
# [23 Valid ] Loss ==> 3.786 Acc ==> 1.636 F1 ==> 1.636
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 4.538 Acc ==> 1.261 F1 ==> 1.261
# [24 Valid ] Loss ==> 3.872 Acc ==> 1.644 F1 ==> 1.644
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 4.449 Acc ==> 1.276 F1 ==> 1.276
# [25 Valid ] Loss ==> 3.683 Acc ==> 1.718 F1 ==> 1.718
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 4.376 Acc ==> 1.352 F1 ==> 1.352
# [26 Valid ] Loss ==> 3.621 Acc ==> 1.678 F1 ==> 1.678
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 4.369 Acc ==> 1.315 F1 ==> 1.315
# [27 Valid ] Loss ==> 3.660 Acc ==> 1.735 F1 ==> 1.735
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 4.348 Acc ==> 1.348 F1 ==> 1.348
# [28 Valid ] Loss ==> 3.607 Acc ==> 1.776 F1 ==> 1.776
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 4.371 Acc ==> 1.346 F1 ==> 1.346
# [29 Valid ] Loss ==> 3.606 Acc ==> 1.771 F1 ==> 1.771
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 4.340 Acc ==> 1.365 F1 ==> 1.365
# [30 Valid ] Loss ==> 3.585 Acc ==> 1.698 F1 ==> 1.698
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()
