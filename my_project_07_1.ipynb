# %%
# 모듈로딩
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn           
import torch.nn.functional as F 
import torch.optim as optim
import torchmetrics.functional as metrics
import torchmetrics.functional.classification as metrics
import sklearn.metrics as skm

from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

# %%
featureDF = pd.read_pickle('./DATA/feature2.pkl')
targetDF = pd.read_pickle('./DATA/target2.pkl')

# %%
def plot_fish(image_data):
    image = image_data.reshape(45, 59)
    plt.imshow(image, cmap = 'binary')
    plt.axis('off')

some_fish = featureDF.iloc[0].values
plot_fish(some_fish)
plt.show()

# %%
some_fish.shape
# Out:
# (2655,)

# %%
# 학습을 위해 타겟 데이터를 시리즈로 변경
targetSR = targetDF.squeeze()
type(targetSR)
# Out:
# pandas.core.series.Series

# %%
# shape 확인
print(f'featureDF => {featureDF.shape}, targetSR => {targetSR.shape}')
# Out:
# featureDF => (9000, 2655), targetSR => (9000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(featureDF, targetSR, test_size = 90, random_state = 42, stratify = targetSR)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 810, random_state = 42, stratify = y_train)

# %%
# 데이터의 Tensor 변환
class DLDataset(Dataset):

    # 초기화 콜백 함수(callback function)
    def __init__(self, x_data, y_data):
        super().__init__()
        # x, y 데이터 => ndarray
        x_data = x_data.values if isinstance(x_data, pd.DataFrame) else x_data
        y_data = y_data.values if isinstance(y_data, pd.Series) else y_data

        # ndarray => tensor
        self.feature = torch.FloatTensor(x_data)
        self.target = torch.LongTensor(y_data)  # 타겟을 원핫인코딩하면 FloatTensor 사용
        print('[target & target shape]', self.target.shape, self.target.ndim)
    
    # 데이터셋의 개수 체크 콜백 함수(callback function)
    def __len__(self):
        return self.target.shape[0]
    
    # 특정 인덱스 데이터 + 라벨 반환 콜백 함수(callback function)
    def __getitem__(self, index):
        return self.feature[index], self.target[index]

# %%
trainDS = DLDataset(X_train, y_train)
validDS = DLDataset(X_val, y_val)
testDS = DLDataset(X_test, y_test)
# Out:
# [target & target shape] torch.Size([8100]) 1
# [target & target shape] torch.Size([810]) 1
# [target & target shape] torch.Size([90]) 1

# %%
validDS.feature.shape
# Out:
# torch.Size([810, 2655])

# %%
batch_size = 50
trainDL = DataLoader(trainDS, batch_size = batch_size, shuffle = True, drop_last = True)
validDL = DataLoader(validDS, batch_size = batch_size, shuffle = True, drop_last = True)
testDL = DataLoader(testDS, batch_size = batch_size, shuffle = True, drop_last = True)

# %%
len(trainDL), len(validDL), len(testDL)
# Out:
# (162, 16, 1)

# %%
# Epoch당 반복 단위
print(f'batch_size = {batch_size}')
print(f'trainDL => {len(trainDL)}개, validDL => {len(validDL)}개, testDL => {len(testDL)}개')
# Out:
# batch_size = 50
# trainDL => 162개, validDL => 16개, testDL => 1개

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
CLASSES = 9

# %% [markdown]
# ### Dropout 미적용, Weight Initialization 미적용 <hr>

# %%
class FishModel(nn.Module):
    
    # 모델 구성 요소 초기화 
    def __init__(self, in_dim, out_dim, nodes_list = []):
        super().__init__()
        nodes_list.insert(0, in_dim)
        nodes_list.append(out_dim)
        layer_num = len(nodes_list) - 1
        layers = []
        for i in range(layer_num):
            if i <= layer_num - 2:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))
                layers.append(nn.BatchNorm1d(num_features = nodes_list[i+1]))
                layers.append(nn.ReLU())
            else:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))
                
        self.layers = nn.ModuleList(layers)
               
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
### ===> 학습 진행함수 
def training(epoch):
    # 학습모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화 
    model.train()
    
    # 배치크기 만큼 학습 진행 및 저장
    train_report=[[], [], []]
    for idx, (feature, target)  in enumerate(trainDL):
        # 배치크기만큼의 학습 데이터 준비
        feature, target = feature.to(DEVICE), target.to(DEVICE)
        
        # 학습
        pre_traget = model(feature)
        
        # 손실계산
        loss = LOSS_FN(pre_traget, target)
        train_report[0].append(loss)
        
        # 성능 평가
        acc = metrics.accuracy(pre_traget, target, task='multiclass', num_classes = 9)
        train_report[1].append(acc)
        
        f1 = metrics.f1_score(pre_traget, target, task='multiclass', num_classes = CLASSES)
        train_report[2].append(f1)
        
        # W,b업데이트
        OPTIMIZER.zero_grad()
        loss.backward()
        OPTIMIZER.step()
        
        if not idx%50: print('.', end='')
    
    # 에포크 단위로 학습 모델 저장
    # torch.save(model, './model/my_model.pt')
    
    # 에포크 단위 학습 진행 메시지 출력
    loss_score = (sum(train_report[0])/batch_size).item()
    acc_score = (sum(train_report[1])/batch_size).item()
    f1_score = (sum(train_report[2])/batch_size).item() 
    print(f'\n[{epoch+1} Train ] Loss ==> {loss_score:.3f} Acc ==> {acc_score:.3f} F1 ==> {f1_score:.3f}')
    
    return loss_score, acc_score, f1_score

# %%
### ===> 검증 및 테스트 진행함수 
def testing(epoch, kind='valid'):
    # 학습모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화 
    model.eval()
        
    with torch.no_grad():
        # 배치크기 만큼 학습 진행 및 저장
        test_report=[[], [], []]
        for idx, (feature, target) in enumerate(trainDL):
            # 배치크기만큼의 학습 데이터 준비
            feature, target = feature.to(DEVICE), target.to(DEVICE)

            # 학습
            pre_traget = model(feature)

            # 손실계산
            loss = LOSS_FN(pre_traget, target)
            test_report[0].append(loss)
            
            # 성능 평가 
            acc = metrics.accuracy(pre_traget, target, task='multiclass', num_classes=CLASSES)
            test_report[1].append(acc)
            
            f1 = metrics.f1_score(pre_traget, target, task='multiclass', num_classes=CLASSES)
            test_report[2].append(f1)
            
            #if not idx%50: print('.', end='')

    testing_type = 'Valid' if kind == 'valid' else 'Test'
        
    # 에포크 단위 학습 진행 메시지 출력
    loss_score = (sum(test_report[0])/batch_size).item()
    acc_score = (sum(test_report[1])/batch_size).item()
    f1_score = (sum(test_report[2])/batch_size).item() 
    print(f'[{epoch+1} {testing_type} ] Loss ==> {loss_score:.3f} Acc ==> {acc_score:.3f} F1 ==> {f1_score:.3f}\n')
    
    return loss_score, acc_score, f1_score

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 증가

# %%
layer_list1 = [[2**(j+4) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list1:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)
    

    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model1/my_model1.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# [Epoch 1/30] .
# ...
# [1 Train ] Loss ==> 5.684 Acc ==> 1.274 F1 ==> 1.274
# [1 Valid ] Loss ==> 4.797 Acc ==> 1.697 F1 ==> 1.697
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 4.479 Acc ==> 1.714 F1 ==> 1.714
# [2 Valid ] Loss ==> 3.978 Acc ==> 1.883 F1 ==> 1.883
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.881 Acc ==> 1.875 F1 ==> 1.875
# [3 Valid ] Loss ==> 3.545 Acc ==> 1.991 F1 ==> 1.991
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.510 Acc ==> 1.983 F1 ==> 1.983
# [4 Valid ] Loss ==> 3.122 Acc ==> 2.168 F1 ==> 2.168
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.204 Acc ==> 2.081 F1 ==> 2.081
# [5 Valid ] Loss ==> 2.850 Acc ==> 2.283 F1 ==> 2.283
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.938 Acc ==> 2.204 F1 ==> 2.204
# [6 Valid ] Loss ==> 2.617 Acc ==> 2.358 F1 ==> 2.358
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.703 Acc ==> 2.278 F1 ==> 2.278
# [7 Valid ] Loss ==> 2.473 Acc ==> 2.388 F1 ==> 2.388
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.486 Acc ==> 2.353 F1 ==> 2.353
# [8 Valid ] Loss ==> 2.261 Acc ==> 2.448 F1 ==> 2.448
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.302 Acc ==> 2.429 F1 ==> 2.429
# [9 Valid ] Loss ==> 1.937 Acc ==> 2.614 F1 ==> 2.614
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.143 Acc ==> 2.500 F1 ==> 2.500
# [10 Valid ] Loss ==> 1.870 Acc ==> 2.662 F1 ==> 2.662
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.962 Acc ==> 2.552 F1 ==> 2.552
# [11 Valid ] Loss ==> 1.696 Acc ==> 2.689 F1 ==> 2.689
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.812 Acc ==> 2.621 F1 ==> 2.621
# [12 Valid ] Loss ==> 1.609 Acc ==> 2.709 F1 ==> 2.709
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.685 Acc ==> 2.665 F1 ==> 2.665
# [13 Valid ] Loss ==> 1.405 Acc ==> 2.794 F1 ==> 2.794
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.559 Acc ==> 2.707 F1 ==> 2.707
# [14 Valid ] Loss ==> 1.260 Acc ==> 2.845 F1 ==> 2.845
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.457 Acc ==> 2.750 F1 ==> 2.750
# [15 Valid ] Loss ==> 1.326 Acc ==> 2.782 F1 ==> 2.782
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.346 Acc ==> 2.785 F1 ==> 2.785
# [16 Valid ] Loss ==> 1.045 Acc ==> 2.914 F1 ==> 2.914
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.241 Acc ==> 2.835 F1 ==> 2.835
# [17 Valid ] Loss ==> 0.995 Acc ==> 2.957 F1 ==> 2.957
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.159 Acc ==> 2.865 F1 ==> 2.865
# [18 Valid ] Loss ==> 0.991 Acc ==> 2.926 F1 ==> 2.926
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.077 Acc ==> 2.895 F1 ==> 2.895
# [19 Valid ] Loss ==> 0.827 Acc ==> 3.006 F1 ==> 3.006
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.043 Acc ==> 2.905 F1 ==> 2.905
# [20 Valid ] Loss ==> 0.760 Acc ==> 3.044 F1 ==> 3.044
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.984 Acc ==> 2.916 F1 ==> 2.916
# [21 Valid ] Loss ==> 0.826 Acc ==> 3.003 F1 ==> 3.003
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.920 Acc ==> 2.944 F1 ==> 2.944
# [22 Valid ] Loss ==> 0.645 Acc ==> 3.087 F1 ==> 3.087
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.876 Acc ==> 2.951 F1 ==> 2.951
# [23 Valid ] Loss ==> 0.922 Acc ==> 2.932 F1 ==> 2.932
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.831 Acc ==> 2.974 F1 ==> 2.974
# [24 Valid ] Loss ==> 0.635 Acc ==> 3.062 F1 ==> 3.062
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.765 Acc ==> 3.000 F1 ==> 3.000
# [25 Valid ] Loss ==> 0.615 Acc ==> 3.076 F1 ==> 3.076
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.761 Acc ==> 2.991 F1 ==> 2.991
# [26 Valid ] Loss ==> 1.077 Acc ==> 2.844 F1 ==> 2.844
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.668 Acc ==> 3.037 F1 ==> 3.037
# [27 Valid ] Loss ==> 0.495 Acc ==> 3.113 F1 ==> 3.113
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.665 Acc ==> 3.032 F1 ==> 3.032
# [28 Valid ] Loss ==> 0.576 Acc ==> 3.070 F1 ==> 3.070
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.632 Acc ==> 3.037 F1 ==> 3.037
# [29 Valid ] Loss ==> 0.473 Acc ==> 3.123 F1 ==> 3.123
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.621 Acc ==> 3.052 F1 ==> 3.052
# [30 Valid ] Loss ==> 0.491 Acc ==> 3.111 F1 ==> 3.111
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.250 Acc ==> 1.335 F1 ==> 1.335
# [1 Valid ] Loss ==> 4.208 Acc ==> 1.671 F1 ==> 1.671
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.964 Acc ==> 1.782 F1 ==> 1.782
# [2 Valid ] Loss ==> 3.454 Acc ==> 1.963 F1 ==> 1.963
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.442 Acc ==> 1.960 F1 ==> 1.960
# [3 Valid ] Loss ==> 3.006 Acc ==> 2.189 F1 ==> 2.189
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.099 Acc ==> 2.104 F1 ==> 2.104
# [4 Valid ] Loss ==> 2.613 Acc ==> 2.345 F1 ==> 2.345
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.818 Acc ==> 2.204 F1 ==> 2.204
# [5 Valid ] Loss ==> 2.392 Acc ==> 2.385 F1 ==> 2.385
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.604 Acc ==> 2.281 F1 ==> 2.281
# [6 Valid ] Loss ==> 2.214 Acc ==> 2.484 F1 ==> 2.484
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.417 Acc ==> 2.356 F1 ==> 2.356
# [7 Valid ] Loss ==> 1.960 Acc ==> 2.555 F1 ==> 2.555
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.214 Acc ==> 2.438 F1 ==> 2.438
# [8 Valid ] Loss ==> 1.701 Acc ==> 2.677 F1 ==> 2.677
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.039 Acc ==> 2.508 F1 ==> 2.508
# [9 Valid ] Loss ==> 1.760 Acc ==> 2.612 F1 ==> 2.612
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.900 Acc ==> 2.554 F1 ==> 2.554
# [10 Valid ] Loss ==> 1.424 Acc ==> 2.766 F1 ==> 2.766
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.747 Acc ==> 2.608 F1 ==> 2.608
# [11 Valid ] Loss ==> 1.406 Acc ==> 2.759 F1 ==> 2.759
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.623 Acc ==> 2.652 F1 ==> 2.652
# [12 Valid ] Loss ==> 1.318 Acc ==> 2.801 F1 ==> 2.801
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.564 Acc ==> 2.668 F1 ==> 2.668
# [13 Valid ] Loss ==> 1.353 Acc ==> 2.748 F1 ==> 2.748
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.478 Acc ==> 2.713 F1 ==> 2.713
# [14 Valid ] Loss ==> 1.131 Acc ==> 2.864 F1 ==> 2.864
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.372 Acc ==> 2.754 F1 ==> 2.754
# [15 Valid ] Loss ==> 0.970 Acc ==> 2.918 F1 ==> 2.918
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.262 Acc ==> 2.786 F1 ==> 2.786
# [16 Valid ] Loss ==> 0.822 Acc ==> 2.990 F1 ==> 2.990
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.197 Acc ==> 2.799 F1 ==> 2.799
# [17 Valid ] Loss ==> 0.806 Acc ==> 2.995 F1 ==> 2.995
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.086 Acc ==> 2.858 F1 ==> 2.858
# [18 Valid ] Loss ==> 0.840 Acc ==> 2.977 F1 ==> 2.977
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.093 Acc ==> 2.850 F1 ==> 2.850
# [19 Valid ] Loss ==> 0.693 Acc ==> 3.027 F1 ==> 3.027
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.018 Acc ==> 2.878 F1 ==> 2.878
# [20 Valid ] Loss ==> 0.820 Acc ==> 2.958 F1 ==> 2.958
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.947 Acc ==> 2.902 F1 ==> 2.902
# [21 Valid ] Loss ==> 0.643 Acc ==> 3.033 F1 ==> 3.033
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.963 Acc ==> 2.893 F1 ==> 2.893
# [22 Valid ] Loss ==> 0.643 Acc ==> 3.031 F1 ==> 3.031
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.843 Acc ==> 2.944 F1 ==> 2.944
# [23 Valid ] Loss ==> 0.577 Acc ==> 3.067 F1 ==> 3.067
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.795 Acc ==> 2.950 F1 ==> 2.950
# [24 Valid ] Loss ==> 0.578 Acc ==> 3.057 F1 ==> 3.057
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.806 Acc ==> 2.945 F1 ==> 2.945
# [25 Valid ] Loss ==> 0.485 Acc ==> 3.098 F1 ==> 3.098
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.740 Acc ==> 2.977 F1 ==> 2.977
# [26 Valid ] Loss ==> 0.681 Acc ==> 2.999 F1 ==> 2.999
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.677 Acc ==> 3.012 F1 ==> 3.012
# [27 Valid ] Loss ==> 0.477 Acc ==> 3.100 F1 ==> 3.100
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.684 Acc ==> 3.004 F1 ==> 3.004
# [28 Valid ] Loss ==> 0.428 Acc ==> 3.109 F1 ==> 3.109
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.711 Acc ==> 2.990 F1 ==> 2.990
# [29 Valid ] Loss ==> 0.447 Acc ==> 3.101 F1 ==> 3.101
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.663 Acc ==> 3.005 F1 ==> 3.005
# [30 Valid ] Loss ==> 0.318 Acc ==> 3.154 F1 ==> 3.154
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.098 Acc ==> 1.332 F1 ==> 1.332
# [1 Valid ] Loss ==> 3.928 Acc ==> 1.764 F1 ==> 1.764
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.796 Acc ==> 1.772 F1 ==> 1.772
# [2 Valid ] Loss ==> 3.224 Acc ==> 2.016 F1 ==> 2.016
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.340 Acc ==> 1.948 F1 ==> 1.948
# [3 Valid ] Loss ==> 2.854 Acc ==> 2.165 F1 ==> 2.165
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.018 Acc ==> 2.084 F1 ==> 2.084
# [4 Valid ] Loss ==> 2.541 Acc ==> 2.316 F1 ==> 2.316
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.778 Acc ==> 2.203 F1 ==> 2.203
# [5 Valid ] Loss ==> 2.336 Acc ==> 2.384 F1 ==> 2.384
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.642 Acc ==> 2.242 F1 ==> 2.242
# [6 Valid ] Loss ==> 2.107 Acc ==> 2.488 F1 ==> 2.488
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.409 Acc ==> 2.321 F1 ==> 2.321
# [7 Valid ] Loss ==> 1.928 Acc ==> 2.550 F1 ==> 2.550
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.248 Acc ==> 2.404 F1 ==> 2.404
# [8 Valid ] Loss ==> 1.871 Acc ==> 2.573 F1 ==> 2.573
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.125 Acc ==> 2.450 F1 ==> 2.450
# [9 Valid ] Loss ==> 1.625 Acc ==> 2.660 F1 ==> 2.660
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.934 Acc ==> 2.522 F1 ==> 2.522
# [10 Valid ] Loss ==> 1.483 Acc ==> 2.734 F1 ==> 2.734
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.789 Acc ==> 2.573 F1 ==> 2.573
# [11 Valid ] Loss ==> 1.477 Acc ==> 2.718 F1 ==> 2.718
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.784 Acc ==> 2.590 F1 ==> 2.590
# [12 Valid ] Loss ==> 1.276 Acc ==> 2.829 F1 ==> 2.829
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.605 Acc ==> 2.645 F1 ==> 2.645
# [13 Valid ] Loss ==> 1.049 Acc ==> 2.903 F1 ==> 2.903
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.576 Acc ==> 2.656 F1 ==> 2.656
# [14 Valid ] Loss ==> 1.018 Acc ==> 2.915 F1 ==> 2.915
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.415 Acc ==> 2.712 F1 ==> 2.712
# [15 Valid ] Loss ==> 1.021 Acc ==> 2.888 F1 ==> 2.888
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.376 Acc ==> 2.734 F1 ==> 2.734
# [16 Valid ] Loss ==> 0.858 Acc ==> 2.966 F1 ==> 2.966
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.316 Acc ==> 2.752 F1 ==> 2.752
# [17 Valid ] Loss ==> 0.821 Acc ==> 2.966 F1 ==> 2.966
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.177 Acc ==> 2.808 F1 ==> 2.808
# [18 Valid ] Loss ==> 0.812 Acc ==> 2.972 F1 ==> 2.972
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.141 Acc ==> 2.831 F1 ==> 2.831
# [19 Valid ] Loss ==> 0.708 Acc ==> 3.013 F1 ==> 3.013
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.075 Acc ==> 2.844 F1 ==> 2.844
# [20 Valid ] Loss ==> 0.702 Acc ==> 3.015 F1 ==> 3.015
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.057 Acc ==> 2.855 F1 ==> 2.855
# [21 Valid ] Loss ==> 0.758 Acc ==> 2.983 F1 ==> 2.983
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.954 Acc ==> 2.906 F1 ==> 2.906
# [22 Valid ] Loss ==> 0.664 Acc ==> 3.017 F1 ==> 3.017
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.926 Acc ==> 2.907 F1 ==> 2.907
# [23 Valid ] Loss ==> 0.586 Acc ==> 3.060 F1 ==> 3.060
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.870 Acc ==> 2.924 F1 ==> 2.924
# [24 Valid ] Loss ==> 0.504 Acc ==> 3.084 F1 ==> 3.084
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.866 Acc ==> 2.929 F1 ==> 2.929
# [25 Valid ] Loss ==> 0.540 Acc ==> 3.054 F1 ==> 3.054
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.770 Acc ==> 2.952 F1 ==> 2.952
# [26 Valid ] Loss ==> 0.492 Acc ==> 3.084 F1 ==> 3.084
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.870 Acc ==> 2.928 F1 ==> 2.928
# [27 Valid ] Loss ==> 0.574 Acc ==> 3.044 F1 ==> 3.044
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.729 Acc ==> 2.987 F1 ==> 2.987
# [28 Valid ] Loss ==> 0.430 Acc ==> 3.108 F1 ==> 3.108
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.723 Acc ==> 2.978 F1 ==> 2.978
# [29 Valid ] Loss ==> 0.378 Acc ==> 3.129 F1 ==> 3.129
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.778 Acc ==> 2.968 F1 ==> 2.968
# [30 Valid ] Loss ==> 0.428 Acc ==> 3.102 F1 ==> 3.102
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.856 Acc ==> 1.342 F1 ==> 1.342
# [1 Valid ] Loss ==> 3.761 Acc ==> 1.794 F1 ==> 1.794
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.775 Acc ==> 1.778 F1 ==> 1.778
# [2 Valid ] Loss ==> 3.220 Acc ==> 2.028 F1 ==> 2.028
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.410 Acc ==> 1.916 F1 ==> 1.916
# [3 Valid ] Loss ==> 2.871 Acc ==> 2.186 F1 ==> 2.186
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.036 Acc ==> 2.091 F1 ==> 2.091
# [4 Valid ] Loss ==> 2.528 Acc ==> 2.311 F1 ==> 2.311
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.911 Acc ==> 2.131 F1 ==> 2.131
# [5 Valid ] Loss ==> 2.355 Acc ==> 2.392 F1 ==> 2.392
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.676 Acc ==> 2.239 F1 ==> 2.239
# [6 Valid ] Loss ==> 2.236 Acc ==> 2.433 F1 ==> 2.433
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.505 Acc ==> 2.297 F1 ==> 2.297
# [7 Valid ] Loss ==> 2.017 Acc ==> 2.513 F1 ==> 2.513
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.334 Acc ==> 2.365 F1 ==> 2.365
# [8 Valid ] Loss ==> 1.710 Acc ==> 2.636 F1 ==> 2.636
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.177 Acc ==> 2.413 F1 ==> 2.413
# [9 Valid ] Loss ==> 1.579 Acc ==> 2.715 F1 ==> 2.715
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.059 Acc ==> 2.482 F1 ==> 2.482
# [10 Valid ] Loss ==> 1.613 Acc ==> 2.669 F1 ==> 2.669
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.969 Acc ==> 2.501 F1 ==> 2.501
# [11 Valid ] Loss ==> 1.381 Acc ==> 2.746 F1 ==> 2.746
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.797 Acc ==> 2.570 F1 ==> 2.570
# [12 Valid ] Loss ==> 1.232 Acc ==> 2.827 F1 ==> 2.827
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.700 Acc ==> 2.613 F1 ==> 2.613
# [13 Valid ] Loss ==> 1.368 Acc ==> 2.764 F1 ==> 2.764
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.645 Acc ==> 2.626 F1 ==> 2.626
# [14 Valid ] Loss ==> 1.129 Acc ==> 2.866 F1 ==> 2.866
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.607 Acc ==> 2.636 F1 ==> 2.636
# [15 Valid ] Loss ==> 1.012 Acc ==> 2.905 F1 ==> 2.905
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.475 Acc ==> 2.687 F1 ==> 2.687
# [16 Valid ] Loss ==> 0.869 Acc ==> 2.966 F1 ==> 2.966
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.433 Acc ==> 2.707 F1 ==> 2.707
# [17 Valid ] Loss ==> 0.824 Acc ==> 2.965 F1 ==> 2.965
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.340 Acc ==> 2.750 F1 ==> 2.750
# [18 Valid ] Loss ==> 0.791 Acc ==> 2.988 F1 ==> 2.988
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.249 Acc ==> 2.786 F1 ==> 2.786
# [19 Valid ] Loss ==> 0.968 Acc ==> 2.911 F1 ==> 2.911
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.282 Acc ==> 2.771 F1 ==> 2.771
# [20 Valid ] Loss ==> 0.814 Acc ==> 2.970 F1 ==> 2.970
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.130 Acc ==> 2.827 F1 ==> 2.827
# [21 Valid ] Loss ==> 0.611 Acc ==> 3.049 F1 ==> 3.049
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.007 Acc ==> 2.887 F1 ==> 2.887
# [22 Valid ] Loss ==> 0.605 Acc ==> 3.039 F1 ==> 3.039
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.024 Acc ==> 2.872 F1 ==> 2.872
# [23 Valid ] Loss ==> 0.531 Acc ==> 3.081 F1 ==> 3.081
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.018 Acc ==> 2.862 F1 ==> 2.862
# [24 Valid ] Loss ==> 0.573 Acc ==> 3.055 F1 ==> 3.055
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.942 Acc ==> 2.910 F1 ==> 2.910
# [25 Valid ] Loss ==> 0.639 Acc ==> 3.025 F1 ==> 3.025
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.988 Acc ==> 2.878 F1 ==> 2.878
# [26 Valid ] Loss ==> 0.530 Acc ==> 3.067 F1 ==> 3.067
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.915 Acc ==> 2.911 F1 ==> 2.911
# [27 Valid ] Loss ==> 0.416 Acc ==> 3.125 F1 ==> 3.125
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.839 Acc ==> 2.937 F1 ==> 2.937
# [28 Valid ] Loss ==> 0.390 Acc ==> 3.129 F1 ==> 3.129
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.826 Acc ==> 2.940 F1 ==> 2.940
# [29 Valid ] Loss ==> 0.367 Acc ==> 3.136 F1 ==> 3.136
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.868 Acc ==> 2.919 F1 ==> 2.919
# [30 Valid ] Loss ==> 0.401 Acc ==> 3.116 F1 ==> 3.116
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.651 Acc ==> 1.421 F1 ==> 1.421
# [1 Valid ] Loss ==> 3.532 Acc ==> 1.883 F1 ==> 1.883
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.661 Acc ==> 1.795 F1 ==> 1.795
# [2 Valid ] Loss ==> 3.039 Acc ==> 2.084 F1 ==> 2.084
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.317 Acc ==> 1.952 F1 ==> 1.952
# [3 Valid ] Loss ==> 2.766 Acc ==> 2.191 F1 ==> 2.191
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.040 Acc ==> 2.061 F1 ==> 2.061
# [4 Valid ] Loss ==> 2.439 Acc ==> 2.353 F1 ==> 2.353
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.855 Acc ==> 2.167 F1 ==> 2.167
# [5 Valid ] Loss ==> 2.212 Acc ==> 2.433 F1 ==> 2.433
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.670 Acc ==> 2.241 F1 ==> 2.241
# [6 Valid ] Loss ==> 2.040 Acc ==> 2.529 F1 ==> 2.529
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.476 Acc ==> 2.321 F1 ==> 2.321
# [7 Valid ] Loss ==> 1.911 Acc ==> 2.554 F1 ==> 2.554
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.387 Acc ==> 2.361 F1 ==> 2.361
# [8 Valid ] Loss ==> 1.855 Acc ==> 2.591 F1 ==> 2.591
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.247 Acc ==> 2.413 F1 ==> 2.413
# [9 Valid ] Loss ==> 1.669 Acc ==> 2.657 F1 ==> 2.657
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.086 Acc ==> 2.444 F1 ==> 2.444
# [10 Valid ] Loss ==> 1.571 Acc ==> 2.659 F1 ==> 2.659
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.019 Acc ==> 2.501 F1 ==> 2.501
# [11 Valid ] Loss ==> 1.369 Acc ==> 2.766 F1 ==> 2.766
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.944 Acc ==> 2.533 F1 ==> 2.533
# [12 Valid ] Loss ==> 1.401 Acc ==> 2.757 F1 ==> 2.757
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.807 Acc ==> 2.576 F1 ==> 2.576
# [13 Valid ] Loss ==> 1.275 Acc ==> 2.789 F1 ==> 2.789
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.762 Acc ==> 2.586 F1 ==> 2.586
# [14 Valid ] Loss ==> 1.217 Acc ==> 2.802 F1 ==> 2.802
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.612 Acc ==> 2.644 F1 ==> 2.644
# [15 Valid ] Loss ==> 1.154 Acc ==> 2.834 F1 ==> 2.834
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.561 Acc ==> 2.673 F1 ==> 2.673
# [16 Valid ] Loss ==> 0.950 Acc ==> 2.927 F1 ==> 2.927
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.447 Acc ==> 2.706 F1 ==> 2.706
# [17 Valid ] Loss ==> 0.892 Acc ==> 2.952 F1 ==> 2.952
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.423 Acc ==> 2.721 F1 ==> 2.721
# [18 Valid ] Loss ==> 1.131 Acc ==> 2.852 F1 ==> 2.852
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.465 Acc ==> 2.704 F1 ==> 2.704
# [19 Valid ] Loss ==> 1.038 Acc ==> 2.869 F1 ==> 2.869
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.282 Acc ==> 2.778 F1 ==> 2.778
# [20 Valid ] Loss ==> 0.740 Acc ==> 3.003 F1 ==> 3.003
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.206 Acc ==> 2.796 F1 ==> 2.796
# [21 Valid ] Loss ==> 0.670 Acc ==> 3.033 F1 ==> 3.033
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.293 Acc ==> 2.760 F1 ==> 2.760
# [22 Valid ] Loss ==> 0.674 Acc ==> 3.026 F1 ==> 3.026
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.202 Acc ==> 2.793 F1 ==> 2.793
# [23 Valid ] Loss ==> 0.607 Acc ==> 3.054 F1 ==> 3.054
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.126 Acc ==> 2.828 F1 ==> 2.828
# [24 Valid ] Loss ==> 0.747 Acc ==> 3.005 F1 ==> 3.005
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.036 Acc ==> 2.860 F1 ==> 2.860
# [25 Valid ] Loss ==> 0.570 Acc ==> 3.054 F1 ==> 3.054
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.058 Acc ==> 2.852 F1 ==> 2.852
# [26 Valid ] Loss ==> 0.651 Acc ==> 3.026 F1 ==> 3.026
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.072 Acc ==> 2.839 F1 ==> 2.839
# [27 Valid ] Loss ==> 0.571 Acc ==> 3.052 F1 ==> 3.052
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.975 Acc ==> 2.879 F1 ==> 2.879
# [28 Valid ] Loss ==> 0.515 Acc ==> 3.081 F1 ==> 3.081
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.968 Acc ==> 2.890 F1 ==> 2.890
# [29 Valid ] Loss ==> 0.609 Acc ==> 3.035 F1 ==> 3.035
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.946 Acc ==> 2.895 F1 ==> 2.895
# [30 Valid ] Loss ==> 0.447 Acc ==> 3.102 F1 ==> 3.102
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.590 Acc ==> 1.422 F1 ==> 1.422
# [1 Valid ] Loss ==> 3.459 Acc ==> 1.875 F1 ==> 1.875
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.732 Acc ==> 1.778 F1 ==> 1.778
# [2 Valid ] Loss ==> 3.153 Acc ==> 1.984 F1 ==> 1.984
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.370 Acc ==> 1.944 F1 ==> 1.944
# [3 Valid ] Loss ==> 2.676 Acc ==> 2.233 F1 ==> 2.233
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.131 Acc ==> 2.066 F1 ==> 2.066
# [4 Valid ] Loss ==> 2.519 Acc ==> 2.276 F1 ==> 2.276
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.015 Acc ==> 2.110 F1 ==> 2.110
# [5 Valid ] Loss ==> 2.482 Acc ==> 2.308 F1 ==> 2.308
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.819 Acc ==> 2.186 F1 ==> 2.186
# [6 Valid ] Loss ==> 2.213 Acc ==> 2.401 F1 ==> 2.401
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.614 Acc ==> 2.241 F1 ==> 2.241
# [7 Valid ] Loss ==> 2.049 Acc ==> 2.480 F1 ==> 2.480
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.552 Acc ==> 2.280 F1 ==> 2.280
# [8 Valid ] Loss ==> 2.046 Acc ==> 2.488 F1 ==> 2.488
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.384 Acc ==> 2.346 F1 ==> 2.346
# [9 Valid ] Loss ==> 1.731 Acc ==> 2.624 F1 ==> 2.624
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.279 Acc ==> 2.397 F1 ==> 2.397
# [10 Valid ] Loss ==> 1.609 Acc ==> 2.670 F1 ==> 2.670
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.148 Acc ==> 2.441 F1 ==> 2.441
# [11 Valid ] Loss ==> 1.535 Acc ==> 2.690 F1 ==> 2.690
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.075 Acc ==> 2.460 F1 ==> 2.460
# [12 Valid ] Loss ==> 1.384 Acc ==> 2.764 F1 ==> 2.764
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.988 Acc ==> 2.501 F1 ==> 2.501
# [13 Valid ] Loss ==> 1.264 Acc ==> 2.803 F1 ==> 2.803
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.899 Acc ==> 2.533 F1 ==> 2.533
# [14 Valid ] Loss ==> 1.241 Acc ==> 2.808 F1 ==> 2.808
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.903 Acc ==> 2.534 F1 ==> 2.534
# [15 Valid ] Loss ==> 1.283 Acc ==> 2.776 F1 ==> 2.776
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.742 Acc ==> 2.600 F1 ==> 2.600
# [16 Valid ] Loss ==> 1.180 Acc ==> 2.821 F1 ==> 2.821
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.704 Acc ==> 2.615 F1 ==> 2.615
# [17 Valid ] Loss ==> 1.064 Acc ==> 2.858 F1 ==> 2.858
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.597 Acc ==> 2.651 F1 ==> 2.651
# [18 Valid ] Loss ==> 1.056 Acc ==> 2.872 F1 ==> 2.872
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.555 Acc ==> 2.673 F1 ==> 2.673
# [19 Valid ] Loss ==> 1.054 Acc ==> 2.865 F1 ==> 2.865
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.530 Acc ==> 2.688 F1 ==> 2.688
# [20 Valid ] Loss ==> 0.838 Acc ==> 2.956 F1 ==> 2.956
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.492 Acc ==> 2.692 F1 ==> 2.692
# [21 Valid ] Loss ==> 0.902 Acc ==> 2.934 F1 ==> 2.934
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.401 Acc ==> 2.722 F1 ==> 2.722
# [22 Valid ] Loss ==> 0.845 Acc ==> 2.960 F1 ==> 2.960
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.379 Acc ==> 2.737 F1 ==> 2.737
# [23 Valid ] Loss ==> 0.756 Acc ==> 2.988 F1 ==> 2.988
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.267 Acc ==> 2.781 F1 ==> 2.781
# [24 Valid ] Loss ==> 0.689 Acc ==> 3.025 F1 ==> 3.025
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.310 Acc ==> 2.753 F1 ==> 2.753
# [25 Valid ] Loss ==> 0.712 Acc ==> 3.004 F1 ==> 3.004
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.299 Acc ==> 2.763 F1 ==> 2.763
# [26 Valid ] Loss ==> 0.701 Acc ==> 3.012 F1 ==> 3.012
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.226 Acc ==> 2.790 F1 ==> 2.790
# [27 Valid ] Loss ==> 0.549 Acc ==> 3.077 F1 ==> 3.077
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.115 Acc ==> 2.838 F1 ==> 2.838
# [28 Valid ] Loss ==> 0.608 Acc ==> 3.030 F1 ==> 3.030
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.135 Acc ==> 2.820 F1 ==> 2.820
# [29 Valid ] Loss ==> 0.707 Acc ==> 2.988 F1 ==> 2.988
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.082 Acc ==> 2.840 F1 ==> 2.840
# [30 Valid ] Loss ==> 0.629 Acc ==> 3.026 F1 ==> 3.026
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.804 Acc ==> 1.338 F1 ==> 1.338
# [1 Valid ] Loss ==> 3.584 Acc ==> 1.818 F1 ==> 1.818
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.897 Acc ==> 1.732 F1 ==> 1.732
# [2 Valid ] Loss ==> 3.365 Acc ==> 1.924 F1 ==> 1.924
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.523 Acc ==> 1.885 F1 ==> 1.885
# [3 Valid ] Loss ==> 2.973 Acc ==> 2.153 F1 ==> 2.153
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.294 Acc ==> 1.965 F1 ==> 1.965
# [4 Valid ] Loss ==> 2.521 Acc ==> 2.266 F1 ==> 2.266
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.034 Acc ==> 2.083 F1 ==> 2.083
# [5 Valid ] Loss ==> 2.435 Acc ==> 2.299 F1 ==> 2.299
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.852 Acc ==> 2.139 F1 ==> 2.139
# [6 Valid ] Loss ==> 2.324 Acc ==> 2.392 F1 ==> 2.392
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.693 Acc ==> 2.226 F1 ==> 2.226
# [7 Valid ] Loss ==> 2.080 Acc ==> 2.461 F1 ==> 2.461
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.613 Acc ==> 2.252 F1 ==> 2.252
# [8 Valid ] Loss ==> 1.820 Acc ==> 2.580 F1 ==> 2.580
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.425 Acc ==> 2.341 F1 ==> 2.341
# [9 Valid ] Loss ==> 1.760 Acc ==> 2.606 F1 ==> 2.606
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.321 Acc ==> 2.370 F1 ==> 2.370
# [10 Valid ] Loss ==> 1.597 Acc ==> 2.677 F1 ==> 2.677
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.194 Acc ==> 2.419 F1 ==> 2.419
# [11 Valid ] Loss ==> 1.579 Acc ==> 2.658 F1 ==> 2.658
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.134 Acc ==> 2.456 F1 ==> 2.456
# [12 Valid ] Loss ==> 1.528 Acc ==> 2.697 F1 ==> 2.697
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 2.032 Acc ==> 2.492 F1 ==> 2.492
# [13 Valid ] Loss ==> 1.420 Acc ==> 2.743 F1 ==> 2.743
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.928 Acc ==> 2.530 F1 ==> 2.530
# [14 Valid ] Loss ==> 1.453 Acc ==> 2.719 F1 ==> 2.719
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.859 Acc ==> 2.552 F1 ==> 2.552
# [15 Valid ] Loss ==> 1.233 Acc ==> 2.816 F1 ==> 2.816
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.778 Acc ==> 2.591 F1 ==> 2.591
# [16 Valid ] Loss ==> 1.256 Acc ==> 2.816 F1 ==> 2.816
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.763 Acc ==> 2.578 F1 ==> 2.578
# [17 Valid ] Loss ==> 1.095 Acc ==> 2.890 F1 ==> 2.890
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.650 Acc ==> 2.638 F1 ==> 2.638
# [18 Valid ] Loss ==> 1.082 Acc ==> 2.857 F1 ==> 2.857
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.619 Acc ==> 2.656 F1 ==> 2.656
# [19 Valid ] Loss ==> 0.952 Acc ==> 2.921 F1 ==> 2.921
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.532 Acc ==> 2.672 F1 ==> 2.672
# [20 Valid ] Loss ==> 0.964 Acc ==> 2.928 F1 ==> 2.928
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.488 Acc ==> 2.699 F1 ==> 2.699
# [21 Valid ] Loss ==> 0.920 Acc ==> 2.928 F1 ==> 2.928
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.434 Acc ==> 2.716 F1 ==> 2.716
# [22 Valid ] Loss ==> 0.726 Acc ==> 3.000 F1 ==> 3.000
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.357 Acc ==> 2.738 F1 ==> 2.738
# [23 Valid ] Loss ==> 0.795 Acc ==> 2.967 F1 ==> 2.967
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.304 Acc ==> 2.765 F1 ==> 2.765
# [24 Valid ] Loss ==> 0.764 Acc ==> 2.986 F1 ==> 2.986
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.271 Acc ==> 2.771 F1 ==> 2.771
# [25 Valid ] Loss ==> 0.708 Acc ==> 3.006 F1 ==> 3.006
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.272 Acc ==> 2.776 F1 ==> 2.776
# [26 Valid ] Loss ==> 0.662 Acc ==> 3.012 F1 ==> 3.012
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.299 Acc ==> 2.772 F1 ==> 2.772
# [27 Valid ] Loss ==> 0.751 Acc ==> 2.990 F1 ==> 2.990
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.169 Acc ==> 2.829 F1 ==> 2.829
# [28 Valid ] Loss ==> 0.563 Acc ==> 3.063 F1 ==> 3.063
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.148 Acc ==> 2.836 F1 ==> 2.836
# [29 Valid ] Loss ==> 0.537 Acc ==> 3.080 F1 ==> 3.080
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.098 Acc ==> 2.845 F1 ==> 2.845
# [30 Valid ] Loss ==> 0.592 Acc ==> 3.042 F1 ==> 3.042
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 감소

# %%
layer_list2 = [[2**(10-j) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list2:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)
    
    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model1/my_model2.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.015 Acc ==> 1.666 F1 ==> 1.666
# [1 Valid ] Loss ==> 2.942 Acc ==> 2.113 F1 ==> 2.113
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.039 Acc ==> 2.073 F1 ==> 2.073
# [2 Valid ] Loss ==> 2.428 Acc ==> 2.309 F1 ==> 2.309
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.508 Acc ==> 2.288 F1 ==> 2.288
# [3 Valid ] Loss ==> 1.864 Acc ==> 2.583 F1 ==> 2.583
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.094 Acc ==> 2.474 F1 ==> 2.474
# [4 Valid ] Loss ==> 1.536 Acc ==> 2.706 F1 ==> 2.706
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.709 Acc ==> 2.619 F1 ==> 2.619
# [5 Valid ] Loss ==> 1.287 Acc ==> 2.807 F1 ==> 2.807
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.410 Acc ==> 2.734 F1 ==> 2.734
# [6 Valid ] Loss ==> 0.962 Acc ==> 2.944 F1 ==> 2.944
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.159 Acc ==> 2.840 F1 ==> 2.840
# [7 Valid ] Loss ==> 0.797 Acc ==> 2.992 F1 ==> 2.992
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 0.993 Acc ==> 2.894 F1 ==> 2.894
# [8 Valid ] Loss ==> 0.907 Acc ==> 2.938 F1 ==> 2.938
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.800 Acc ==> 2.966 F1 ==> 2.966
# [9 Valid ] Loss ==> 0.636 Acc ==> 3.042 F1 ==> 3.042
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.633 Acc ==> 3.030 F1 ==> 3.030
# [10 Valid ] Loss ==> 0.362 Acc ==> 3.157 F1 ==> 3.157
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.519 Acc ==> 3.078 F1 ==> 3.078
# [11 Valid ] Loss ==> 0.328 Acc ==> 3.156 F1 ==> 3.156
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.419 Acc ==> 3.110 F1 ==> 3.110
# [12 Valid ] Loss ==> 0.501 Acc ==> 3.070 F1 ==> 3.070
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.413 Acc ==> 3.110 F1 ==> 3.110
# [13 Valid ] Loss ==> 0.272 Acc ==> 3.166 F1 ==> 3.166
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.328 Acc ==> 3.148 F1 ==> 3.148
# [14 Valid ] Loss ==> 0.179 Acc ==> 3.201 F1 ==> 3.201
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.271 Acc ==> 3.161 F1 ==> 3.161
# [15 Valid ] Loss ==> 0.194 Acc ==> 3.199 F1 ==> 3.199
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.269 Acc ==> 3.162 F1 ==> 3.162
# [16 Valid ] Loss ==> 0.419 Acc ==> 3.105 F1 ==> 3.105
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.308 Acc ==> 3.148 F1 ==> 3.148
# [17 Valid ] Loss ==> 0.217 Acc ==> 3.175 F1 ==> 3.175
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.272 Acc ==> 3.149 F1 ==> 3.149
# [18 Valid ] Loss ==> 0.121 Acc ==> 3.211 F1 ==> 3.211
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.216 Acc ==> 3.184 F1 ==> 3.184
# [19 Valid ] Loss ==> 0.100 Acc ==> 3.223 F1 ==> 3.223
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.207 Acc ==> 3.181 F1 ==> 3.181
# [20 Valid ] Loss ==> 0.138 Acc ==> 3.199 F1 ==> 3.199
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.165 Acc ==> 3.193 F1 ==> 3.193
# [21 Valid ] Loss ==> 0.136 Acc ==> 3.200 F1 ==> 3.200
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.155 Acc ==> 3.200 F1 ==> 3.200
# [22 Valid ] Loss ==> 0.142 Acc ==> 3.209 F1 ==> 3.209
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.150 Acc ==> 3.197 F1 ==> 3.197
# [23 Valid ] Loss ==> 0.102 Acc ==> 3.215 F1 ==> 3.215
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.203 Acc ==> 3.182 F1 ==> 3.182
# [24 Valid ] Loss ==> 0.129 Acc ==> 3.202 F1 ==> 3.202
#
# Early stopping at epoch 23
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.034 Acc ==> 1.672 F1 ==> 1.672
# [1 Valid ] Loss ==> 3.025 Acc ==> 2.061 F1 ==> 2.061
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.121 Acc ==> 2.044 F1 ==> 2.044
# [2 Valid ] Loss ==> 2.314 Acc ==> 2.381 F1 ==> 2.381
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.525 Acc ==> 2.298 F1 ==> 2.298
# [3 Valid ] Loss ==> 1.946 Acc ==> 2.525 F1 ==> 2.525
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.096 Acc ==> 2.443 F1 ==> 2.443
# [4 Valid ] Loss ==> 1.523 Acc ==> 2.699 F1 ==> 2.699
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.652 Acc ==> 2.623 F1 ==> 2.623
# [5 Valid ] Loss ==> 1.152 Acc ==> 2.856 F1 ==> 2.856
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.446 Acc ==> 2.700 F1 ==> 2.700
# [6 Valid ] Loss ==> 0.973 Acc ==> 2.902 F1 ==> 2.902
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.164 Acc ==> 2.800 F1 ==> 2.800
# [7 Valid ] Loss ==> 0.761 Acc ==> 2.986 F1 ==> 2.986
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.015 Acc ==> 2.872 F1 ==> 2.872
# [8 Valid ] Loss ==> 0.607 Acc ==> 3.040 F1 ==> 3.040
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.725 Acc ==> 2.987 F1 ==> 2.987
# [9 Valid ] Loss ==> 0.490 Acc ==> 3.087 F1 ==> 3.087
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.694 Acc ==> 2.988 F1 ==> 2.988
# [10 Valid ] Loss ==> 0.621 Acc ==> 3.012 F1 ==> 3.012
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.617 Acc ==> 3.008 F1 ==> 3.008
# [11 Valid ] Loss ==> 0.377 Acc ==> 3.125 F1 ==> 3.125
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.524 Acc ==> 3.045 F1 ==> 3.045
# [12 Valid ] Loss ==> 0.351 Acc ==> 3.125 F1 ==> 3.125
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.381 Acc ==> 3.109 F1 ==> 3.109
# [13 Valid ] Loss ==> 0.204 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.360 Acc ==> 3.121 F1 ==> 3.121
# [14 Valid ] Loss ==> 0.269 Acc ==> 3.146 F1 ==> 3.146
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.305 Acc ==> 3.145 F1 ==> 3.145
# [15 Valid ] Loss ==> 0.136 Acc ==> 3.203 F1 ==> 3.203
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.322 Acc ==> 3.136 F1 ==> 3.136
# [16 Valid ] Loss ==> 0.141 Acc ==> 3.202 F1 ==> 3.202
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.359 Acc ==> 3.116 F1 ==> 3.116
# [17 Valid ] Loss ==> 0.136 Acc ==> 3.201 F1 ==> 3.201
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.306 Acc ==> 3.126 F1 ==> 3.126
# [18 Valid ] Loss ==> 0.144 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.275 Acc ==> 3.145 F1 ==> 3.145
# [19 Valid ] Loss ==> 0.130 Acc ==> 3.199 F1 ==> 3.199
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.280 Acc ==> 3.140 F1 ==> 3.140
# [20 Valid ] Loss ==> 0.110 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.222 Acc ==> 3.164 F1 ==> 3.164
# [21 Valid ] Loss ==> 0.080 Acc ==> 3.220 F1 ==> 3.220
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.194 Acc ==> 3.177 F1 ==> 3.177
# [22 Valid ] Loss ==> 0.095 Acc ==> 3.214 F1 ==> 3.214
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.259 Acc ==> 3.149 F1 ==> 3.149
# [23 Valid ] Loss ==> 0.131 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.208 Acc ==> 3.172 F1 ==> 3.172
# [24 Valid ] Loss ==> 0.072 Acc ==> 3.217 F1 ==> 3.217
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.225 Acc ==> 3.161 F1 ==> 3.161
# [25 Valid ] Loss ==> 0.139 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.206 Acc ==> 3.162 F1 ==> 3.162
# [26 Valid ] Loss ==> 0.088 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.245 Acc ==> 3.153 F1 ==> 3.153
# [27 Valid ] Loss ==> 0.209 Acc ==> 3.174 F1 ==> 3.174
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.178 Acc ==> 3.182 F1 ==> 3.182
# [28 Valid ] Loss ==> 0.089 Acc ==> 3.212 F1 ==> 3.212
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.195 Acc ==> 3.177 F1 ==> 3.177
# [29 Valid ] Loss ==> 0.063 Acc ==> 3.219 F1 ==> 3.219
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.114 Acc ==> 3.206 F1 ==> 3.206
# [30 Valid ] Loss ==> 0.112 Acc ==> 3.204 F1 ==> 3.204
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.103 Acc ==> 1.626 F1 ==> 1.626
# [1 Valid ] Loss ==> 3.100 Acc ==> 2.044 F1 ==> 2.044
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.125 Acc ==> 2.051 F1 ==> 2.051
# [2 Valid ] Loss ==> 2.353 Acc ==> 2.394 F1 ==> 2.394
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.540 Acc ==> 2.288 F1 ==> 2.288
# [3 Valid ] Loss ==> 1.970 Acc ==> 2.541 F1 ==> 2.541
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.090 Acc ==> 2.476 F1 ==> 2.476
# [4 Valid ] Loss ==> 1.620 Acc ==> 2.650 F1 ==> 2.650
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.753 Acc ==> 2.594 F1 ==> 2.594
# [5 Valid ] Loss ==> 1.166 Acc ==> 2.840 F1 ==> 2.840
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.527 Acc ==> 2.678 F1 ==> 2.678
# [6 Valid ] Loss ==> 1.037 Acc ==> 2.872 F1 ==> 2.872
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.394 Acc ==> 2.724 F1 ==> 2.724
# [7 Valid ] Loss ==> 0.776 Acc ==> 2.990 F1 ==> 2.990
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.072 Acc ==> 2.847 F1 ==> 2.847
# [8 Valid ] Loss ==> 0.736 Acc ==> 2.993 F1 ==> 2.993
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.948 Acc ==> 2.881 F1 ==> 2.881
# [9 Valid ] Loss ==> 0.532 Acc ==> 3.068 F1 ==> 3.068
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.836 Acc ==> 2.922 F1 ==> 2.922
# [10 Valid ] Loss ==> 0.442 Acc ==> 3.106 F1 ==> 3.106
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.675 Acc ==> 2.996 F1 ==> 2.996
# [11 Valid ] Loss ==> 0.426 Acc ==> 3.097 F1 ==> 3.097
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.618 Acc ==> 3.009 F1 ==> 3.009
# [12 Valid ] Loss ==> 0.302 Acc ==> 3.139 F1 ==> 3.139
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.519 Acc ==> 3.054 F1 ==> 3.054
# [13 Valid ] Loss ==> 0.266 Acc ==> 3.156 F1 ==> 3.156
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.495 Acc ==> 3.073 F1 ==> 3.073
# [14 Valid ] Loss ==> 0.255 Acc ==> 3.161 F1 ==> 3.161
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.393 Acc ==> 3.103 F1 ==> 3.103
# [15 Valid ] Loss ==> 0.161 Acc ==> 3.190 F1 ==> 3.190
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.440 Acc ==> 3.085 F1 ==> 3.085
# [16 Valid ] Loss ==> 0.139 Acc ==> 3.199 F1 ==> 3.199
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.324 Acc ==> 3.128 F1 ==> 3.128
# [17 Valid ] Loss ==> 0.183 Acc ==> 3.181 F1 ==> 3.181
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.367 Acc ==> 3.114 F1 ==> 3.114
# [18 Valid ] Loss ==> 0.170 Acc ==> 3.186 F1 ==> 3.186
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.278 Acc ==> 3.137 F1 ==> 3.137
# [19 Valid ] Loss ==> 0.240 Acc ==> 3.159 F1 ==> 3.159
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.391 Acc ==> 3.106 F1 ==> 3.106
# [20 Valid ] Loss ==> 0.151 Acc ==> 3.191 F1 ==> 3.191
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.356 Acc ==> 3.119 F1 ==> 3.119
# [21 Valid ] Loss ==> 0.185 Acc ==> 3.184 F1 ==> 3.184
#
# Early stopping at epoch 20
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.214 Acc ==> 1.621 F1 ==> 1.621
# [1 Valid ] Loss ==> 3.167 Acc ==> 2.035 F1 ==> 2.035
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.257 Acc ==> 1.991 F1 ==> 1.991
# [2 Valid ] Loss ==> 2.566 Acc ==> 2.263 F1 ==> 2.263
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.739 Acc ==> 2.186 F1 ==> 2.186
# [3 Valid ] Loss ==> 2.184 Acc ==> 2.415 F1 ==> 2.415
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.338 Acc ==> 2.355 F1 ==> 2.355
# [4 Valid ] Loss ==> 1.757 Acc ==> 2.603 F1 ==> 2.603
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.982 Acc ==> 2.505 F1 ==> 2.505
# [5 Valid ] Loss ==> 1.404 Acc ==> 2.743 F1 ==> 2.743
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.690 Acc ==> 2.618 F1 ==> 2.618
# [6 Valid ] Loss ==> 1.037 Acc ==> 2.884 F1 ==> 2.884
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.423 Acc ==> 2.714 F1 ==> 2.714
# [7 Valid ] Loss ==> 0.908 Acc ==> 2.951 F1 ==> 2.951
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.200 Acc ==> 2.800 F1 ==> 2.800
# [8 Valid ] Loss ==> 0.731 Acc ==> 3.006 F1 ==> 3.006
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.117 Acc ==> 2.840 F1 ==> 2.840
# [9 Valid ] Loss ==> 0.621 Acc ==> 3.043 F1 ==> 3.043
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.955 Acc ==> 2.888 F1 ==> 2.888
# [10 Valid ] Loss ==> 0.696 Acc ==> 2.992 F1 ==> 2.992
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.859 Acc ==> 2.940 F1 ==> 2.940
# [11 Valid ] Loss ==> 0.462 Acc ==> 3.096 F1 ==> 3.096
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.727 Acc ==> 2.979 F1 ==> 2.979
# [12 Valid ] Loss ==> 0.405 Acc ==> 3.120 F1 ==> 3.120
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.687 Acc ==> 2.992 F1 ==> 2.992
# [13 Valid ] Loss ==> 0.330 Acc ==> 3.137 F1 ==> 3.137
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.597 Acc ==> 3.029 F1 ==> 3.029
# [14 Valid ] Loss ==> 0.227 Acc ==> 3.168 F1 ==> 3.168
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.576 Acc ==> 3.041 F1 ==> 3.041
# [15 Valid ] Loss ==> 0.318 Acc ==> 3.130 F1 ==> 3.130
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.472 Acc ==> 3.077 F1 ==> 3.077
# [16 Valid ] Loss ==> 0.251 Acc ==> 3.157 F1 ==> 3.157
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.366 Acc ==> 3.112 F1 ==> 3.112
# [17 Valid ] Loss ==> 0.195 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.475 Acc ==> 3.070 F1 ==> 3.070
# [18 Valid ] Loss ==> 0.219 Acc ==> 3.162 F1 ==> 3.162
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.434 Acc ==> 3.090 F1 ==> 3.090
# [19 Valid ] Loss ==> 0.146 Acc ==> 3.195 F1 ==> 3.195
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.337 Acc ==> 3.120 F1 ==> 3.120
# [20 Valid ] Loss ==> 0.174 Acc ==> 3.186 F1 ==> 3.186
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.272 Acc ==> 3.147 F1 ==> 3.147
# [21 Valid ] Loss ==> 0.134 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.328 Acc ==> 3.130 F1 ==> 3.130
# [22 Valid ] Loss ==> 0.108 Acc ==> 3.208 F1 ==> 3.208
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.337 Acc ==> 3.131 F1 ==> 3.131
# [23 Valid ] Loss ==> 0.100 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.300 Acc ==> 3.137 F1 ==> 3.137
# [24 Valid ] Loss ==> 0.179 Acc ==> 3.182 F1 ==> 3.182
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.363 Acc ==> 3.119 F1 ==> 3.119
# [25 Valid ] Loss ==> 0.125 Acc ==> 3.204 F1 ==> 3.204
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.282 Acc ==> 3.145 F1 ==> 3.145
# [26 Valid ] Loss ==> 0.160 Acc ==> 3.191 F1 ==> 3.191
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.314 Acc ==> 3.127 F1 ==> 3.127
# [27 Valid ] Loss ==> 0.167 Acc ==> 3.189 F1 ==> 3.189
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.216 Acc ==> 3.168 F1 ==> 3.168
# [28 Valid ] Loss ==> 0.082 Acc ==> 3.213 F1 ==> 3.213
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.179 Acc ==> 3.180 F1 ==> 3.180
# [29 Valid ] Loss ==> 0.090 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.294 Acc ==> 3.145 F1 ==> 3.145
# [30 Valid ] Loss ==> 0.119 Acc ==> 3.202 F1 ==> 3.202
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.457 Acc ==> 1.566 F1 ==> 1.566
# [1 Valid ] Loss ==> 3.357 Acc ==> 1.974 F1 ==> 1.974
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.470 Acc ==> 1.936 F1 ==> 1.936
# [2 Valid ] Loss ==> 2.804 Acc ==> 2.196 F1 ==> 2.196
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.909 Acc ==> 2.143 F1 ==> 2.143
# [3 Valid ] Loss ==> 2.348 Acc ==> 2.408 F1 ==> 2.408
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.482 Acc ==> 2.312 F1 ==> 2.312
# [4 Valid ] Loss ==> 1.817 Acc ==> 2.628 F1 ==> 2.628
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.180 Acc ==> 2.449 F1 ==> 2.449
# [5 Valid ] Loss ==> 1.514 Acc ==> 2.728 F1 ==> 2.728
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.892 Acc ==> 2.538 F1 ==> 2.538
# [6 Valid ] Loss ==> 1.250 Acc ==> 2.833 F1 ==> 2.833
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.639 Acc ==> 2.657 F1 ==> 2.657
# [7 Valid ] Loss ==> 1.088 Acc ==> 2.880 F1 ==> 2.880
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.426 Acc ==> 2.724 F1 ==> 2.724
# [8 Valid ] Loss ==> 0.972 Acc ==> 2.912 F1 ==> 2.912
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.330 Acc ==> 2.778 F1 ==> 2.778
# [9 Valid ] Loss ==> 0.843 Acc ==> 2.975 F1 ==> 2.975
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.155 Acc ==> 2.824 F1 ==> 2.824
# [10 Valid ] Loss ==> 0.791 Acc ==> 2.964 F1 ==> 2.964
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.997 Acc ==> 2.881 F1 ==> 2.881
# [11 Valid ] Loss ==> 0.576 Acc ==> 3.056 F1 ==> 3.056
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.943 Acc ==> 2.905 F1 ==> 2.905
# [12 Valid ] Loss ==> 0.650 Acc ==> 3.036 F1 ==> 3.036
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.814 Acc ==> 2.961 F1 ==> 2.961
# [13 Valid ] Loss ==> 0.419 Acc ==> 3.115 F1 ==> 3.115
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.718 Acc ==> 2.989 F1 ==> 2.989
# [14 Valid ] Loss ==> 0.305 Acc ==> 3.160 F1 ==> 3.160
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.593 Acc ==> 3.037 F1 ==> 3.037
# [15 Valid ] Loss ==> 0.286 Acc ==> 3.150 F1 ==> 3.150
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.569 Acc ==> 3.044 F1 ==> 3.044
# [16 Valid ] Loss ==> 0.321 Acc ==> 3.144 F1 ==> 3.144
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.585 Acc ==> 3.039 F1 ==> 3.039
# [17 Valid ] Loss ==> 0.323 Acc ==> 3.138 F1 ==> 3.138
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.544 Acc ==> 3.058 F1 ==> 3.058
# [18 Valid ] Loss ==> 0.230 Acc ==> 3.168 F1 ==> 3.168
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.477 Acc ==> 3.074 F1 ==> 3.074
# [19 Valid ] Loss ==> 0.183 Acc ==> 3.185 F1 ==> 3.185
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.416 Acc ==> 3.094 F1 ==> 3.094
# [20 Valid ] Loss ==> 0.162 Acc ==> 3.190 F1 ==> 3.190
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.368 Acc ==> 3.110 F1 ==> 3.110
# [21 Valid ] Loss ==> 0.128 Acc ==> 3.202 F1 ==> 3.202
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.400 Acc ==> 3.104 F1 ==> 3.104
# [22 Valid ] Loss ==> 0.187 Acc ==> 3.186 F1 ==> 3.186
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.409 Acc ==> 3.098 F1 ==> 3.098
# [23 Valid ] Loss ==> 0.208 Acc ==> 3.180 F1 ==> 3.180
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.374 Acc ==> 3.120 F1 ==> 3.120
# [24 Valid ] Loss ==> 0.216 Acc ==> 3.174 F1 ==> 3.174
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.378 Acc ==> 3.115 F1 ==> 3.115
# [25 Valid ] Loss ==> 0.143 Acc ==> 3.195 F1 ==> 3.195
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.337 Acc ==> 3.126 F1 ==> 3.126
# [26 Valid ] Loss ==> 0.151 Acc ==> 3.194 F1 ==> 3.194
#
# Early stopping at epoch 25
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.829 Acc ==> 1.518 F1 ==> 1.518
# [1 Valid ] Loss ==> 3.676 Acc ==> 1.888 F1 ==> 1.888
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.676 Acc ==> 1.888 F1 ==> 1.888
# [2 Valid ] Loss ==> 2.983 Acc ==> 2.143 F1 ==> 2.143
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.102 Acc ==> 2.097 F1 ==> 2.097
# [3 Valid ] Loss ==> 2.423 Acc ==> 2.406 F1 ==> 2.406
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.752 Acc ==> 2.243 F1 ==> 2.243
# [4 Valid ] Loss ==> 2.205 Acc ==> 2.449 F1 ==> 2.449
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.403 Acc ==> 2.370 F1 ==> 2.370
# [5 Valid ] Loss ==> 1.677 Acc ==> 2.694 F1 ==> 2.694
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.111 Acc ==> 2.480 F1 ==> 2.480
# [6 Valid ] Loss ==> 1.530 Acc ==> 2.729 F1 ==> 2.729
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.886 Acc ==> 2.572 F1 ==> 2.572
# [7 Valid ] Loss ==> 1.234 Acc ==> 2.842 F1 ==> 2.842
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.597 Acc ==> 2.667 F1 ==> 2.667
# [8 Valid ] Loss ==> 1.339 Acc ==> 2.779 F1 ==> 2.779
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.489 Acc ==> 2.711 F1 ==> 2.711
# [9 Valid ] Loss ==> 1.061 Acc ==> 2.892 F1 ==> 2.892
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.389 Acc ==> 2.748 F1 ==> 2.748
# [10 Valid ] Loss ==> 0.834 Acc ==> 2.966 F1 ==> 2.966
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.205 Acc ==> 2.820 F1 ==> 2.820
# [11 Valid ] Loss ==> 0.801 Acc ==> 2.994 F1 ==> 2.994
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.050 Acc ==> 2.877 F1 ==> 2.877
# [12 Valid ] Loss ==> 0.655 Acc ==> 3.031 F1 ==> 3.031
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.901 Acc ==> 2.932 F1 ==> 2.932
# [13 Valid ] Loss ==> 0.594 Acc ==> 3.052 F1 ==> 3.052
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.893 Acc ==> 2.928 F1 ==> 2.928
# [14 Valid ] Loss ==> 0.392 Acc ==> 3.135 F1 ==> 3.135
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.792 Acc ==> 2.972 F1 ==> 2.972
# [15 Valid ] Loss ==> 0.443 Acc ==> 3.110 F1 ==> 3.110
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.692 Acc ==> 3.001 F1 ==> 3.001
# [16 Valid ] Loss ==> 0.423 Acc ==> 3.101 F1 ==> 3.101
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.655 Acc ==> 3.018 F1 ==> 3.018
# [17 Valid ] Loss ==> 0.355 Acc ==> 3.131 F1 ==> 3.131
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.605 Acc ==> 3.038 F1 ==> 3.038
# [18 Valid ] Loss ==> 0.362 Acc ==> 3.120 F1 ==> 3.120
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.596 Acc ==> 3.041 F1 ==> 3.041
# [19 Valid ] Loss ==> 0.229 Acc ==> 3.179 F1 ==> 3.179
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.501 Acc ==> 3.072 F1 ==> 3.072
# [20 Valid ] Loss ==> 0.206 Acc ==> 3.185 F1 ==> 3.185
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.491 Acc ==> 3.069 F1 ==> 3.069
# [21 Valid ] Loss ==> 0.310 Acc ==> 3.136 F1 ==> 3.136
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.492 Acc ==> 3.080 F1 ==> 3.080
# [22 Valid ] Loss ==> 0.214 Acc ==> 3.182 F1 ==> 3.182
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.443 Acc ==> 3.096 F1 ==> 3.096
# [23 Valid ] Loss ==> 0.149 Acc ==> 3.200 F1 ==> 3.200
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.353 Acc ==> 3.122 F1 ==> 3.122
# [24 Valid ] Loss ==> 0.173 Acc ==> 3.187 F1 ==> 3.187
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.389 Acc ==> 3.106 F1 ==> 3.106
# [25 Valid ] Loss ==> 0.174 Acc ==> 3.192 F1 ==> 3.192
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.385 Acc ==> 3.111 F1 ==> 3.111
# [26 Valid ] Loss ==> 0.157 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.330 Acc ==> 3.123 F1 ==> 3.123
# [27 Valid ] Loss ==> 0.198 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.422 Acc ==> 3.097 F1 ==> 3.097
# [28 Valid ] Loss ==> 0.202 Acc ==> 3.170 F1 ==> 3.170
#
# Early stopping at epoch 27
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.581 Acc ==> 1.344 F1 ==> 1.344
# [1 Valid ] Loss ==> 4.329 Acc ==> 1.826 F1 ==> 1.826
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 4.202 Acc ==> 1.754 F1 ==> 1.754
# [2 Valid ] Loss ==> 3.411 Acc ==> 2.062 F1 ==> 2.062
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.488 Acc ==> 1.993 F1 ==> 1.993
# [3 Valid ] Loss ==> 2.829 Acc ==> 2.262 F1 ==> 2.262
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.098 Acc ==> 2.140 F1 ==> 2.140
# [4 Valid ] Loss ==> 2.378 Acc ==> 2.436 F1 ==> 2.436
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.698 Acc ==> 2.277 F1 ==> 2.277
# [5 Valid ] Loss ==> 2.058 Acc ==> 2.571 F1 ==> 2.571
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.456 Acc ==> 2.373 F1 ==> 2.373
# [6 Valid ] Loss ==> 1.826 Acc ==> 2.631 F1 ==> 2.631
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.142 Acc ==> 2.488 F1 ==> 2.488
# [7 Valid ] Loss ==> 1.632 Acc ==> 2.684 F1 ==> 2.684
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.956 Acc ==> 2.559 F1 ==> 2.559
# [8 Valid ] Loss ==> 1.592 Acc ==> 2.715 F1 ==> 2.715
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.773 Acc ==> 2.632 F1 ==> 2.632
# [9 Valid ] Loss ==> 1.287 Acc ==> 2.813 F1 ==> 2.813
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.547 Acc ==> 2.711 F1 ==> 2.711
# [10 Valid ] Loss ==> 1.123 Acc ==> 2.864 F1 ==> 2.864
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.423 Acc ==> 2.746 F1 ==> 2.746
# [11 Valid ] Loss ==> 0.864 Acc ==> 2.973 F1 ==> 2.973
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.284 Acc ==> 2.800 F1 ==> 2.800
# [12 Valid ] Loss ==> 0.804 Acc ==> 2.982 F1 ==> 2.982
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.187 Acc ==> 2.851 F1 ==> 2.851
# [13 Valid ] Loss ==> 0.668 Acc ==> 3.041 F1 ==> 3.041
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.068 Acc ==> 2.877 F1 ==> 2.877
# [14 Valid ] Loss ==> 0.540 Acc ==> 3.092 F1 ==> 3.092
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.987 Acc ==> 2.910 F1 ==> 2.910
# [15 Valid ] Loss ==> 0.642 Acc ==> 3.026 F1 ==> 3.026
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.883 Acc ==> 2.941 F1 ==> 2.941
# [16 Valid ] Loss ==> 0.488 Acc ==> 3.096 F1 ==> 3.096
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.799 Acc ==> 2.970 F1 ==> 2.970
# [17 Valid ] Loss ==> 0.381 Acc ==> 3.126 F1 ==> 3.126
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.741 Acc ==> 2.991 F1 ==> 2.991
# [18 Valid ] Loss ==> 0.392 Acc ==> 3.117 F1 ==> 3.117
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.737 Acc ==> 2.996 F1 ==> 2.996
# [19 Valid ] Loss ==> 0.526 Acc ==> 3.060 F1 ==> 3.060
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.654 Acc ==> 3.026 F1 ==> 3.026
# [20 Valid ] Loss ==> 0.312 Acc ==> 3.154 F1 ==> 3.154
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.594 Acc ==> 3.043 F1 ==> 3.043
# [21 Valid ] Loss ==> 0.362 Acc ==> 3.128 F1 ==> 3.128
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.580 Acc ==> 3.042 F1 ==> 3.042
# [22 Valid ] Loss ==> 0.213 Acc ==> 3.186 F1 ==> 3.186
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.506 Acc ==> 3.071 F1 ==> 3.071
# [23 Valid ] Loss ==> 0.287 Acc ==> 3.153 F1 ==> 3.153
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.498 Acc ==> 3.082 F1 ==> 3.082
# [24 Valid ] Loss ==> 0.269 Acc ==> 3.151 F1 ==> 3.151
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.507 Acc ==> 3.065 F1 ==> 3.065
# [25 Valid ] Loss ==> 0.199 Acc ==> 3.182 F1 ==> 3.182
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.464 Acc ==> 3.092 F1 ==> 3.092
# [26 Valid ] Loss ==> 0.238 Acc ==> 3.166 F1 ==> 3.166
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.414 Acc ==> 3.110 F1 ==> 3.110
# [27 Valid ] Loss ==> 0.202 Acc ==> 3.190 F1 ==> 3.190
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.430 Acc ==> 3.096 F1 ==> 3.096
# [28 Valid ] Loss ==> 0.189 Acc ==> 3.182 F1 ==> 3.182
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.401 Acc ==> 3.104 F1 ==> 3.104
# [29 Valid ] Loss ==> 0.116 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.374 Acc ==> 3.115 F1 ==> 3.115
# [30 Valid ] Loss ==> 0.151 Acc ==> 3.198 F1 ==> 3.198
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()
