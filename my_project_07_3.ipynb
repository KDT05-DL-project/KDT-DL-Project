# %%
# 모듈로딩
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn           
import torch.nn.functional as F 
import torch.optim as optim
import torchmetrics.functional as metrics
import torchmetrics.functional.classification as metrics
import sklearn.metrics as skm

from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split

# %%
featureDF = pd.read_pickle('./DATA/feature2.pkl')
targetDF = pd.read_pickle('./DATA/target2.pkl')

# %%
def plot_fish(image_data):
    image = image_data.reshape(45, 59)
    plt.imshow(image, cmap = 'binary')
    plt.axis('off')

some_fish = featureDF.iloc[0].values
plot_fish(some_fish)
plt.show()

# %%
some_fish.shape
# Out:
# (2655,)

# %%
# 학습을 위해 타겟 데이터를 시리즈로 변경
targetSR = targetDF.squeeze()
type(targetSR)
# Out:
# pandas.core.series.Series

# %%
# shape 확인
print(f'featureDF => {featureDF.shape}, targetSR => {targetSR.shape}')
# Out:
# featureDF => (9000, 2655), targetSR => (9000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(featureDF, targetSR, test_size = 90, random_state = 42, stratify = targetSR)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 810, random_state = 42, stratify = y_train)

# %%
# 데이터의 Tensor 변환
class DLDataset(Dataset):

    # 초기화 콜백 함수(callback function)
    def __init__(self, x_data, y_data):
        super().__init__()
        # x, y 데이터 => ndarray
        x_data = x_data.values if isinstance(x_data, pd.DataFrame) else x_data
        y_data = y_data.values if isinstance(y_data, pd.Series) else y_data

        # ndarray => tensor
        self.feature = torch.FloatTensor(x_data)
        self.target = torch.LongTensor(y_data)  # 타겟을 원핫인코딩하면 FloatTensor 사용
        print('[target & target shape]', self.target.shape, self.target.ndim)
    
    # 데이터셋의 개수 체크 콜백 함수(callback function)
    def __len__(self):
        return self.target.shape[0]
    
    # 특정 인덱스 데이터 + 라벨 반환 콜백 함수(callback function)
    def __getitem__(self, index):
        return self.feature[index], self.target[index]

# %%
trainDS = DLDataset(X_train, y_train)
validDS = DLDataset(X_val, y_val)
testDS = DLDataset(X_test, y_test)
# Out:
# [target & target shape] torch.Size([8100]) 1
# [target & target shape] torch.Size([810]) 1
# [target & target shape] torch.Size([90]) 1

# %%
validDS.feature.shape
# Out:
# torch.Size([810, 2655])

# %%
batch_size = 50
trainDL = DataLoader(trainDS, batch_size = batch_size, shuffle = True, drop_last = True)
validDL = DataLoader(validDS, batch_size = batch_size, shuffle = True, drop_last = True)
testDL = DataLoader(testDS, batch_size = batch_size, shuffle = True, drop_last = True)

# %%
len(trainDL), len(validDL), len(testDL)
# Out:
# (162, 16, 1)

# %%
# Epoch당 반복 단위
print(f'batch_size = {batch_size}')
print(f'trainDL => {len(trainDL)}개, validDL => {len(validDL)}개, testDL => {len(testDL)}개')
# Out:
# batch_size = 50
# trainDL => 162개, validDL => 16개, testDL => 1개

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
CLASSES = 9

# %%
# 모델 인스턴스
IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
print(f'IN : {IN_DIM}, OUT : {OUT_DIM}')
# Out:
# IN : 2655, OUT : 9

# %% [markdown]
# ### Dropout 미적용, Weight Initialization 적용 <hr>

# %% [markdown]
# #### He Initialization

# %%
class FishModel(nn.Module):
    
    # 모델 구성 요소 초기화 
    def __init__(self, in_dim, out_dim, nodes_list = []):
        super().__init__()
        nodes_list.insert(0, in_dim)
        nodes_list.append(out_dim)
        layer_num = len(nodes_list) - 1
        layers = []
        for i in range(layer_num):
            if i <= layer_num - 2:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))
                layers.append(nn.BatchNorm1d(num_features = nodes_list[i+1]))
                layers.append(nn.ReLU())
            else:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))
        
        self.layers = nn.ModuleList(layers)
        
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
m1 = FishModel(100, 9)
for _, modellist in m1.named_children():    
    for child in modellist:
        print(child)
        # if isinstance(child, nn.Linear):
        #     nn.init.kaiming_normal_(child.weight)
        #     break
        # break
# Out:
# Linear(in_features=100, out_features=9, bias=True)

# %%
### ===> 학습 진행함수 
def training(epoch):
    # 학습모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화 
    model.train()
    
    # 배치크기 만큼 학습 진행 및 저장
    train_report=[[], [], []]
    for idx, (feature, target)  in enumerate(trainDL):
        # 배치크기만큼의 학습 데이터 준비
        feature, target = feature.to(DEVICE), target.to(DEVICE)
        
        # 학습
        pre_traget = model(feature)
        
        # 손실계산
        loss = LOSS_FN(pre_traget, target)
        train_report[0].append(loss)
        
        # 성능 평가
        acc = metrics.accuracy(pre_traget, target, task='multiclass', num_classes = CLASSES)
        train_report[1].append(acc)
        
        f1 = metrics.f1_score(pre_traget, target, task='multiclass', num_classes = CLASSES)
        train_report[2].append(f1)
        
        # W,b업데이트
        OPTIMIZER.zero_grad()
        loss.backward()
        OPTIMIZER.step()
        
        if not idx%50: print('.', end='')
    
    # 에포크 단위로 학습 모델 저장
    # torch.save(model, './model/my_model.pt')
    
    # 에포크 단위 학습 진행 메시지 출력
    loss_score = (sum(train_report[0])/batch_size).item()
    acc_score = (sum(train_report[1])/batch_size).item()
    f1_score = (sum(train_report[2])/batch_size).item() 
    print(f'\n[{epoch+1} Train ] Loss ==> {loss_score:.3f} Acc ==> {acc_score:.3f} F1 ==> {f1_score:.3f}')
    
    return loss_score, acc_score, f1_score

# %%
### ===> 검증 및 테스트 진행함수 
def testing(epoch, kind='valid'):
    # 학습모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화 
    model.eval()
        
    with torch.no_grad():
        # 배치크기 만큼 학습 진행 및 저장
        test_report=[[], [], []]
        for idx, (feature, target) in enumerate(trainDL):
            # 배치크기만큼의 학습 데이터 준비
            feature, target = feature.to(DEVICE), target.to(DEVICE)

            # 학습
            pre_traget = model(feature)

            # 손실계산
            loss = LOSS_FN(pre_traget, target)
            test_report[0].append(loss)
            
            # 성능 평가 
            acc = metrics.accuracy(pre_traget, target, task='multiclass', num_classes = CLASSES)
            test_report[1].append(acc)
            
            f1 = metrics.f1_score(pre_traget, target, task='multiclass', num_classes = CLASSES)
            test_report[2].append(f1)
            
            #if not idx%50: print('.', end='')

    testing_type = 'Valid' if kind == 'valid' else 'Test'
        
    # 에포크 단위 학습 진행 메시지 출력
    loss_score = (sum(test_report[0])/batch_size).item()
    acc_score = (sum(test_report[1])/batch_size).item()
    f1_score = (sum(test_report[2])/batch_size).item() 
    print(f'[{epoch+1} {testing_type} ] Loss ==> {loss_score:.3f} Acc ==> {acc_score:.3f} F1 ==> {f1_score:.3f}\n')
    
    return loss_score, acc_score, f1_score

# %% [markdown]
# #### hidden layer 7개

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 증가

# %%
layer_list1 = [[2**(j+4) for j in range(i+1)] for i in range(7)]
layer_list1
# Out:
# [[16],
#  [16, 32],
#  [16, 32, 64],
#  [16, 32, 64, 128],
#  [16, 32, 64, 128, 256],
#  [16, 32, 64, 128, 256, 512],
#  [16, 32, 64, 128, 256, 512, 1024]]

# %%
layer_list1 = [[2**(j+4) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list1:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    for _, modelList in model.named_children():
        for child in modelList:
            if isinstance(child, nn.Linear):
                nn.init.kaiming_normal_(child.weight)
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)
    
    print(f'IN : {IN_DIM}, OUT : {OUT_DIM}')

    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model3/my_model1.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# IN : 2655, OUT : 9
# [Epoch 1/30] .
# ...
# [1 Train ] Loss ==> 5.585 Acc ==> 1.229 F1 ==> 1.229
# [1 Valid ] Loss ==> 4.579 Acc ==> 1.636 F1 ==> 1.636
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 4.354 Acc ==> 1.703 F1 ==> 1.703
# [2 Valid ] Loss ==> 3.819 Acc ==> 1.928 F1 ==> 1.928
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.773 Acc ==> 1.901 F1 ==> 1.901
# [3 Valid ] Loss ==> 3.378 Acc ==> 2.078 F1 ==> 2.078
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.420 Acc ==> 2.025 F1 ==> 2.025
# [4 Valid ] Loss ==> 3.089 Acc ==> 2.177 F1 ==> 2.177
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.150 Acc ==> 2.119 F1 ==> 2.119
# [5 Valid ] Loss ==> 2.800 Acc ==> 2.294 F1 ==> 2.294
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.927 Acc ==> 2.204 F1 ==> 2.204
# [6 Valid ] Loss ==> 2.565 Acc ==> 2.402 F1 ==> 2.402
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.704 Acc ==> 2.272 F1 ==> 2.272
# [7 Valid ] Loss ==> 2.325 Acc ==> 2.447 F1 ==> 2.447
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.496 Acc ==> 2.355 F1 ==> 2.355
# [8 Valid ] Loss ==> 2.262 Acc ==> 2.458 F1 ==> 2.458
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.348 Acc ==> 2.422 F1 ==> 2.422
# [9 Valid ] Loss ==> 2.059 Acc ==> 2.558 F1 ==> 2.558
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.170 Acc ==> 2.467 F1 ==> 2.467
# [10 Valid ] Loss ==> 1.849 Acc ==> 2.656 F1 ==> 2.656
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.054 Acc ==> 2.493 F1 ==> 2.493
# [11 Valid ] Loss ==> 1.836 Acc ==> 2.634 F1 ==> 2.634
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.865 Acc ==> 2.597 F1 ==> 2.597
# [12 Valid ] Loss ==> 1.515 Acc ==> 2.777 F1 ==> 2.777
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.779 Acc ==> 2.630 F1 ==> 2.630
# [13 Valid ] Loss ==> 1.638 Acc ==> 2.694 F1 ==> 2.694
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.643 Acc ==> 2.676 F1 ==> 2.676
# [14 Valid ] Loss ==> 1.362 Acc ==> 2.783 F1 ==> 2.783
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.543 Acc ==> 2.705 F1 ==> 2.705
# [15 Valid ] Loss ==> 1.191 Acc ==> 2.885 F1 ==> 2.885
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.429 Acc ==> 2.757 F1 ==> 2.757
# [16 Valid ] Loss ==> 1.091 Acc ==> 2.929 F1 ==> 2.929
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.295 Acc ==> 2.808 F1 ==> 2.808
# [17 Valid ] Loss ==> 1.059 Acc ==> 2.940 F1 ==> 2.940
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.241 Acc ==> 2.821 F1 ==> 2.821
# [18 Valid ] Loss ==> 1.090 Acc ==> 2.892 F1 ==> 2.892
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.178 Acc ==> 2.846 F1 ==> 2.846
# [19 Valid ] Loss ==> 0.932 Acc ==> 2.968 F1 ==> 2.968
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.091 Acc ==> 2.874 F1 ==> 2.874
# [20 Valid ] Loss ==> 0.887 Acc ==> 2.968 F1 ==> 2.968
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.041 Acc ==> 2.895 F1 ==> 2.895
# [21 Valid ] Loss ==> 0.771 Acc ==> 3.031 F1 ==> 3.031
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.920 Acc ==> 2.963 F1 ==> 2.963
# [22 Valid ] Loss ==> 0.797 Acc ==> 2.988 F1 ==> 2.988
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.866 Acc ==> 2.968 F1 ==> 2.968
# [23 Valid ] Loss ==> 0.734 Acc ==> 3.030 F1 ==> 3.030
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.882 Acc ==> 2.958 F1 ==> 2.958
# [24 Valid ] Loss ==> 0.683 Acc ==> 3.043 F1 ==> 3.043
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.828 Acc ==> 2.984 F1 ==> 2.984
# [25 Valid ] Loss ==> 0.782 Acc ==> 2.976 F1 ==> 2.976
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.806 Acc ==> 2.982 F1 ==> 2.982
# [26 Valid ] Loss ==> 0.627 Acc ==> 3.060 F1 ==> 3.060
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.711 Acc ==> 3.026 F1 ==> 3.026
# [27 Valid ] Loss ==> 0.536 Acc ==> 3.096 F1 ==> 3.096
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.679 Acc ==> 3.030 F1 ==> 3.030
# [28 Valid ] Loss ==> 0.501 Acc ==> 3.120 F1 ==> 3.120
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.663 Acc ==> 3.030 F1 ==> 3.030
# [29 Valid ] Loss ==> 0.534 Acc ==> 3.086 F1 ==> 3.086
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.650 Acc ==> 3.038 F1 ==> 3.038
# [30 Valid ] Loss ==> 0.607 Acc ==> 3.041 F1 ==> 3.041
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.042 Acc ==> 1.340 F1 ==> 1.340
# [1 Valid ] Loss ==> 4.092 Acc ==> 1.725 F1 ==> 1.725
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.977 Acc ==> 1.748 F1 ==> 1.748
# [2 Valid ] Loss ==> 3.483 Acc ==> 1.962 F1 ==> 1.962
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.511 Acc ==> 1.929 F1 ==> 1.929
# [3 Valid ] Loss ==> 3.055 Acc ==> 2.146 F1 ==> 2.146
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.240 Acc ==> 2.030 F1 ==> 2.030
# [4 Valid ] Loss ==> 2.780 Acc ==> 2.242 F1 ==> 2.242
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.997 Acc ==> 2.130 F1 ==> 2.130
# [5 Valid ] Loss ==> 2.528 Acc ==> 2.381 F1 ==> 2.381
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.780 Acc ==> 2.209 F1 ==> 2.209
# [6 Valid ] Loss ==> 2.354 Acc ==> 2.415 F1 ==> 2.415
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.568 Acc ==> 2.300 F1 ==> 2.300
# [7 Valid ] Loss ==> 2.152 Acc ==> 2.502 F1 ==> 2.502
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.389 Acc ==> 2.384 F1 ==> 2.384
# [8 Valid ] Loss ==> 1.956 Acc ==> 2.586 F1 ==> 2.586
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.275 Acc ==> 2.408 F1 ==> 2.408
# [9 Valid ] Loss ==> 1.798 Acc ==> 2.628 F1 ==> 2.628
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.055 Acc ==> 2.512 F1 ==> 2.512
# [10 Valid ] Loss ==> 1.588 Acc ==> 2.715 F1 ==> 2.715
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.985 Acc ==> 2.525 F1 ==> 2.525
# [11 Valid ] Loss ==> 1.769 Acc ==> 2.598 F1 ==> 2.598
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.830 Acc ==> 2.590 F1 ==> 2.590
# [12 Valid ] Loss ==> 1.421 Acc ==> 2.776 F1 ==> 2.776
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.721 Acc ==> 2.627 F1 ==> 2.627
# [13 Valid ] Loss ==> 1.351 Acc ==> 2.805 F1 ==> 2.805
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.599 Acc ==> 2.662 F1 ==> 2.662
# [14 Valid ] Loss ==> 1.191 Acc ==> 2.856 F1 ==> 2.856
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.469 Acc ==> 2.729 F1 ==> 2.729
# [15 Valid ] Loss ==> 1.017 Acc ==> 2.926 F1 ==> 2.926
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.399 Acc ==> 2.752 F1 ==> 2.752
# [16 Valid ] Loss ==> 1.039 Acc ==> 2.926 F1 ==> 2.926
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.290 Acc ==> 2.776 F1 ==> 2.776
# [17 Valid ] Loss ==> 0.942 Acc ==> 2.938 F1 ==> 2.938
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.267 Acc ==> 2.789 F1 ==> 2.789
# [18 Valid ] Loss ==> 0.910 Acc ==> 2.934 F1 ==> 2.934
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.206 Acc ==> 2.822 F1 ==> 2.822
# [19 Valid ] Loss ==> 0.982 Acc ==> 2.902 F1 ==> 2.902
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.141 Acc ==> 2.831 F1 ==> 2.831
# [20 Valid ] Loss ==> 0.805 Acc ==> 2.977 F1 ==> 2.977
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.052 Acc ==> 2.870 F1 ==> 2.870
# [21 Valid ] Loss ==> 0.756 Acc ==> 3.007 F1 ==> 3.007
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.963 Acc ==> 2.901 F1 ==> 2.901
# [22 Valid ] Loss ==> 0.760 Acc ==> 3.010 F1 ==> 3.010
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.915 Acc ==> 2.924 F1 ==> 2.924
# [23 Valid ] Loss ==> 0.658 Acc ==> 3.038 F1 ==> 3.038
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.856 Acc ==> 2.944 F1 ==> 2.944
# [24 Valid ] Loss ==> 0.594 Acc ==> 3.069 F1 ==> 3.069
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.837 Acc ==> 2.947 F1 ==> 2.947
# [25 Valid ] Loss ==> 0.483 Acc ==> 3.096 F1 ==> 3.096
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.780 Acc ==> 2.971 F1 ==> 2.971
# [26 Valid ] Loss ==> 0.470 Acc ==> 3.110 F1 ==> 3.110
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.777 Acc ==> 2.986 F1 ==> 2.986
# [27 Valid ] Loss ==> 0.508 Acc ==> 3.095 F1 ==> 3.095
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.703 Acc ==> 3.001 F1 ==> 3.001
# [28 Valid ] Loss ==> 0.792 Acc ==> 3.008 F1 ==> 3.008
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.749 Acc ==> 2.974 F1 ==> 2.974
# [29 Valid ] Loss ==> 0.426 Acc ==> 3.123 F1 ==> 3.123
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.697 Acc ==> 3.000 F1 ==> 3.000
# [30 Valid ] Loss ==> 0.358 Acc ==> 3.149 F1 ==> 3.149
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.153 Acc ==> 1.285 F1 ==> 1.285
# [1 Valid ] Loss ==> 3.951 Acc ==> 1.794 F1 ==> 1.794
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.913 Acc ==> 1.752 F1 ==> 1.752
# [2 Valid ] Loss ==> 3.354 Acc ==> 2.000 F1 ==> 2.000
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.505 Acc ==> 1.917 F1 ==> 1.917
# [3 Valid ] Loss ==> 2.999 Acc ==> 2.131 F1 ==> 2.131
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.219 Acc ==> 2.016 F1 ==> 2.016
# [4 Valid ] Loss ==> 2.679 Acc ==> 2.262 F1 ==> 2.262
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.022 Acc ==> 2.100 F1 ==> 2.100
# [5 Valid ] Loss ==> 2.531 Acc ==> 2.314 F1 ==> 2.314
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.799 Acc ==> 2.215 F1 ==> 2.215
# [6 Valid ] Loss ==> 2.350 Acc ==> 2.398 F1 ==> 2.398
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.631 Acc ==> 2.266 F1 ==> 2.266
# [7 Valid ] Loss ==> 2.080 Acc ==> 2.514 F1 ==> 2.514
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.474 Acc ==> 2.319 F1 ==> 2.319
# [8 Valid ] Loss ==> 1.955 Acc ==> 2.563 F1 ==> 2.563
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.324 Acc ==> 2.376 F1 ==> 2.376
# [9 Valid ] Loss ==> 1.783 Acc ==> 2.619 F1 ==> 2.619
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.134 Acc ==> 2.469 F1 ==> 2.469
# [10 Valid ] Loss ==> 1.690 Acc ==> 2.650 F1 ==> 2.650
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.074 Acc ==> 2.470 F1 ==> 2.470
# [11 Valid ] Loss ==> 1.790 Acc ==> 2.579 F1 ==> 2.579
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.970 Acc ==> 2.514 F1 ==> 2.514
# [12 Valid ] Loss ==> 1.433 Acc ==> 2.773 F1 ==> 2.773
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.795 Acc ==> 2.592 F1 ==> 2.592
# [13 Valid ] Loss ==> 1.392 Acc ==> 2.769 F1 ==> 2.769
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.728 Acc ==> 2.614 F1 ==> 2.614
# [14 Valid ] Loss ==> 1.332 Acc ==> 2.784 F1 ==> 2.784
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.631 Acc ==> 2.635 F1 ==> 2.635
# [15 Valid ] Loss ==> 1.056 Acc ==> 2.889 F1 ==> 2.889
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.582 Acc ==> 2.666 F1 ==> 2.666
# [16 Valid ] Loss ==> 1.071 Acc ==> 2.880 F1 ==> 2.880
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.411 Acc ==> 2.734 F1 ==> 2.734
# [17 Valid ] Loss ==> 1.051 Acc ==> 2.894 F1 ==> 2.894
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.371 Acc ==> 2.744 F1 ==> 2.744
# [18 Valid ] Loss ==> 0.849 Acc ==> 2.973 F1 ==> 2.973
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.312 Acc ==> 2.764 F1 ==> 2.764
# [19 Valid ] Loss ==> 0.918 Acc ==> 2.929 F1 ==> 2.929
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.224 Acc ==> 2.793 F1 ==> 2.793
# [20 Valid ] Loss ==> 0.765 Acc ==> 3.010 F1 ==> 3.010
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.213 Acc ==> 2.806 F1 ==> 2.806
# [21 Valid ] Loss ==> 0.736 Acc ==> 3.018 F1 ==> 3.018
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.164 Acc ==> 2.828 F1 ==> 2.828
# [22 Valid ] Loss ==> 0.848 Acc ==> 2.947 F1 ==> 2.947
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.128 Acc ==> 2.838 F1 ==> 2.838
# [23 Valid ] Loss ==> 0.651 Acc ==> 3.039 F1 ==> 3.039
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.009 Acc ==> 2.878 F1 ==> 2.878
# [24 Valid ] Loss ==> 0.592 Acc ==> 3.056 F1 ==> 3.056
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.016 Acc ==> 2.882 F1 ==> 2.882
# [25 Valid ] Loss ==> 0.632 Acc ==> 3.042 F1 ==> 3.042
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.966 Acc ==> 2.902 F1 ==> 2.902
# [26 Valid ] Loss ==> 0.533 Acc ==> 3.078 F1 ==> 3.078
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.929 Acc ==> 2.907 F1 ==> 2.907
# [27 Valid ] Loss ==> 0.550 Acc ==> 3.070 F1 ==> 3.070
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.880 Acc ==> 2.932 F1 ==> 2.932
# [28 Valid ] Loss ==> 0.572 Acc ==> 3.049 F1 ==> 3.049
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.892 Acc ==> 2.934 F1 ==> 2.934
# [29 Valid ] Loss ==> 0.514 Acc ==> 3.084 F1 ==> 3.084
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.821 Acc ==> 2.937 F1 ==> 2.937
# [30 Valid ] Loss ==> 0.589 Acc ==> 3.050 F1 ==> 3.050
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.087 Acc ==> 1.274 F1 ==> 1.274
# [1 Valid ] Loss ==> 3.801 Acc ==> 1.811 F1 ==> 1.811
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.877 Acc ==> 1.748 F1 ==> 1.748
# [2 Valid ] Loss ==> 3.336 Acc ==> 1.982 F1 ==> 1.982
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.508 Acc ==> 1.886 F1 ==> 1.886
# [3 Valid ] Loss ==> 2.920 Acc ==> 2.150 F1 ==> 2.150
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.219 Acc ==> 2.001 F1 ==> 2.001
# [4 Valid ] Loss ==> 2.679 Acc ==> 2.236 F1 ==> 2.236
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.033 Acc ==> 2.085 F1 ==> 2.085
# [5 Valid ] Loss ==> 2.507 Acc ==> 2.310 F1 ==> 2.310
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.871 Acc ==> 2.136 F1 ==> 2.136
# [6 Valid ] Loss ==> 2.342 Acc ==> 2.375 F1 ==> 2.375
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.706 Acc ==> 2.189 F1 ==> 2.189
# [7 Valid ] Loss ==> 2.181 Acc ==> 2.464 F1 ==> 2.464
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.511 Acc ==> 2.308 F1 ==> 2.308
# [8 Valid ] Loss ==> 2.016 Acc ==> 2.501 F1 ==> 2.501
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.433 Acc ==> 2.329 F1 ==> 2.329
# [9 Valid ] Loss ==> 1.900 Acc ==> 2.544 F1 ==> 2.544
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.349 Acc ==> 2.357 F1 ==> 2.357
# [10 Valid ] Loss ==> 1.866 Acc ==> 2.552 F1 ==> 2.552
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.128 Acc ==> 2.444 F1 ==> 2.444
# [11 Valid ] Loss ==> 1.631 Acc ==> 2.664 F1 ==> 2.664
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.052 Acc ==> 2.486 F1 ==> 2.486
# [12 Valid ] Loss ==> 1.574 Acc ==> 2.686 F1 ==> 2.686
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.934 Acc ==> 2.515 F1 ==> 2.515
# [13 Valid ] Loss ==> 1.426 Acc ==> 2.747 F1 ==> 2.747
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.825 Acc ==> 2.576 F1 ==> 2.576
# [14 Valid ] Loss ==> 1.187 Acc ==> 2.847 F1 ==> 2.847
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.746 Acc ==> 2.613 F1 ==> 2.613
# [15 Valid ] Loss ==> 1.276 Acc ==> 2.785 F1 ==> 2.785
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.666 Acc ==> 2.631 F1 ==> 2.631
# [16 Valid ] Loss ==> 1.128 Acc ==> 2.860 F1 ==> 2.860
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.539 Acc ==> 2.676 F1 ==> 2.676
# [17 Valid ] Loss ==> 1.028 Acc ==> 2.894 F1 ==> 2.894
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.469 Acc ==> 2.710 F1 ==> 2.710
# [18 Valid ] Loss ==> 1.116 Acc ==> 2.862 F1 ==> 2.862
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.377 Acc ==> 2.736 F1 ==> 2.736
# [19 Valid ] Loss ==> 0.984 Acc ==> 2.916 F1 ==> 2.916
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.380 Acc ==> 2.742 F1 ==> 2.742
# [20 Valid ] Loss ==> 0.835 Acc ==> 2.979 F1 ==> 2.979
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.308 Acc ==> 2.773 F1 ==> 2.773
# [21 Valid ] Loss ==> 0.778 Acc ==> 2.979 F1 ==> 2.979
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.213 Acc ==> 2.797 F1 ==> 2.797
# [22 Valid ] Loss ==> 0.788 Acc ==> 2.982 F1 ==> 2.982
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.155 Acc ==> 2.817 F1 ==> 2.817
# [23 Valid ] Loss ==> 0.839 Acc ==> 2.957 F1 ==> 2.957
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.138 Acc ==> 2.808 F1 ==> 2.808
# [24 Valid ] Loss ==> 0.910 Acc ==> 2.922 F1 ==> 2.922
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.131 Acc ==> 2.837 F1 ==> 2.837
# [25 Valid ] Loss ==> 0.682 Acc ==> 3.014 F1 ==> 3.014
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.034 Acc ==> 2.877 F1 ==> 2.877
# [26 Valid ] Loss ==> 0.539 Acc ==> 3.076 F1 ==> 3.076
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.033 Acc ==> 2.868 F1 ==> 2.868
# [27 Valid ] Loss ==> 0.576 Acc ==> 3.056 F1 ==> 3.056
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.023 Acc ==> 2.870 F1 ==> 2.870
# [28 Valid ] Loss ==> 0.565 Acc ==> 3.071 F1 ==> 3.071
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.907 Acc ==> 2.911 F1 ==> 2.911
# [29 Valid ] Loss ==> 0.438 Acc ==> 3.117 F1 ==> 3.117
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.971 Acc ==> 2.889 F1 ==> 2.889
# [30 Valid ] Loss ==> 0.494 Acc ==> 3.092 F1 ==> 3.092
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.009 Acc ==> 1.280 F1 ==> 1.280
# [1 Valid ] Loss ==> 3.894 Acc ==> 1.722 F1 ==> 1.722
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.839 Acc ==> 1.742 F1 ==> 1.742
# [2 Valid ] Loss ==> 3.264 Acc ==> 1.956 F1 ==> 1.956
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.493 Acc ==> 1.875 F1 ==> 1.875
# [3 Valid ] Loss ==> 2.869 Acc ==> 2.143 F1 ==> 2.143
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.289 Acc ==> 1.970 F1 ==> 1.970
# [4 Valid ] Loss ==> 2.626 Acc ==> 2.259 F1 ==> 2.259
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.074 Acc ==> 2.045 F1 ==> 2.045
# [5 Valid ] Loss ==> 2.495 Acc ==> 2.287 F1 ==> 2.287
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.911 Acc ==> 2.114 F1 ==> 2.114
# [6 Valid ] Loss ==> 2.254 Acc ==> 2.401 F1 ==> 2.401
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.752 Acc ==> 2.200 F1 ==> 2.200
# [7 Valid ] Loss ==> 2.068 Acc ==> 2.494 F1 ==> 2.494
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.583 Acc ==> 2.262 F1 ==> 2.262
# [8 Valid ] Loss ==> 1.991 Acc ==> 2.536 F1 ==> 2.536
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.464 Acc ==> 2.326 F1 ==> 2.326
# [9 Valid ] Loss ==> 1.865 Acc ==> 2.551 F1 ==> 2.551
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.340 Acc ==> 2.364 F1 ==> 2.364
# [10 Valid ] Loss ==> 1.753 Acc ==> 2.620 F1 ==> 2.620
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.168 Acc ==> 2.423 F1 ==> 2.423
# [11 Valid ] Loss ==> 1.651 Acc ==> 2.650 F1 ==> 2.650
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.058 Acc ==> 2.453 F1 ==> 2.453
# [12 Valid ] Loss ==> 1.528 Acc ==> 2.683 F1 ==> 2.683
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 2.060 Acc ==> 2.466 F1 ==> 2.466
# [13 Valid ] Loss ==> 1.514 Acc ==> 2.700 F1 ==> 2.700
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.854 Acc ==> 2.556 F1 ==> 2.556
# [14 Valid ] Loss ==> 1.281 Acc ==> 2.795 F1 ==> 2.795
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.807 Acc ==> 2.570 F1 ==> 2.570
# [15 Valid ] Loss ==> 1.220 Acc ==> 2.813 F1 ==> 2.813
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.777 Acc ==> 2.576 F1 ==> 2.576
# [16 Valid ] Loss ==> 1.105 Acc ==> 2.883 F1 ==> 2.883
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.712 Acc ==> 2.608 F1 ==> 2.608
# [17 Valid ] Loss ==> 1.108 Acc ==> 2.872 F1 ==> 2.872
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.680 Acc ==> 2.610 F1 ==> 2.610
# [18 Valid ] Loss ==> 1.014 Acc ==> 2.892 F1 ==> 2.892
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.600 Acc ==> 2.636 F1 ==> 2.636
# [19 Valid ] Loss ==> 0.991 Acc ==> 2.906 F1 ==> 2.906
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.498 Acc ==> 2.667 F1 ==> 2.667
# [20 Valid ] Loss ==> 0.986 Acc ==> 2.898 F1 ==> 2.898
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.494 Acc ==> 2.694 F1 ==> 2.694
# [21 Valid ] Loss ==> 0.821 Acc ==> 2.974 F1 ==> 2.974
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.354 Acc ==> 2.751 F1 ==> 2.751
# [22 Valid ] Loss ==> 0.781 Acc ==> 3.000 F1 ==> 3.000
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.340 Acc ==> 2.749 F1 ==> 2.749
# [23 Valid ] Loss ==> 0.752 Acc ==> 2.986 F1 ==> 2.986
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.271 Acc ==> 2.776 F1 ==> 2.776
# [24 Valid ] Loss ==> 0.706 Acc ==> 3.010 F1 ==> 3.010
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.123 Acc ==> 2.834 F1 ==> 2.834
# [25 Valid ] Loss ==> 0.601 Acc ==> 3.054 F1 ==> 3.054
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.131 Acc ==> 2.822 F1 ==> 2.822
# [26 Valid ] Loss ==> 0.655 Acc ==> 3.026 F1 ==> 3.026
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.177 Acc ==> 2.804 F1 ==> 2.804
# [27 Valid ] Loss ==> 0.660 Acc ==> 3.031 F1 ==> 3.031
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.127 Acc ==> 2.824 F1 ==> 2.824
# [28 Valid ] Loss ==> 0.595 Acc ==> 3.041 F1 ==> 3.041
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.105 Acc ==> 2.825 F1 ==> 2.825
# [29 Valid ] Loss ==> 0.561 Acc ==> 3.049 F1 ==> 3.049
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.042 Acc ==> 2.852 F1 ==> 2.852
# [30 Valid ] Loss ==> 0.543 Acc ==> 3.075 F1 ==> 3.075
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.051 Acc ==> 1.289 F1 ==> 1.289
# [1 Valid ] Loss ==> 3.644 Acc ==> 1.776 F1 ==> 1.776
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.880 Acc ==> 1.699 F1 ==> 1.699
# [2 Valid ] Loss ==> 3.128 Acc ==> 2.052 F1 ==> 2.052
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.492 Acc ==> 1.876 F1 ==> 1.876
# [3 Valid ] Loss ==> 2.953 Acc ==> 2.081 F1 ==> 2.081
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.243 Acc ==> 1.988 F1 ==> 1.988
# [4 Valid ] Loss ==> 2.777 Acc ==> 2.172 F1 ==> 2.172
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.033 Acc ==> 2.080 F1 ==> 2.080
# [5 Valid ] Loss ==> 2.291 Acc ==> 2.390 F1 ==> 2.390
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.914 Acc ==> 2.129 F1 ==> 2.129
# [6 Valid ] Loss ==> 2.298 Acc ==> 2.367 F1 ==> 2.367
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.720 Acc ==> 2.202 F1 ==> 2.202
# [7 Valid ] Loss ==> 2.093 Acc ==> 2.466 F1 ==> 2.466
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.640 Acc ==> 2.232 F1 ==> 2.232
# [8 Valid ] Loss ==> 2.042 Acc ==> 2.489 F1 ==> 2.489
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.520 Acc ==> 2.282 F1 ==> 2.282
# [9 Valid ] Loss ==> 1.892 Acc ==> 2.561 F1 ==> 2.561
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.299 Acc ==> 2.371 F1 ==> 2.371
# [10 Valid ] Loss ==> 1.649 Acc ==> 2.671 F1 ==> 2.671
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.222 Acc ==> 2.409 F1 ==> 2.409
# [11 Valid ] Loss ==> 1.626 Acc ==> 2.658 F1 ==> 2.658
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.266 Acc ==> 2.387 F1 ==> 2.387
# [12 Valid ] Loss ==> 1.452 Acc ==> 2.711 F1 ==> 2.711
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 2.128 Acc ==> 2.450 F1 ==> 2.450
# [13 Valid ] Loss ==> 1.435 Acc ==> 2.733 F1 ==> 2.733
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 2.055 Acc ==> 2.478 F1 ==> 2.478
# [14 Valid ] Loss ==> 1.290 Acc ==> 2.807 F1 ==> 2.807
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.970 Acc ==> 2.503 F1 ==> 2.503
# [15 Valid ] Loss ==> 1.255 Acc ==> 2.801 F1 ==> 2.801
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.872 Acc ==> 2.539 F1 ==> 2.539
# [16 Valid ] Loss ==> 1.244 Acc ==> 2.799 F1 ==> 2.799
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.782 Acc ==> 2.579 F1 ==> 2.579
# [17 Valid ] Loss ==> 1.066 Acc ==> 2.853 F1 ==> 2.853
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.654 Acc ==> 2.622 F1 ==> 2.622
# [18 Valid ] Loss ==> 1.077 Acc ==> 2.863 F1 ==> 2.863
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.761 Acc ==> 2.596 F1 ==> 2.596
# [19 Valid ] Loss ==> 1.093 Acc ==> 2.847 F1 ==> 2.847
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.658 Acc ==> 2.619 F1 ==> 2.619
# [20 Valid ] Loss ==> 1.013 Acc ==> 2.886 F1 ==> 2.886
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.510 Acc ==> 2.677 F1 ==> 2.677
# [21 Valid ] Loss ==> 1.039 Acc ==> 2.872 F1 ==> 2.872
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.528 Acc ==> 2.682 F1 ==> 2.682
# [22 Valid ] Loss ==> 0.946 Acc ==> 2.918 F1 ==> 2.918
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.435 Acc ==> 2.707 F1 ==> 2.707
# [23 Valid ] Loss ==> 0.755 Acc ==> 3.004 F1 ==> 3.004
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.471 Acc ==> 2.692 F1 ==> 2.692
# [24 Valid ] Loss ==> 0.778 Acc ==> 2.990 F1 ==> 2.990
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.338 Acc ==> 2.754 F1 ==> 2.754
# [25 Valid ] Loss ==> 0.764 Acc ==> 2.986 F1 ==> 2.986
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.313 Acc ==> 2.754 F1 ==> 2.754
# [26 Valid ] Loss ==> 0.684 Acc ==> 3.009 F1 ==> 3.009
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.302 Acc ==> 2.761 F1 ==> 2.761
# [27 Valid ] Loss ==> 0.713 Acc ==> 2.994 F1 ==> 2.994
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.270 Acc ==> 2.780 F1 ==> 2.780
# [28 Valid ] Loss ==> 0.642 Acc ==> 3.042 F1 ==> 3.042
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.113 Acc ==> 2.834 F1 ==> 2.834
# [29 Valid ] Loss ==> 0.605 Acc ==> 3.046 F1 ==> 3.046
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.255 Acc ==> 2.793 F1 ==> 2.793
# [30 Valid ] Loss ==> 0.583 Acc ==> 3.048 F1 ==> 3.048
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.336 Acc ==> 1.235 F1 ==> 1.235
# [1 Valid ] Loss ==> 3.966 Acc ==> 1.697 F1 ==> 1.697
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 4.095 Acc ==> 1.658 F1 ==> 1.658
# [2 Valid ] Loss ==> 3.612 Acc ==> 1.782 F1 ==> 1.782
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.671 Acc ==> 1.799 F1 ==> 1.799
# [3 Valid ] Loss ==> 2.920 Acc ==> 2.123 F1 ==> 2.123
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.445 Acc ==> 1.897 F1 ==> 1.897
# [4 Valid ] Loss ==> 2.666 Acc ==> 2.224 F1 ==> 2.224
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.200 Acc ==> 2.011 F1 ==> 2.011
# [5 Valid ] Loss ==> 2.541 Acc ==> 2.264 F1 ==> 2.264
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 3.091 Acc ==> 2.045 F1 ==> 2.045
# [6 Valid ] Loss ==> 2.184 Acc ==> 2.431 F1 ==> 2.431
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.847 Acc ==> 2.161 F1 ==> 2.161
# [7 Valid ] Loss ==> 2.258 Acc ==> 2.392 F1 ==> 2.392
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.707 Acc ==> 2.209 F1 ==> 2.209
# [8 Valid ] Loss ==> 2.173 Acc ==> 2.413 F1 ==> 2.413
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.528 Acc ==> 2.290 F1 ==> 2.290
# [9 Valid ] Loss ==> 1.920 Acc ==> 2.520 F1 ==> 2.520
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.455 Acc ==> 2.310 F1 ==> 2.310
# [10 Valid ] Loss ==> 1.766 Acc ==> 2.603 F1 ==> 2.603
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.317 Acc ==> 2.377 F1 ==> 2.377
# [11 Valid ] Loss ==> 1.575 Acc ==> 2.652 F1 ==> 2.652
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.323 Acc ==> 2.357 F1 ==> 2.357
# [12 Valid ] Loss ==> 1.548 Acc ==> 2.703 F1 ==> 2.703
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 2.179 Acc ==> 2.421 F1 ==> 2.421
# [13 Valid ] Loss ==> 1.428 Acc ==> 2.727 F1 ==> 2.727
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 2.057 Acc ==> 2.476 F1 ==> 2.476
# [14 Valid ] Loss ==> 1.349 Acc ==> 2.752 F1 ==> 2.752
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 2.042 Acc ==> 2.476 F1 ==> 2.476
# [15 Valid ] Loss ==> 1.429 Acc ==> 2.713 F1 ==> 2.713
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.954 Acc ==> 2.525 F1 ==> 2.525
# [16 Valid ] Loss ==> 1.194 Acc ==> 2.837 F1 ==> 2.837
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.804 Acc ==> 2.578 F1 ==> 2.578
# [17 Valid ] Loss ==> 1.128 Acc ==> 2.867 F1 ==> 2.867
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.743 Acc ==> 2.605 F1 ==> 2.605
# [18 Valid ] Loss ==> 1.063 Acc ==> 2.892 F1 ==> 2.892
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.710 Acc ==> 2.602 F1 ==> 2.602
# [19 Valid ] Loss ==> 0.930 Acc ==> 2.930 F1 ==> 2.930
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.647 Acc ==> 2.628 F1 ==> 2.628
# [20 Valid ] Loss ==> 0.922 Acc ==> 2.929 F1 ==> 2.929
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.629 Acc ==> 2.634 F1 ==> 2.634
# [21 Valid ] Loss ==> 0.987 Acc ==> 2.904 F1 ==> 2.904
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.615 Acc ==> 2.643 F1 ==> 2.643
# [22 Valid ] Loss ==> 1.036 Acc ==> 2.863 F1 ==> 2.863
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.519 Acc ==> 2.677 F1 ==> 2.677
# [23 Valid ] Loss ==> 0.787 Acc ==> 2.977 F1 ==> 2.977
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.422 Acc ==> 2.728 F1 ==> 2.728
# [24 Valid ] Loss ==> 0.899 Acc ==> 2.933 F1 ==> 2.933
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.422 Acc ==> 2.705 F1 ==> 2.705
# [25 Valid ] Loss ==> 0.652 Acc ==> 3.032 F1 ==> 3.032
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.378 Acc ==> 2.728 F1 ==> 2.728
# [26 Valid ] Loss ==> 0.699 Acc ==> 3.018 F1 ==> 3.018
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.321 Acc ==> 2.759 F1 ==> 2.759
# [27 Valid ] Loss ==> 0.680 Acc ==> 3.016 F1 ==> 3.016
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.267 Acc ==> 2.781 F1 ==> 2.781
# [28 Valid ] Loss ==> 0.642 Acc ==> 3.016 F1 ==> 3.016
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.312 Acc ==> 2.762 F1 ==> 2.762
# [29 Valid ] Loss ==> 0.576 Acc ==> 3.053 F1 ==> 3.053
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.183 Acc ==> 2.808 F1 ==> 2.808
# [30 Valid ] Loss ==> 0.590 Acc ==> 3.048 F1 ==> 3.048
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 감소

# %%
layer_list2 = [[2**(10-j) for j in range(i+1)] for i in range(7)]
layer_list2
# Out:
# [[1024],
#  [1024, 512],
#  [1024, 512, 256],
#  [1024, 512, 256, 128],
#  [1024, 512, 256, 128, 64],
#  [1024, 512, 256, 128, 64, 32],
#  [1024, 512, 256, 128, 64, 32, 16]]

# %%
layer_list2 = [[2**(10-j) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list2:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    for _, modelList in model.named_children():
        for child in modelList:
            if isinstance(child, nn.Linear):
                nn.init.kaiming_normal_(child.weight)
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)

    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model3/my_model2.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.256 Acc ==> 1.696 F1 ==> 1.696
# [1 Valid ] Loss ==> 2.669 Acc ==> 2.224 F1 ==> 2.224
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 2.877 Acc ==> 2.140 F1 ==> 2.140
# [2 Valid ] Loss ==> 2.207 Acc ==> 2.438 F1 ==> 2.438
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.364 Acc ==> 2.350 F1 ==> 2.350
# [3 Valid ] Loss ==> 1.675 Acc ==> 2.661 F1 ==> 2.661
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 1.940 Acc ==> 2.534 F1 ==> 2.534
# [4 Valid ] Loss ==> 1.372 Acc ==> 2.773 F1 ==> 2.773
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.594 Acc ==> 2.667 F1 ==> 2.667
# [5 Valid ] Loss ==> 1.109 Acc ==> 2.878 F1 ==> 2.878
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.278 Acc ==> 2.790 F1 ==> 2.790
# [6 Valid ] Loss ==> 0.940 Acc ==> 2.930 F1 ==> 2.930
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.094 Acc ==> 2.845 F1 ==> 2.845
# [7 Valid ] Loss ==> 0.951 Acc ==> 2.902 F1 ==> 2.902
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 0.909 Acc ==> 2.930 F1 ==> 2.930
# [8 Valid ] Loss ==> 0.523 Acc ==> 3.105 F1 ==> 3.105
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.760 Acc ==> 2.980 F1 ==> 2.980
# [9 Valid ] Loss ==> 0.536 Acc ==> 3.074 F1 ==> 3.074
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.670 Acc ==> 3.020 F1 ==> 3.020
# [10 Valid ] Loss ==> 0.412 Acc ==> 3.135 F1 ==> 3.135
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.496 Acc ==> 3.080 F1 ==> 3.080
# [11 Valid ] Loss ==> 0.294 Acc ==> 3.177 F1 ==> 3.177
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.395 Acc ==> 3.120 F1 ==> 3.120
# [12 Valid ] Loss ==> 0.277 Acc ==> 3.174 F1 ==> 3.174
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.368 Acc ==> 3.129 F1 ==> 3.129
# [13 Valid ] Loss ==> 0.388 Acc ==> 3.119 F1 ==> 3.119
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.323 Acc ==> 3.143 F1 ==> 3.143
# [14 Valid ] Loss ==> 0.157 Acc ==> 3.216 F1 ==> 3.216
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.239 Acc ==> 3.178 F1 ==> 3.178
# [15 Valid ] Loss ==> 0.135 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.260 Acc ==> 3.169 F1 ==> 3.169
# [16 Valid ] Loss ==> 0.179 Acc ==> 3.192 F1 ==> 3.192
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.254 Acc ==> 3.169 F1 ==> 3.169
# [17 Valid ] Loss ==> 0.213 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.243 Acc ==> 3.175 F1 ==> 3.175
# [18 Valid ] Loss ==> 0.245 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.266 Acc ==> 3.156 F1 ==> 3.156
# [19 Valid ] Loss ==> 0.122 Acc ==> 3.213 F1 ==> 3.213
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.204 Acc ==> 3.179 F1 ==> 3.179
# [20 Valid ] Loss ==> 0.146 Acc ==> 3.205 F1 ==> 3.205
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.218 Acc ==> 3.174 F1 ==> 3.174
# [21 Valid ] Loss ==> 0.164 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.250 Acc ==> 3.158 F1 ==> 3.158
# [22 Valid ] Loss ==> 0.199 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.224 Acc ==> 3.168 F1 ==> 3.168
# [23 Valid ] Loss ==> 0.137 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.174 Acc ==> 3.192 F1 ==> 3.192
# [24 Valid ] Loss ==> 0.146 Acc ==> 3.196 F1 ==> 3.196
#
# Early stopping at epoch 23
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.076 Acc ==> 1.683 F1 ==> 1.683
# [1 Valid ] Loss ==> 2.757 Acc ==> 2.191 F1 ==> 2.191
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 2.901 Acc ==> 2.148 F1 ==> 2.148
# [2 Valid ] Loss ==> 1.988 Acc ==> 2.532 F1 ==> 2.532
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.397 Acc ==> 2.338 F1 ==> 2.338
# [3 Valid ] Loss ==> 1.778 Acc ==> 2.597 F1 ==> 2.597
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 1.929 Acc ==> 2.533 F1 ==> 2.533
# [4 Valid ] Loss ==> 1.321 Acc ==> 2.780 F1 ==> 2.780
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.592 Acc ==> 2.660 F1 ==> 2.660
# [5 Valid ] Loss ==> 1.156 Acc ==> 2.825 F1 ==> 2.825
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.329 Acc ==> 2.735 F1 ==> 2.735
# [6 Valid ] Loss ==> 0.894 Acc ==> 2.950 F1 ==> 2.950
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 0.998 Acc ==> 2.882 F1 ==> 2.882
# [7 Valid ] Loss ==> 0.653 Acc ==> 3.025 F1 ==> 3.025
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 0.864 Acc ==> 2.926 F1 ==> 2.926
# [8 Valid ] Loss ==> 0.749 Acc ==> 2.976 F1 ==> 2.976
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.735 Acc ==> 2.972 F1 ==> 2.972
# [9 Valid ] Loss ==> 0.497 Acc ==> 3.077 F1 ==> 3.077
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.671 Acc ==> 3.000 F1 ==> 3.000
# [10 Valid ] Loss ==> 0.290 Acc ==> 3.163 F1 ==> 3.163
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.503 Acc ==> 3.060 F1 ==> 3.060
# [11 Valid ] Loss ==> 0.323 Acc ==> 3.136 F1 ==> 3.136
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.515 Acc ==> 3.056 F1 ==> 3.056
# [12 Valid ] Loss ==> 0.287 Acc ==> 3.147 F1 ==> 3.147
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.411 Acc ==> 3.103 F1 ==> 3.103
# [13 Valid ] Loss ==> 0.213 Acc ==> 3.180 F1 ==> 3.180
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.379 Acc ==> 3.119 F1 ==> 3.119
# [14 Valid ] Loss ==> 0.164 Acc ==> 3.195 F1 ==> 3.195
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.267 Acc ==> 3.152 F1 ==> 3.152
# [15 Valid ] Loss ==> 0.287 Acc ==> 3.143 F1 ==> 3.143
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.253 Acc ==> 3.156 F1 ==> 3.156
# [16 Valid ] Loss ==> 0.129 Acc ==> 3.200 F1 ==> 3.200
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.293 Acc ==> 3.138 F1 ==> 3.138
# [17 Valid ] Loss ==> 0.206 Acc ==> 3.167 F1 ==> 3.167
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.400 Acc ==> 3.107 F1 ==> 3.107
# [18 Valid ] Loss ==> 0.182 Acc ==> 3.182 F1 ==> 3.182
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.298 Acc ==> 3.139 F1 ==> 3.139
# [19 Valid ] Loss ==> 0.125 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.214 Acc ==> 3.174 F1 ==> 3.174
# [20 Valid ] Loss ==> 0.158 Acc ==> 3.195 F1 ==> 3.195
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.179 Acc ==> 3.189 F1 ==> 3.189
# [21 Valid ] Loss ==> 0.116 Acc ==> 3.201 F1 ==> 3.201
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.222 Acc ==> 3.171 F1 ==> 3.171
# [22 Valid ] Loss ==> 0.101 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.255 Acc ==> 3.156 F1 ==> 3.156
# [23 Valid ] Loss ==> 0.119 Acc ==> 3.202 F1 ==> 3.202
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.259 Acc ==> 3.155 F1 ==> 3.155
# [24 Valid ] Loss ==> 0.126 Acc ==> 3.201 F1 ==> 3.201
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.236 Acc ==> 3.158 F1 ==> 3.158
# [25 Valid ] Loss ==> 0.132 Acc ==> 3.196 F1 ==> 3.196
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.273 Acc ==> 3.149 F1 ==> 3.149
# [26 Valid ] Loss ==> 0.083 Acc ==> 3.215 F1 ==> 3.215
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.180 Acc ==> 3.180 F1 ==> 3.180
# [27 Valid ] Loss ==> 0.110 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.109 Acc ==> 3.203 F1 ==> 3.203
# [28 Valid ] Loss ==> 0.111 Acc ==> 3.202 F1 ==> 3.202
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.164 Acc ==> 3.181 F1 ==> 3.181
# [29 Valid ] Loss ==> 0.088 Acc ==> 3.213 F1 ==> 3.213
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.253 Acc ==> 3.154 F1 ==> 3.154
# [30 Valid ] Loss ==> 0.162 Acc ==> 3.191 F1 ==> 3.191
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.029 Acc ==> 1.682 F1 ==> 1.682
# [1 Valid ] Loss ==> 3.011 Acc ==> 2.048 F1 ==> 2.048
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 2.973 Acc ==> 2.100 F1 ==> 2.100
# [2 Valid ] Loss ==> 2.203 Acc ==> 2.440 F1 ==> 2.440
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.436 Acc ==> 2.325 F1 ==> 2.325
# [3 Valid ] Loss ==> 1.778 Acc ==> 2.611 F1 ==> 2.611
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.020 Acc ==> 2.485 F1 ==> 2.485
# [4 Valid ] Loss ==> 1.312 Acc ==> 2.792 F1 ==> 2.792
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.692 Acc ==> 2.601 F1 ==> 2.601
# [5 Valid ] Loss ==> 1.132 Acc ==> 2.851 F1 ==> 2.851
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.396 Acc ==> 2.718 F1 ==> 2.718
# [6 Valid ] Loss ==> 0.974 Acc ==> 2.910 F1 ==> 2.910
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.148 Acc ==> 2.812 F1 ==> 2.812
# [7 Valid ] Loss ==> 0.757 Acc ==> 2.996 F1 ==> 2.996
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.007 Acc ==> 2.870 F1 ==> 2.870
# [8 Valid ] Loss ==> 0.579 Acc ==> 3.058 F1 ==> 3.058
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.795 Acc ==> 2.962 F1 ==> 2.962
# [9 Valid ] Loss ==> 0.432 Acc ==> 3.115 F1 ==> 3.115
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.715 Acc ==> 2.982 F1 ==> 2.982
# [10 Valid ] Loss ==> 0.378 Acc ==> 3.122 F1 ==> 3.122
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.582 Acc ==> 3.038 F1 ==> 3.038
# [11 Valid ] Loss ==> 0.422 Acc ==> 3.094 F1 ==> 3.094
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.607 Acc ==> 3.017 F1 ==> 3.017
# [12 Valid ] Loss ==> 0.348 Acc ==> 3.129 F1 ==> 3.129
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.448 Acc ==> 3.088 F1 ==> 3.088
# [13 Valid ] Loss ==> 0.272 Acc ==> 3.155 F1 ==> 3.155
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.468 Acc ==> 3.073 F1 ==> 3.073
# [14 Valid ] Loss ==> 0.422 Acc ==> 3.102 F1 ==> 3.102
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.475 Acc ==> 3.066 F1 ==> 3.066
# [15 Valid ] Loss ==> 0.222 Acc ==> 3.168 F1 ==> 3.168
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.388 Acc ==> 3.102 F1 ==> 3.102
# [16 Valid ] Loss ==> 0.259 Acc ==> 3.165 F1 ==> 3.165
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.307 Acc ==> 3.144 F1 ==> 3.144
# [17 Valid ] Loss ==> 0.139 Acc ==> 3.200 F1 ==> 3.200
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.306 Acc ==> 3.131 F1 ==> 3.131
# [18 Valid ] Loss ==> 0.150 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.268 Acc ==> 3.146 F1 ==> 3.146
# [19 Valid ] Loss ==> 0.124 Acc ==> 3.208 F1 ==> 3.208
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.290 Acc ==> 3.144 F1 ==> 3.144
# [20 Valid ] Loss ==> 0.161 Acc ==> 3.190 F1 ==> 3.190
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.314 Acc ==> 3.135 F1 ==> 3.135
# [21 Valid ] Loss ==> 0.146 Acc ==> 3.196 F1 ==> 3.196
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.278 Acc ==> 3.143 F1 ==> 3.143
# [22 Valid ] Loss ==> 0.151 Acc ==> 3.192 F1 ==> 3.192
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.275 Acc ==> 3.145 F1 ==> 3.145
# [23 Valid ] Loss ==> 0.174 Acc ==> 3.181 F1 ==> 3.181
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.221 Acc ==> 3.163 F1 ==> 3.163
# [24 Valid ] Loss ==> 0.094 Acc ==> 3.212 F1 ==> 3.212
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.215 Acc ==> 3.166 F1 ==> 3.166
# [25 Valid ] Loss ==> 0.105 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.242 Acc ==> 3.152 F1 ==> 3.152
# [26 Valid ] Loss ==> 0.165 Acc ==> 3.187 F1 ==> 3.187
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.285 Acc ==> 3.137 F1 ==> 3.137
# [27 Valid ] Loss ==> 0.193 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.329 Acc ==> 3.126 F1 ==> 3.126
# [28 Valid ] Loss ==> 0.099 Acc ==> 3.216 F1 ==> 3.216
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.236 Acc ==> 3.158 F1 ==> 3.158
# [29 Valid ] Loss ==> 0.088 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.179 Acc ==> 3.176 F1 ==> 3.176
# [30 Valid ] Loss ==> 0.101 Acc ==> 3.209 F1 ==> 3.209
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.150 Acc ==> 1.635 F1 ==> 1.635
# [1 Valid ] Loss ==> 2.938 Acc ==> 2.165 F1 ==> 2.165
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.102 Acc ==> 2.056 F1 ==> 2.056
# [2 Valid ] Loss ==> 2.385 Acc ==> 2.370 F1 ==> 2.370
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.520 Acc ==> 2.304 F1 ==> 2.304
# [3 Valid ] Loss ==> 1.794 Acc ==> 2.584 F1 ==> 2.584
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.167 Acc ==> 2.436 F1 ==> 2.436
# [4 Valid ] Loss ==> 1.484 Acc ==> 2.723 F1 ==> 2.723
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.798 Acc ==> 2.577 F1 ==> 2.577
# [5 Valid ] Loss ==> 1.180 Acc ==> 2.849 F1 ==> 2.849
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.545 Acc ==> 2.658 F1 ==> 2.658
# [6 Valid ] Loss ==> 0.995 Acc ==> 2.921 F1 ==> 2.921
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.347 Acc ==> 2.746 F1 ==> 2.746
# [7 Valid ] Loss ==> 1.139 Acc ==> 2.807 F1 ==> 2.807
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.111 Acc ==> 2.826 F1 ==> 2.826
# [8 Valid ] Loss ==> 0.757 Acc ==> 2.969 F1 ==> 2.969
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.996 Acc ==> 2.882 F1 ==> 2.882
# [9 Valid ] Loss ==> 0.578 Acc ==> 3.048 F1 ==> 3.048
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.826 Acc ==> 2.951 F1 ==> 2.951
# [10 Valid ] Loss ==> 0.421 Acc ==> 3.110 F1 ==> 3.110
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.785 Acc ==> 2.959 F1 ==> 2.959
# [11 Valid ] Loss ==> 0.399 Acc ==> 3.109 F1 ==> 3.109
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.645 Acc ==> 3.016 F1 ==> 3.016
# [12 Valid ] Loss ==> 0.343 Acc ==> 3.130 F1 ==> 3.130
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.544 Acc ==> 3.046 F1 ==> 3.046
# [13 Valid ] Loss ==> 0.292 Acc ==> 3.148 F1 ==> 3.148
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.597 Acc ==> 3.029 F1 ==> 3.029
# [14 Valid ] Loss ==> 0.240 Acc ==> 3.167 F1 ==> 3.167
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.465 Acc ==> 3.079 F1 ==> 3.079
# [15 Valid ] Loss ==> 0.242 Acc ==> 3.168 F1 ==> 3.168
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.387 Acc ==> 3.110 F1 ==> 3.110
# [16 Valid ] Loss ==> 0.199 Acc ==> 3.180 F1 ==> 3.180
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.490 Acc ==> 3.074 F1 ==> 3.074
# [17 Valid ] Loss ==> 0.252 Acc ==> 3.160 F1 ==> 3.160
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.533 Acc ==> 3.052 F1 ==> 3.052
# [18 Valid ] Loss ==> 0.192 Acc ==> 3.181 F1 ==> 3.181
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.334 Acc ==> 3.124 F1 ==> 3.124
# [19 Valid ] Loss ==> 0.178 Acc ==> 3.192 F1 ==> 3.192
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.284 Acc ==> 3.141 F1 ==> 3.141
# [20 Valid ] Loss ==> 0.145 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.303 Acc ==> 3.137 F1 ==> 3.137
# [21 Valid ] Loss ==> 0.133 Acc ==> 3.195 F1 ==> 3.195
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.357 Acc ==> 3.122 F1 ==> 3.122
# [22 Valid ] Loss ==> 0.128 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.323 Acc ==> 3.127 F1 ==> 3.127
# [23 Valid ] Loss ==> 0.149 Acc ==> 3.202 F1 ==> 3.202
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.301 Acc ==> 3.138 F1 ==> 3.138
# [24 Valid ] Loss ==> 0.111 Acc ==> 3.207 F1 ==> 3.207
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.272 Acc ==> 3.150 F1 ==> 3.150
# [25 Valid ] Loss ==> 0.102 Acc ==> 3.211 F1 ==> 3.211
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.341 Acc ==> 3.125 F1 ==> 3.125
# [26 Valid ] Loss ==> 0.199 Acc ==> 3.186 F1 ==> 3.186
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.290 Acc ==> 3.136 F1 ==> 3.136
# [27 Valid ] Loss ==> 0.096 Acc ==> 3.213 F1 ==> 3.213
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.204 Acc ==> 3.176 F1 ==> 3.176
# [28 Valid ] Loss ==> 0.087 Acc ==> 3.214 F1 ==> 3.214
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.224 Acc ==> 3.164 F1 ==> 3.164
# [29 Valid ] Loss ==> 0.082 Acc ==> 3.214 F1 ==> 3.214
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.260 Acc ==> 3.148 F1 ==> 3.148
# [30 Valid ] Loss ==> 0.164 Acc ==> 3.190 F1 ==> 3.190
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.264 Acc ==> 1.620 F1 ==> 1.620
# [1 Valid ] Loss ==> 3.131 Acc ==> 2.067 F1 ==> 2.067
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.232 Acc ==> 2.015 F1 ==> 2.015
# [2 Valid ] Loss ==> 2.537 Acc ==> 2.323 F1 ==> 2.323
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.702 Acc ==> 2.218 F1 ==> 2.218
# [3 Valid ] Loss ==> 2.124 Acc ==> 2.469 F1 ==> 2.469
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.351 Acc ==> 2.365 F1 ==> 2.365
# [4 Valid ] Loss ==> 1.633 Acc ==> 2.693 F1 ==> 2.693
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.029 Acc ==> 2.499 F1 ==> 2.499
# [5 Valid ] Loss ==> 1.444 Acc ==> 2.749 F1 ==> 2.749
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.765 Acc ==> 2.603 F1 ==> 2.603
# [6 Valid ] Loss ==> 1.262 Acc ==> 2.795 F1 ==> 2.795
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.530 Acc ==> 2.686 F1 ==> 2.686
# [7 Valid ] Loss ==> 0.972 Acc ==> 2.918 F1 ==> 2.918
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.296 Acc ==> 2.782 F1 ==> 2.782
# [8 Valid ] Loss ==> 0.782 Acc ==> 2.982 F1 ==> 2.982
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.166 Acc ==> 2.825 F1 ==> 2.825
# [9 Valid ] Loss ==> 0.649 Acc ==> 3.028 F1 ==> 3.028
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.083 Acc ==> 2.842 F1 ==> 2.842
# [10 Valid ] Loss ==> 0.678 Acc ==> 3.026 F1 ==> 3.026
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.835 Acc ==> 2.948 F1 ==> 2.948
# [11 Valid ] Loss ==> 0.424 Acc ==> 3.114 F1 ==> 3.114
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.840 Acc ==> 2.944 F1 ==> 2.944
# [12 Valid ] Loss ==> 0.602 Acc ==> 3.027 F1 ==> 3.027
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.749 Acc ==> 2.970 F1 ==> 2.970
# [13 Valid ] Loss ==> 0.473 Acc ==> 3.091 F1 ==> 3.091
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.643 Acc ==> 3.009 F1 ==> 3.009
# [14 Valid ] Loss ==> 0.261 Acc ==> 3.173 F1 ==> 3.173
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.555 Acc ==> 3.048 F1 ==> 3.048
# [15 Valid ] Loss ==> 0.391 Acc ==> 3.109 F1 ==> 3.109
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.580 Acc ==> 3.037 F1 ==> 3.037
# [16 Valid ] Loss ==> 0.275 Acc ==> 3.157 F1 ==> 3.157
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.484 Acc ==> 3.079 F1 ==> 3.079
# [17 Valid ] Loss ==> 0.227 Acc ==> 3.174 F1 ==> 3.174
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.482 Acc ==> 3.084 F1 ==> 3.084
# [18 Valid ] Loss ==> 0.202 Acc ==> 3.176 F1 ==> 3.176
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.460 Acc ==> 3.084 F1 ==> 3.084
# [19 Valid ] Loss ==> 0.225 Acc ==> 3.174 F1 ==> 3.174
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.342 Acc ==> 3.122 F1 ==> 3.122
# [20 Valid ] Loss ==> 0.157 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.372 Acc ==> 3.105 F1 ==> 3.105
# [21 Valid ] Loss ==> 0.202 Acc ==> 3.174 F1 ==> 3.174
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.384 Acc ==> 3.107 F1 ==> 3.107
# [22 Valid ] Loss ==> 0.257 Acc ==> 3.158 F1 ==> 3.158
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.362 Acc ==> 3.118 F1 ==> 3.118
# [23 Valid ] Loss ==> 0.085 Acc ==> 3.220 F1 ==> 3.220
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.337 Acc ==> 3.125 F1 ==> 3.125
# [24 Valid ] Loss ==> 0.130 Acc ==> 3.199 F1 ==> 3.199
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.417 Acc ==> 3.102 F1 ==> 3.102
# [25 Valid ] Loss ==> 0.198 Acc ==> 3.179 F1 ==> 3.179
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.277 Acc ==> 3.150 F1 ==> 3.150
# [26 Valid ] Loss ==> 0.161 Acc ==> 3.191 F1 ==> 3.191
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.246 Acc ==> 3.166 F1 ==> 3.166
# [27 Valid ] Loss ==> 0.150 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.303 Acc ==> 3.140 F1 ==> 3.140
# [28 Valid ] Loss ==> 0.092 Acc ==> 3.216 F1 ==> 3.216
#
# Early stopping at epoch 27
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.697 Acc ==> 1.538 F1 ==> 1.538
# [1 Valid ] Loss ==> 3.434 Acc ==> 2.011 F1 ==> 2.011
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.523 Acc ==> 1.912 F1 ==> 1.912
# [2 Valid ] Loss ==> 2.790 Acc ==> 2.274 F1 ==> 2.274
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.053 Acc ==> 2.103 F1 ==> 2.103
# [3 Valid ] Loss ==> 2.284 Acc ==> 2.443 F1 ==> 2.443
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.597 Acc ==> 2.279 F1 ==> 2.279
# [4 Valid ] Loss ==> 1.802 Acc ==> 2.631 F1 ==> 2.631
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.279 Acc ==> 2.408 F1 ==> 2.408
# [5 Valid ] Loss ==> 1.758 Acc ==> 2.597 F1 ==> 2.597
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.054 Acc ==> 2.487 F1 ==> 2.487
# [6 Valid ] Loss ==> 1.391 Acc ==> 2.777 F1 ==> 2.777
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.779 Acc ==> 2.596 F1 ==> 2.596
# [7 Valid ] Loss ==> 1.278 Acc ==> 2.792 F1 ==> 2.792
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.587 Acc ==> 2.677 F1 ==> 2.677
# [8 Valid ] Loss ==> 1.212 Acc ==> 2.828 F1 ==> 2.828
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.480 Acc ==> 2.723 F1 ==> 2.723
# [9 Valid ] Loss ==> 0.976 Acc ==> 2.920 F1 ==> 2.920
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.289 Acc ==> 2.793 F1 ==> 2.793
# [10 Valid ] Loss ==> 0.816 Acc ==> 2.966 F1 ==> 2.966
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.181 Acc ==> 2.825 F1 ==> 2.825
# [11 Valid ] Loss ==> 0.672 Acc ==> 3.032 F1 ==> 3.032
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.012 Acc ==> 2.875 F1 ==> 2.875
# [12 Valid ] Loss ==> 0.661 Acc ==> 3.017 F1 ==> 3.017
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.941 Acc ==> 2.913 F1 ==> 2.913
# [13 Valid ] Loss ==> 0.480 Acc ==> 3.099 F1 ==> 3.099
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.848 Acc ==> 2.948 F1 ==> 2.948
# [14 Valid ] Loss ==> 0.571 Acc ==> 3.050 F1 ==> 3.050
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.800 Acc ==> 2.960 F1 ==> 2.960
# [15 Valid ] Loss ==> 0.509 Acc ==> 3.071 F1 ==> 3.071
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.651 Acc ==> 3.018 F1 ==> 3.018
# [16 Valid ] Loss ==> 0.358 Acc ==> 3.133 F1 ==> 3.133
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.726 Acc ==> 2.981 F1 ==> 2.981
# [17 Valid ] Loss ==> 0.320 Acc ==> 3.142 F1 ==> 3.142
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.622 Acc ==> 3.032 F1 ==> 3.032
# [18 Valid ] Loss ==> 0.366 Acc ==> 3.123 F1 ==> 3.123
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.546 Acc ==> 3.056 F1 ==> 3.056
# [19 Valid ] Loss ==> 0.257 Acc ==> 3.170 F1 ==> 3.170
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.582 Acc ==> 3.047 F1 ==> 3.047
# [20 Valid ] Loss ==> 0.214 Acc ==> 3.175 F1 ==> 3.175
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.481 Acc ==> 3.084 F1 ==> 3.084
# [21 Valid ] Loss ==> 0.229 Acc ==> 3.175 F1 ==> 3.175
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.431 Acc ==> 3.093 F1 ==> 3.093
# [22 Valid ] Loss ==> 0.291 Acc ==> 3.136 F1 ==> 3.136
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.496 Acc ==> 3.075 F1 ==> 3.075
# [23 Valid ] Loss ==> 0.339 Acc ==> 3.125 F1 ==> 3.125
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.478 Acc ==> 3.074 F1 ==> 3.074
# [24 Valid ] Loss ==> 0.145 Acc ==> 3.204 F1 ==> 3.204
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.412 Acc ==> 3.106 F1 ==> 3.106
# [25 Valid ] Loss ==> 0.215 Acc ==> 3.177 F1 ==> 3.177
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.433 Acc ==> 3.101 F1 ==> 3.101
# [26 Valid ] Loss ==> 0.158 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.343 Acc ==> 3.128 F1 ==> 3.128
# [27 Valid ] Loss ==> 0.144 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.353 Acc ==> 3.119 F1 ==> 3.119
# [28 Valid ] Loss ==> 0.182 Acc ==> 3.182 F1 ==> 3.182
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.324 Acc ==> 3.133 F1 ==> 3.133
# [29 Valid ] Loss ==> 0.149 Acc ==> 3.197 F1 ==> 3.197
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.357 Acc ==> 3.118 F1 ==> 3.118
# [30 Valid ] Loss ==> 0.099 Acc ==> 3.216 F1 ==> 3.216
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.499 Acc ==> 1.228 F1 ==> 1.228
# [1 Valid ] Loss ==> 4.453 Acc ==> 1.760 F1 ==> 1.760
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 4.184 Acc ==> 1.798 F1 ==> 1.798
# [2 Valid ] Loss ==> 3.416 Acc ==> 2.105 F1 ==> 2.105
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.490 Acc ==> 2.018 F1 ==> 2.018
# [3 Valid ] Loss ==> 2.803 Acc ==> 2.286 F1 ==> 2.286
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.054 Acc ==> 2.140 F1 ==> 2.140
# [4 Valid ] Loss ==> 2.397 Acc ==> 2.412 F1 ==> 2.412
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.703 Acc ==> 2.283 F1 ==> 2.283
# [5 Valid ] Loss ==> 1.985 Acc ==> 2.560 F1 ==> 2.560
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.342 Acc ==> 2.416 F1 ==> 2.416
# [6 Valid ] Loss ==> 1.773 Acc ==> 2.646 F1 ==> 2.646
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.097 Acc ==> 2.498 F1 ==> 2.498
# [7 Valid ] Loss ==> 1.431 Acc ==> 2.772 F1 ==> 2.772
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.947 Acc ==> 2.557 F1 ==> 2.557
# [8 Valid ] Loss ==> 1.416 Acc ==> 2.760 F1 ==> 2.760
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.719 Acc ==> 2.622 F1 ==> 2.622
# [9 Valid ] Loss ==> 1.025 Acc ==> 2.916 F1 ==> 2.916
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.621 Acc ==> 2.680 F1 ==> 2.680
# [10 Valid ] Loss ==> 1.098 Acc ==> 2.886 F1 ==> 2.886
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.432 Acc ==> 2.746 F1 ==> 2.746
# [11 Valid ] Loss ==> 1.092 Acc ==> 2.884 F1 ==> 2.884
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.385 Acc ==> 2.737 F1 ==> 2.737
# [12 Valid ] Loss ==> 0.853 Acc ==> 2.960 F1 ==> 2.960
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.148 Acc ==> 2.848 F1 ==> 2.848
# [13 Valid ] Loss ==> 0.686 Acc ==> 3.023 F1 ==> 3.023
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.099 Acc ==> 2.853 F1 ==> 2.853
# [14 Valid ] Loss ==> 0.649 Acc ==> 3.036 F1 ==> 3.036
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.967 Acc ==> 2.904 F1 ==> 2.904
# [15 Valid ] Loss ==> 0.498 Acc ==> 3.093 F1 ==> 3.093
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.955 Acc ==> 2.909 F1 ==> 2.909
# [16 Valid ] Loss ==> 0.606 Acc ==> 3.046 F1 ==> 3.046
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.883 Acc ==> 2.925 F1 ==> 2.925
# [17 Valid ] Loss ==> 0.437 Acc ==> 3.107 F1 ==> 3.107
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.753 Acc ==> 2.988 F1 ==> 2.988
# [18 Valid ] Loss ==> 0.410 Acc ==> 3.120 F1 ==> 3.120
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.677 Acc ==> 3.012 F1 ==> 3.012
# [19 Valid ] Loss ==> 0.275 Acc ==> 3.160 F1 ==> 3.160
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.659 Acc ==> 3.016 F1 ==> 3.016
# [20 Valid ] Loss ==> 0.285 Acc ==> 3.159 F1 ==> 3.159
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.567 Acc ==> 3.048 F1 ==> 3.048
# [21 Valid ] Loss ==> 0.304 Acc ==> 3.152 F1 ==> 3.152
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.646 Acc ==> 3.027 F1 ==> 3.027
# [22 Valid ] Loss ==> 0.340 Acc ==> 3.130 F1 ==> 3.130
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.563 Acc ==> 3.049 F1 ==> 3.049
# [23 Valid ] Loss ==> 0.281 Acc ==> 3.144 F1 ==> 3.144
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.495 Acc ==> 3.074 F1 ==> 3.074
# [24 Valid ] Loss ==> 0.214 Acc ==> 3.177 F1 ==> 3.177
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.494 Acc ==> 3.072 F1 ==> 3.072
# [25 Valid ] Loss ==> 0.245 Acc ==> 3.163 F1 ==> 3.163
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.490 Acc ==> 3.079 F1 ==> 3.079
# [26 Valid ] Loss ==> 0.187 Acc ==> 3.188 F1 ==> 3.188
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.451 Acc ==> 3.087 F1 ==> 3.087
# [27 Valid ] Loss ==> 0.191 Acc ==> 3.185 F1 ==> 3.185
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.474 Acc ==> 3.084 F1 ==> 3.084
# [28 Valid ] Loss ==> 0.161 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.400 Acc ==> 3.104 F1 ==> 3.104
# [29 Valid ] Loss ==> 0.218 Acc ==> 3.175 F1 ==> 3.175
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.394 Acc ==> 3.107 F1 ==> 3.107
# [30 Valid ] Loss ==> 0.194 Acc ==> 3.183 F1 ==> 3.183
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Orthogonal Initialization

# %%
class FishModel(nn.Module):
    
    # 모델 구성 요소 초기화 
    def __init__(self, in_dim, out_dim, nodes_list = []):
        super().__init__()
        nodes_list.insert(0, in_dim)
        nodes_list.append(out_dim)
        layer_num = len(nodes_list) - 1
        layers = []
        for i in range(layer_num):
             if i <= layer_num - 2:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))
                layers.append(nn.BatchNorm1d(num_features = nodes_list[i+1]))
                layers.append(nn.ReLU())
             else:
                layers.append(nn.Linear(nodes_list[i], nodes_list[i + 1]))
        
        self.layers = nn.ModuleList(layers)
        
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 증가

# %%
layer_list1 = [[2**(j+4) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list1:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    for _, modelList in model.named_children():
        for child in modelList:
            if isinstance(child, nn.Linear):
                nn.init.orthogonal_(child.weight)
                
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)
    
    print(f'IN : {IN_DIM}, OUT : {OUT_DIM}')

    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model3/my_model3.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.323 Acc ==> 1.338 F1 ==> 1.338
# [1 Valid ] Loss ==> 4.433 Acc ==> 1.750 F1 ==> 1.750
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 4.201 Acc ==> 1.770 F1 ==> 1.770
# [2 Valid ] Loss ==> 3.751 Acc ==> 1.905 F1 ==> 1.905
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.693 Acc ==> 1.924 F1 ==> 1.924
# [3 Valid ] Loss ==> 3.350 Acc ==> 2.081 F1 ==> 2.081
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.364 Acc ==> 2.027 F1 ==> 2.027
# [4 Valid ] Loss ==> 3.055 Acc ==> 2.169 F1 ==> 2.169
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.072 Acc ==> 2.146 F1 ==> 2.146
# [5 Valid ] Loss ==> 2.766 Acc ==> 2.273 F1 ==> 2.273
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.847 Acc ==> 2.245 F1 ==> 2.245
# [6 Valid ] Loss ==> 2.479 Acc ==> 2.402 F1 ==> 2.402
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.615 Acc ==> 2.308 F1 ==> 2.308
# [7 Valid ] Loss ==> 2.419 Acc ==> 2.394 F1 ==> 2.394
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.436 Acc ==> 2.377 F1 ==> 2.377
# [8 Valid ] Loss ==> 2.101 Acc ==> 2.521 F1 ==> 2.521
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.226 Acc ==> 2.461 F1 ==> 2.461
# [9 Valid ] Loss ==> 1.887 Acc ==> 2.608 F1 ==> 2.608
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.092 Acc ==> 2.502 F1 ==> 2.502
# [10 Valid ] Loss ==> 1.898 Acc ==> 2.620 F1 ==> 2.620
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.926 Acc ==> 2.586 F1 ==> 2.586
# [11 Valid ] Loss ==> 1.772 Acc ==> 2.642 F1 ==> 2.642
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.788 Acc ==> 2.626 F1 ==> 2.626
# [12 Valid ] Loss ==> 1.632 Acc ==> 2.700 F1 ==> 2.700
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.692 Acc ==> 2.646 F1 ==> 2.646
# [13 Valid ] Loss ==> 1.499 Acc ==> 2.753 F1 ==> 2.753
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.571 Acc ==> 2.707 F1 ==> 2.707
# [14 Valid ] Loss ==> 1.367 Acc ==> 2.795 F1 ==> 2.795
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.405 Acc ==> 2.766 F1 ==> 2.766
# [15 Valid ] Loss ==> 1.128 Acc ==> 2.895 F1 ==> 2.895
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.334 Acc ==> 2.817 F1 ==> 2.817
# [16 Valid ] Loss ==> 1.038 Acc ==> 2.945 F1 ==> 2.945
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.261 Acc ==> 2.818 F1 ==> 2.818
# [17 Valid ] Loss ==> 1.147 Acc ==> 2.866 F1 ==> 2.866
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.207 Acc ==> 2.834 F1 ==> 2.834
# [18 Valid ] Loss ==> 0.958 Acc ==> 2.969 F1 ==> 2.969
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.135 Acc ==> 2.868 F1 ==> 2.868
# [19 Valid ] Loss ==> 0.849 Acc ==> 3.011 F1 ==> 3.011
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.056 Acc ==> 2.891 F1 ==> 2.891
# [20 Valid ] Loss ==> 0.934 Acc ==> 2.931 F1 ==> 2.931
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.958 Acc ==> 2.924 F1 ==> 2.924
# [21 Valid ] Loss ==> 0.756 Acc ==> 3.037 F1 ==> 3.037
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.910 Acc ==> 2.959 F1 ==> 2.959
# [22 Valid ] Loss ==> 0.716 Acc ==> 3.037 F1 ==> 3.037
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.888 Acc ==> 2.953 F1 ==> 2.953
# [23 Valid ] Loss ==> 0.702 Acc ==> 3.045 F1 ==> 3.045
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.902 Acc ==> 2.941 F1 ==> 2.941
# [24 Valid ] Loss ==> 0.617 Acc ==> 3.077 F1 ==> 3.077
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.801 Acc ==> 2.988 F1 ==> 2.988
# [25 Valid ] Loss ==> 0.587 Acc ==> 3.095 F1 ==> 3.095
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.744 Acc ==> 3.005 F1 ==> 3.005
# [26 Valid ] Loss ==> 0.634 Acc ==> 3.062 F1 ==> 3.062
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.744 Acc ==> 3.001 F1 ==> 3.001
# [27 Valid ] Loss ==> 0.480 Acc ==> 3.130 F1 ==> 3.130
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.685 Acc ==> 3.027 F1 ==> 3.027
# [28 Valid ] Loss ==> 0.480 Acc ==> 3.109 F1 ==> 3.109
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.649 Acc ==> 3.040 F1 ==> 3.040
# [29 Valid ] Loss ==> 0.572 Acc ==> 3.061 F1 ==> 3.061
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.628 Acc ==> 3.029 F1 ==> 3.029
# [30 Valid ] Loss ==> 0.549 Acc ==> 3.084 F1 ==> 3.084
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.062 Acc ==> 1.410 F1 ==> 1.410
# [1 Valid ] Loss ==> 4.034 Acc ==> 1.785 F1 ==> 1.785
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.918 Acc ==> 1.780 F1 ==> 1.780
# [2 Valid ] Loss ==> 3.375 Acc ==> 2.003 F1 ==> 2.003
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.495 Acc ==> 1.919 F1 ==> 1.919
# [3 Valid ] Loss ==> 2.977 Acc ==> 2.180 F1 ==> 2.180
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.183 Acc ==> 2.026 F1 ==> 2.026
# [4 Valid ] Loss ==> 2.668 Acc ==> 2.304 F1 ==> 2.304
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.880 Acc ==> 2.170 F1 ==> 2.170
# [5 Valid ] Loss ==> 2.463 Acc ==> 2.368 F1 ==> 2.368
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.663 Acc ==> 2.266 F1 ==> 2.266
# [6 Valid ] Loss ==> 2.304 Acc ==> 2.405 F1 ==> 2.405
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.463 Acc ==> 2.350 F1 ==> 2.350
# [7 Valid ] Loss ==> 2.028 Acc ==> 2.547 F1 ==> 2.547
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.291 Acc ==> 2.403 F1 ==> 2.403
# [8 Valid ] Loss ==> 1.911 Acc ==> 2.576 F1 ==> 2.576
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.156 Acc ==> 2.480 F1 ==> 2.480
# [9 Valid ] Loss ==> 1.698 Acc ==> 2.662 F1 ==> 2.662
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.004 Acc ==> 2.519 F1 ==> 2.519
# [10 Valid ] Loss ==> 1.606 Acc ==> 2.677 F1 ==> 2.677
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.905 Acc ==> 2.548 F1 ==> 2.548
# [11 Valid ] Loss ==> 1.425 Acc ==> 2.773 F1 ==> 2.773
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.745 Acc ==> 2.612 F1 ==> 2.612
# [12 Valid ] Loss ==> 1.310 Acc ==> 2.806 F1 ==> 2.806
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.598 Acc ==> 2.667 F1 ==> 2.667
# [13 Valid ] Loss ==> 1.152 Acc ==> 2.874 F1 ==> 2.874
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.546 Acc ==> 2.682 F1 ==> 2.682
# [14 Valid ] Loss ==> 1.176 Acc ==> 2.852 F1 ==> 2.852
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.482 Acc ==> 2.710 F1 ==> 2.710
# [15 Valid ] Loss ==> 1.025 Acc ==> 2.920 F1 ==> 2.920
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.356 Acc ==> 2.762 F1 ==> 2.762
# [16 Valid ] Loss ==> 1.018 Acc ==> 2.913 F1 ==> 2.913
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.288 Acc ==> 2.780 F1 ==> 2.780
# [17 Valid ] Loss ==> 0.964 Acc ==> 2.925 F1 ==> 2.925
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.195 Acc ==> 2.800 F1 ==> 2.800
# [18 Valid ] Loss ==> 1.009 Acc ==> 2.896 F1 ==> 2.896
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.145 Acc ==> 2.843 F1 ==> 2.843
# [19 Valid ] Loss ==> 0.742 Acc ==> 3.013 F1 ==> 3.013
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.025 Acc ==> 2.883 F1 ==> 2.883
# [20 Valid ] Loss ==> 0.822 Acc ==> 2.959 F1 ==> 2.959
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.050 Acc ==> 2.860 F1 ==> 2.860
# [21 Valid ] Loss ==> 0.740 Acc ==> 3.005 F1 ==> 3.005
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.022 Acc ==> 2.881 F1 ==> 2.881
# [22 Valid ] Loss ==> 0.938 Acc ==> 2.929 F1 ==> 2.929
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.954 Acc ==> 2.908 F1 ==> 2.908
# [23 Valid ] Loss ==> 0.790 Acc ==> 2.974 F1 ==> 2.974
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.886 Acc ==> 2.938 F1 ==> 2.938
# [24 Valid ] Loss ==> 0.565 Acc ==> 3.082 F1 ==> 3.082
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.772 Acc ==> 2.974 F1 ==> 2.974
# [25 Valid ] Loss ==> 0.568 Acc ==> 3.066 F1 ==> 3.066
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.788 Acc ==> 2.969 F1 ==> 2.969
# [26 Valid ] Loss ==> 0.505 Acc ==> 3.091 F1 ==> 3.091
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.803 Acc ==> 2.956 F1 ==> 2.956
# [27 Valid ] Loss ==> 0.521 Acc ==> 3.080 F1 ==> 3.080
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.799 Acc ==> 2.952 F1 ==> 2.952
# [28 Valid ] Loss ==> 0.439 Acc ==> 3.110 F1 ==> 3.110
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.671 Acc ==> 3.001 F1 ==> 3.001
# [29 Valid ] Loss ==> 0.409 Acc ==> 3.114 F1 ==> 3.114
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.685 Acc ==> 3.002 F1 ==> 3.002
# [30 Valid ] Loss ==> 0.436 Acc ==> 3.108 F1 ==> 3.108
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.920 Acc ==> 1.415 F1 ==> 1.415
# [1 Valid ] Loss ==> 3.817 Acc ==> 1.859 F1 ==> 1.859
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.807 Acc ==> 1.783 F1 ==> 1.783
# [2 Valid ] Loss ==> 3.229 Acc ==> 2.067 F1 ==> 2.067
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.362 Acc ==> 1.978 F1 ==> 1.978
# [3 Valid ] Loss ==> 2.860 Acc ==> 2.172 F1 ==> 2.172
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.081 Acc ==> 2.076 F1 ==> 2.076
# [4 Valid ] Loss ==> 2.663 Acc ==> 2.260 F1 ==> 2.260
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.812 Acc ==> 2.192 F1 ==> 2.192
# [5 Valid ] Loss ==> 2.405 Acc ==> 2.369 F1 ==> 2.369
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.657 Acc ==> 2.261 F1 ==> 2.261
# [6 Valid ] Loss ==> 2.107 Acc ==> 2.498 F1 ==> 2.498
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.489 Acc ==> 2.322 F1 ==> 2.322
# [7 Valid ] Loss ==> 2.029 Acc ==> 2.545 F1 ==> 2.545
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.299 Acc ==> 2.416 F1 ==> 2.416
# [8 Valid ] Loss ==> 1.753 Acc ==> 2.631 F1 ==> 2.631
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.134 Acc ==> 2.460 F1 ==> 2.460
# [9 Valid ] Loss ==> 1.678 Acc ==> 2.659 F1 ==> 2.659
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.956 Acc ==> 2.540 F1 ==> 2.540
# [10 Valid ] Loss ==> 1.460 Acc ==> 2.737 F1 ==> 2.737
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.834 Acc ==> 2.558 F1 ==> 2.558
# [11 Valid ] Loss ==> 1.594 Acc ==> 2.664 F1 ==> 2.664
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.774 Acc ==> 2.599 F1 ==> 2.599
# [12 Valid ] Loss ==> 1.301 Acc ==> 2.798 F1 ==> 2.798
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.685 Acc ==> 2.628 F1 ==> 2.628
# [13 Valid ] Loss ==> 1.221 Acc ==> 2.822 F1 ==> 2.822
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.541 Acc ==> 2.686 F1 ==> 2.686
# [14 Valid ] Loss ==> 1.261 Acc ==> 2.810 F1 ==> 2.810
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.439 Acc ==> 2.720 F1 ==> 2.720
# [15 Valid ] Loss ==> 0.991 Acc ==> 2.923 F1 ==> 2.923
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.322 Acc ==> 2.756 F1 ==> 2.756
# [16 Valid ] Loss ==> 0.941 Acc ==> 2.936 F1 ==> 2.936
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.261 Acc ==> 2.781 F1 ==> 2.781
# [17 Valid ] Loss ==> 0.730 Acc ==> 3.021 F1 ==> 3.021
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.243 Acc ==> 2.785 F1 ==> 2.785
# [18 Valid ] Loss ==> 0.769 Acc ==> 2.990 F1 ==> 2.990
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.137 Acc ==> 2.835 F1 ==> 2.835
# [19 Valid ] Loss ==> 0.695 Acc ==> 3.025 F1 ==> 3.025
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.122 Acc ==> 2.841 F1 ==> 2.841
# [20 Valid ] Loss ==> 0.711 Acc ==> 3.010 F1 ==> 3.010
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.980 Acc ==> 2.891 F1 ==> 2.891
# [21 Valid ] Loss ==> 0.717 Acc ==> 3.002 F1 ==> 3.002
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.963 Acc ==> 2.895 F1 ==> 2.895
# [22 Valid ] Loss ==> 0.582 Acc ==> 3.064 F1 ==> 3.064
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.860 Acc ==> 2.942 F1 ==> 2.942
# [23 Valid ] Loss ==> 0.573 Acc ==> 3.045 F1 ==> 3.045
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.012 Acc ==> 2.872 F1 ==> 2.872
# [24 Valid ] Loss ==> 0.486 Acc ==> 3.087 F1 ==> 3.087
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.824 Acc ==> 2.951 F1 ==> 2.951
# [25 Valid ] Loss ==> 0.459 Acc ==> 3.100 F1 ==> 3.100
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.864 Acc ==> 2.923 F1 ==> 2.923
# [26 Valid ] Loss ==> 0.621 Acc ==> 3.018 F1 ==> 3.018
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.820 Acc ==> 2.933 F1 ==> 2.933
# [27 Valid ] Loss ==> 0.536 Acc ==> 3.069 F1 ==> 3.069
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.801 Acc ==> 2.950 F1 ==> 2.950
# [28 Valid ] Loss ==> 0.398 Acc ==> 3.118 F1 ==> 3.118
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.781 Acc ==> 2.946 F1 ==> 2.946
# [29 Valid ] Loss ==> 0.373 Acc ==> 3.130 F1 ==> 3.130
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.645 Acc ==> 3.014 F1 ==> 3.014
# [30 Valid ] Loss ==> 0.298 Acc ==> 3.161 F1 ==> 3.161
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.722 Acc ==> 1.422 F1 ==> 1.422
# [1 Valid ] Loss ==> 3.596 Acc ==> 1.890 F1 ==> 1.890
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.618 Acc ==> 1.858 F1 ==> 1.858
# [2 Valid ] Loss ==> 3.081 Acc ==> 2.053 F1 ==> 2.053
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.271 Acc ==> 1.970 F1 ==> 1.970
# [3 Valid ] Loss ==> 2.673 Acc ==> 2.251 F1 ==> 2.251
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.947 Acc ==> 2.114 F1 ==> 2.114
# [4 Valid ] Loss ==> 2.335 Acc ==> 2.402 F1 ==> 2.402
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.758 Acc ==> 2.198 F1 ==> 2.198
# [5 Valid ] Loss ==> 2.207 Acc ==> 2.419 F1 ==> 2.419
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.544 Acc ==> 2.283 F1 ==> 2.283
# [6 Valid ] Loss ==> 2.066 Acc ==> 2.505 F1 ==> 2.505
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.368 Acc ==> 2.357 F1 ==> 2.357
# [7 Valid ] Loss ==> 1.765 Acc ==> 2.635 F1 ==> 2.635
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.228 Acc ==> 2.419 F1 ==> 2.419
# [8 Valid ] Loss ==> 1.712 Acc ==> 2.617 F1 ==> 2.617
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.129 Acc ==> 2.443 F1 ==> 2.443
# [9 Valid ] Loss ==> 1.691 Acc ==> 2.629 F1 ==> 2.629
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.949 Acc ==> 2.504 F1 ==> 2.504
# [10 Valid ] Loss ==> 1.410 Acc ==> 2.737 F1 ==> 2.737
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.875 Acc ==> 2.535 F1 ==> 2.535
# [11 Valid ] Loss ==> 1.293 Acc ==> 2.786 F1 ==> 2.786
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.714 Acc ==> 2.622 F1 ==> 2.622
# [12 Valid ] Loss ==> 1.098 Acc ==> 2.883 F1 ==> 2.883
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.642 Acc ==> 2.629 F1 ==> 2.629
# [13 Valid ] Loss ==> 1.202 Acc ==> 2.820 F1 ==> 2.820
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.524 Acc ==> 2.670 F1 ==> 2.670
# [14 Valid ] Loss ==> 1.046 Acc ==> 2.887 F1 ==> 2.887
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.485 Acc ==> 2.702 F1 ==> 2.702
# [15 Valid ] Loss ==> 0.923 Acc ==> 2.937 F1 ==> 2.937
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.448 Acc ==> 2.706 F1 ==> 2.706
# [16 Valid ] Loss ==> 0.855 Acc ==> 2.969 F1 ==> 2.969
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.322 Acc ==> 2.756 F1 ==> 2.756
# [17 Valid ] Loss ==> 0.829 Acc ==> 2.967 F1 ==> 2.967
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.259 Acc ==> 2.774 F1 ==> 2.774
# [18 Valid ] Loss ==> 0.834 Acc ==> 2.961 F1 ==> 2.961
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.166 Acc ==> 2.816 F1 ==> 2.816
# [19 Valid ] Loss ==> 0.694 Acc ==> 3.019 F1 ==> 3.019
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.121 Acc ==> 2.827 F1 ==> 2.827
# [20 Valid ] Loss ==> 0.676 Acc ==> 3.027 F1 ==> 3.027
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.134 Acc ==> 2.831 F1 ==> 2.831
# [21 Valid ] Loss ==> 0.629 Acc ==> 3.049 F1 ==> 3.049
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.036 Acc ==> 2.874 F1 ==> 2.874
# [22 Valid ] Loss ==> 0.611 Acc ==> 3.042 F1 ==> 3.042
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.988 Acc ==> 2.888 F1 ==> 2.888
# [23 Valid ] Loss ==> 0.510 Acc ==> 3.089 F1 ==> 3.089
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.963 Acc ==> 2.887 F1 ==> 2.887
# [24 Valid ] Loss ==> 0.570 Acc ==> 3.061 F1 ==> 3.061
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.964 Acc ==> 2.886 F1 ==> 2.886
# [25 Valid ] Loss ==> 0.429 Acc ==> 3.116 F1 ==> 3.116
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.882 Acc ==> 2.931 F1 ==> 2.931
# [26 Valid ] Loss ==> 0.424 Acc ==> 3.113 F1 ==> 3.113
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.834 Acc ==> 2.940 F1 ==> 2.940
# [27 Valid ] Loss ==> 0.494 Acc ==> 3.078 F1 ==> 3.078
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.816 Acc ==> 2.950 F1 ==> 2.950
# [28 Valid ] Loss ==> 0.562 Acc ==> 3.053 F1 ==> 3.053
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.829 Acc ==> 2.940 F1 ==> 2.940
# [29 Valid ] Loss ==> 0.384 Acc ==> 3.136 F1 ==> 3.136
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.755 Acc ==> 2.970 F1 ==> 2.970
# [30 Valid ] Loss ==> 0.351 Acc ==> 3.134 F1 ==> 3.134
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.663 Acc ==> 1.410 F1 ==> 1.410
# [1 Valid ] Loss ==> 3.547 Acc ==> 1.879 F1 ==> 1.879
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.632 Acc ==> 1.829 F1 ==> 1.829
# [2 Valid ] Loss ==> 3.038 Acc ==> 2.086 F1 ==> 2.086
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.314 Acc ==> 1.965 F1 ==> 1.965
# [3 Valid ] Loss ==> 2.708 Acc ==> 2.220 F1 ==> 2.220
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.041 Acc ==> 2.072 F1 ==> 2.072
# [4 Valid ] Loss ==> 2.555 Acc ==> 2.287 F1 ==> 2.287
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.816 Acc ==> 2.179 F1 ==> 2.179
# [5 Valid ] Loss ==> 2.250 Acc ==> 2.414 F1 ==> 2.414
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.614 Acc ==> 2.257 F1 ==> 2.257
# [6 Valid ] Loss ==> 2.079 Acc ==> 2.508 F1 ==> 2.508
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.438 Acc ==> 2.336 F1 ==> 2.336
# [7 Valid ] Loss ==> 1.777 Acc ==> 2.617 F1 ==> 2.617
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.336 Acc ==> 2.358 F1 ==> 2.358
# [8 Valid ] Loss ==> 1.708 Acc ==> 2.625 F1 ==> 2.625
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.211 Acc ==> 2.419 F1 ==> 2.419
# [9 Valid ] Loss ==> 1.535 Acc ==> 2.695 F1 ==> 2.695
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.043 Acc ==> 2.482 F1 ==> 2.482
# [10 Valid ] Loss ==> 1.433 Acc ==> 2.724 F1 ==> 2.724
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.969 Acc ==> 2.494 F1 ==> 2.494
# [11 Valid ] Loss ==> 1.444 Acc ==> 2.728 F1 ==> 2.728
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.860 Acc ==> 2.550 F1 ==> 2.550
# [12 Valid ] Loss ==> 1.255 Acc ==> 2.810 F1 ==> 2.810
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.776 Acc ==> 2.576 F1 ==> 2.576
# [13 Valid ] Loss ==> 1.165 Acc ==> 2.836 F1 ==> 2.836
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.669 Acc ==> 2.613 F1 ==> 2.613
# [14 Valid ] Loss ==> 1.058 Acc ==> 2.886 F1 ==> 2.886
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.587 Acc ==> 2.659 F1 ==> 2.659
# [15 Valid ] Loss ==> 0.995 Acc ==> 2.910 F1 ==> 2.910
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.579 Acc ==> 2.670 F1 ==> 2.670
# [16 Valid ] Loss ==> 1.060 Acc ==> 2.888 F1 ==> 2.888
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.477 Acc ==> 2.692 F1 ==> 2.692
# [17 Valid ] Loss ==> 0.850 Acc ==> 2.960 F1 ==> 2.960
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.420 Acc ==> 2.711 F1 ==> 2.711
# [18 Valid ] Loss ==> 0.838 Acc ==> 2.960 F1 ==> 2.960
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.319 Acc ==> 2.763 F1 ==> 2.763
# [19 Valid ] Loss ==> 0.783 Acc ==> 2.987 F1 ==> 2.987
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.271 Acc ==> 2.776 F1 ==> 2.776
# [20 Valid ] Loss ==> 0.714 Acc ==> 3.017 F1 ==> 3.017
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.238 Acc ==> 2.778 F1 ==> 2.778
# [21 Valid ] Loss ==> 0.723 Acc ==> 3.004 F1 ==> 3.004
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.229 Acc ==> 2.784 F1 ==> 2.784
# [22 Valid ] Loss ==> 0.662 Acc ==> 3.034 F1 ==> 3.034
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.114 Acc ==> 2.844 F1 ==> 2.844
# [23 Valid ] Loss ==> 0.701 Acc ==> 2.996 F1 ==> 2.996
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.119 Acc ==> 2.840 F1 ==> 2.840
# [24 Valid ] Loss ==> 0.664 Acc ==> 3.020 F1 ==> 3.020
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.074 Acc ==> 2.842 F1 ==> 2.842
# [25 Valid ] Loss ==> 0.539 Acc ==> 3.074 F1 ==> 3.074
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.048 Acc ==> 2.857 F1 ==> 2.857
# [26 Valid ] Loss ==> 0.489 Acc ==> 3.087 F1 ==> 3.087
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.967 Acc ==> 2.885 F1 ==> 2.885
# [27 Valid ] Loss ==> 0.573 Acc ==> 3.052 F1 ==> 3.052
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.999 Acc ==> 2.886 F1 ==> 2.886
# [28 Valid ] Loss ==> 0.454 Acc ==> 3.091 F1 ==> 3.091
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.884 Acc ==> 2.917 F1 ==> 2.917
# [29 Valid ] Loss ==> 0.484 Acc ==> 3.090 F1 ==> 3.090
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.936 Acc ==> 2.909 F1 ==> 2.909
# [30 Valid ] Loss ==> 0.448 Acc ==> 3.094 F1 ==> 3.094
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.790 Acc ==> 1.367 F1 ==> 1.367
# [1 Valid ] Loss ==> 3.628 Acc ==> 1.839 F1 ==> 1.839
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.804 Acc ==> 1.737 F1 ==> 1.737
# [2 Valid ] Loss ==> 3.049 Acc ==> 2.077 F1 ==> 2.077
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.402 Acc ==> 1.904 F1 ==> 1.904
# [3 Valid ] Loss ==> 2.774 Acc ==> 2.209 F1 ==> 2.209
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.144 Acc ==> 2.038 F1 ==> 2.038
# [4 Valid ] Loss ==> 2.486 Acc ==> 2.320 F1 ==> 2.320
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.923 Acc ==> 2.121 F1 ==> 2.121
# [5 Valid ] Loss ==> 2.253 Acc ==> 2.406 F1 ==> 2.406
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.779 Acc ==> 2.168 F1 ==> 2.168
# [6 Valid ] Loss ==> 2.096 Acc ==> 2.456 F1 ==> 2.456
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.589 Acc ==> 2.247 F1 ==> 2.247
# [7 Valid ] Loss ==> 1.938 Acc ==> 2.533 F1 ==> 2.533
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.441 Acc ==> 2.309 F1 ==> 2.309
# [8 Valid ] Loss ==> 1.849 Acc ==> 2.561 F1 ==> 2.561
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.350 Acc ==> 2.356 F1 ==> 2.356
# [9 Valid ] Loss ==> 1.811 Acc ==> 2.575 F1 ==> 2.575
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.275 Acc ==> 2.374 F1 ==> 2.374
# [10 Valid ] Loss ==> 1.486 Acc ==> 2.713 F1 ==> 2.713
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.188 Acc ==> 2.412 F1 ==> 2.412
# [11 Valid ] Loss ==> 1.538 Acc ==> 2.692 F1 ==> 2.692
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.041 Acc ==> 2.481 F1 ==> 2.481
# [12 Valid ] Loss ==> 1.508 Acc ==> 2.694 F1 ==> 2.694
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.968 Acc ==> 2.504 F1 ==> 2.504
# [13 Valid ] Loss ==> 1.235 Acc ==> 2.824 F1 ==> 2.824
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.834 Acc ==> 2.546 F1 ==> 2.546
# [14 Valid ] Loss ==> 1.272 Acc ==> 2.793 F1 ==> 2.793
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.789 Acc ==> 2.574 F1 ==> 2.574
# [15 Valid ] Loss ==> 1.106 Acc ==> 2.854 F1 ==> 2.854
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.712 Acc ==> 2.610 F1 ==> 2.610
# [16 Valid ] Loss ==> 1.120 Acc ==> 2.840 F1 ==> 2.840
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.669 Acc ==> 2.614 F1 ==> 2.614
# [17 Valid ] Loss ==> 1.027 Acc ==> 2.886 F1 ==> 2.886
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.563 Acc ==> 2.663 F1 ==> 2.663
# [18 Valid ] Loss ==> 1.063 Acc ==> 2.857 F1 ==> 2.857
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.458 Acc ==> 2.689 F1 ==> 2.689
# [19 Valid ] Loss ==> 0.775 Acc ==> 2.986 F1 ==> 2.986
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.413 Acc ==> 2.714 F1 ==> 2.714
# [20 Valid ] Loss ==> 0.806 Acc ==> 2.960 F1 ==> 2.960
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.386 Acc ==> 2.729 F1 ==> 2.729
# [21 Valid ] Loss ==> 0.874 Acc ==> 2.938 F1 ==> 2.938
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.274 Acc ==> 2.771 F1 ==> 2.771
# [22 Valid ] Loss ==> 0.694 Acc ==> 3.004 F1 ==> 3.004
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.260 Acc ==> 2.774 F1 ==> 2.774
# [23 Valid ] Loss ==> 0.676 Acc ==> 3.008 F1 ==> 3.008
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.172 Acc ==> 2.804 F1 ==> 2.804
# [24 Valid ] Loss ==> 0.709 Acc ==> 3.008 F1 ==> 3.008
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.253 Acc ==> 2.780 F1 ==> 2.780
# [25 Valid ] Loss ==> 0.649 Acc ==> 3.023 F1 ==> 3.023
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.268 Acc ==> 2.775 F1 ==> 2.775
# [26 Valid ] Loss ==> 0.602 Acc ==> 3.038 F1 ==> 3.038
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.086 Acc ==> 2.850 F1 ==> 2.850
# [27 Valid ] Loss ==> 0.565 Acc ==> 3.061 F1 ==> 3.061
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.109 Acc ==> 2.839 F1 ==> 2.839
# [28 Valid ] Loss ==> 0.531 Acc ==> 3.068 F1 ==> 3.068
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.031 Acc ==> 2.860 F1 ==> 2.860
# [29 Valid ] Loss ==> 0.448 Acc ==> 3.109 F1 ==> 3.109
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.996 Acc ==> 2.878 F1 ==> 2.878
# [30 Valid ] Loss ==> 0.502 Acc ==> 3.085 F1 ==> 3.085
#
# Done!
# IN : 2655, OUT : 9
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.990 Acc ==> 1.336 F1 ==> 1.336
# [1 Valid ] Loss ==> 3.881 Acc ==> 1.678 F1 ==> 1.678
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.940 Acc ==> 1.682 F1 ==> 1.682
# [2 Valid ] Loss ==> 3.203 Acc ==> 2.040 F1 ==> 2.040
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.616 Acc ==> 1.856 F1 ==> 1.856
# [3 Valid ] Loss ==> 3.018 Acc ==> 2.082 F1 ==> 2.082
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 3.302 Acc ==> 1.983 F1 ==> 1.983
# [4 Valid ] Loss ==> 2.552 Acc ==> 2.304 F1 ==> 2.304
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 3.067 Acc ==> 2.076 F1 ==> 2.076
# [5 Valid ] Loss ==> 2.309 Acc ==> 2.395 F1 ==> 2.395
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.904 Acc ==> 2.144 F1 ==> 2.144
# [6 Valid ] Loss ==> 2.205 Acc ==> 2.404 F1 ==> 2.404
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.700 Acc ==> 2.236 F1 ==> 2.236
# [7 Valid ] Loss ==> 2.172 Acc ==> 2.458 F1 ==> 2.458
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 2.630 Acc ==> 2.256 F1 ==> 2.256
# [8 Valid ] Loss ==> 2.058 Acc ==> 2.490 F1 ==> 2.490
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 2.465 Acc ==> 2.326 F1 ==> 2.326
# [9 Valid ] Loss ==> 1.773 Acc ==> 2.583 F1 ==> 2.583
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 2.327 Acc ==> 2.371 F1 ==> 2.371
# [10 Valid ] Loss ==> 1.676 Acc ==> 2.632 F1 ==> 2.632
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 2.203 Acc ==> 2.437 F1 ==> 2.437
# [11 Valid ] Loss ==> 1.529 Acc ==> 2.705 F1 ==> 2.705
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 2.130 Acc ==> 2.434 F1 ==> 2.434
# [12 Valid ] Loss ==> 1.455 Acc ==> 2.731 F1 ==> 2.731
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 2.002 Acc ==> 2.493 F1 ==> 2.493
# [13 Valid ] Loss ==> 1.404 Acc ==> 2.756 F1 ==> 2.756
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.921 Acc ==> 2.521 F1 ==> 2.521
# [14 Valid ] Loss ==> 1.270 Acc ==> 2.803 F1 ==> 2.803
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 1.976 Acc ==> 2.515 F1 ==> 2.515
# [15 Valid ] Loss ==> 1.264 Acc ==> 2.812 F1 ==> 2.812
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 1.754 Acc ==> 2.600 F1 ==> 2.600
# [16 Valid ] Loss ==> 1.213 Acc ==> 2.816 F1 ==> 2.816
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 1.736 Acc ==> 2.604 F1 ==> 2.604
# [17 Valid ] Loss ==> 1.127 Acc ==> 2.832 F1 ==> 2.832
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 1.652 Acc ==> 2.618 F1 ==> 2.618
# [18 Valid ] Loss ==> 1.054 Acc ==> 2.870 F1 ==> 2.870
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 1.633 Acc ==> 2.635 F1 ==> 2.635
# [19 Valid ] Loss ==> 0.893 Acc ==> 2.944 F1 ==> 2.944
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 1.593 Acc ==> 2.633 F1 ==> 2.633
# [20 Valid ] Loss ==> 0.926 Acc ==> 2.938 F1 ==> 2.938
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 1.540 Acc ==> 2.668 F1 ==> 2.668
# [21 Valid ] Loss ==> 0.866 Acc ==> 2.938 F1 ==> 2.938
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 1.447 Acc ==> 2.708 F1 ==> 2.708
# [22 Valid ] Loss ==> 0.758 Acc ==> 3.005 F1 ==> 3.005
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 1.438 Acc ==> 2.711 F1 ==> 2.711
# [23 Valid ] Loss ==> 0.824 Acc ==> 2.974 F1 ==> 2.974
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 1.390 Acc ==> 2.726 F1 ==> 2.726
# [24 Valid ] Loss ==> 0.709 Acc ==> 3.013 F1 ==> 3.013
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 1.357 Acc ==> 2.764 F1 ==> 2.764
# [25 Valid ] Loss ==> 0.803 Acc ==> 2.961 F1 ==> 2.961
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 1.215 Acc ==> 2.814 F1 ==> 2.814
# [26 Valid ] Loss ==> 0.603 Acc ==> 3.044 F1 ==> 3.044
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 1.224 Acc ==> 2.785 F1 ==> 2.785
# [27 Valid ] Loss ==> 0.574 Acc ==> 3.068 F1 ==> 3.068
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 1.213 Acc ==> 2.813 F1 ==> 2.813
# [28 Valid ] Loss ==> 0.568 Acc ==> 3.050 F1 ==> 3.050
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 1.175 Acc ==> 2.803 F1 ==> 2.803
# [29 Valid ] Loss ==> 0.650 Acc ==> 3.030 F1 ==> 3.030
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 1.185 Acc ==> 2.819 F1 ==> 2.819
# [30 Valid ] Loss ==> 0.568 Acc ==> 3.059 F1 ==> 3.059
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# - 첫번째 은닉층을 기준으로 퍼셉트론 수 감소

# %%
layer_list2 = [[2**(10-j) for j in range(i+1)] for i in range(7)]

loss_list = [[], []]
acc_list = [[], []]
f1_score_list = [[], []]

EPOCHS = 30
for layer in layer_list2:
    IN_DIM, OUT_DIM = X_train.shape[1], y_train.nunique()
    model = FishModel(IN_DIM, OUT_DIM, layer)
    for _, modelList in model.named_children():
        for child in modelList:
            if isinstance(child, nn.Linear):
                nn.init.orthogonal_(child.weight)
    OPTIMIZER = optim.Adam(model.parameters())
    LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)
    SCHEDULER = ReduceLROnPlateau(OPTIMIZER, mode = 'min', patience = 5)

    train_ = {'loss':[], 'acc':[], 'f1':[]}
    val_ = {'loss':[], 'acc':[], 'f1':[]}

    pre_va_score = 100

    for epo in range(EPOCHS):
        print(f"[Epoch {epo+1}/{EPOCHS}] ", end='')
    
        tr_score=training(epo)
        va_score=testing(epo)
    
        if pre_va_score > va_score[0]:
            torch.save(model, './model3/my_model4.pt')
            pre_va_score = va_score[0]

        for idx, key in enumerate(train_):
            train_[key].append(tr_score[idx])
            val_[key].append(va_score[idx])
        
        SCHEDULER.step(va_score[0])
        # 조기종료 기능 => 조건 : val_loss가 지정된 횟수이상 개선이 안되면 학습 종료
        if SCHEDULER.num_bad_epochs >= SCHEDULER.patience:
            print(f'Early stopping at epoch {epo}')
            break
        
    loss_list[0].append(train_['loss'][-1])
    loss_list[1].append(val_['loss'][-1])
    acc_list[0].append(train_['acc'][-1])
    acc_list[1].append(val_['acc'][-1])
    f1_score_list[0].append(train_['f1'][-1])
    f1_score_list[1].append(val_['f1'][-1])

    print("Done!")
# Out:
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.054 Acc ==> 1.684 F1 ==> 1.684
# [1 Valid ] Loss ==> 2.991 Acc ==> 2.102 F1 ==> 2.102
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 2.948 Acc ==> 2.116 F1 ==> 2.116
# [2 Valid ] Loss ==> 2.260 Acc ==> 2.414 F1 ==> 2.414
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.425 Acc ==> 2.340 F1 ==> 2.340
# [3 Valid ] Loss ==> 1.775 Acc ==> 2.655 F1 ==> 2.655
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.018 Acc ==> 2.502 F1 ==> 2.502
# [4 Valid ] Loss ==> 1.542 Acc ==> 2.709 F1 ==> 2.709
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.707 Acc ==> 2.606 F1 ==> 2.606
# [5 Valid ] Loss ==> 1.075 Acc ==> 2.921 F1 ==> 2.921
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.368 Acc ==> 2.748 F1 ==> 2.748
# [6 Valid ] Loss ==> 0.934 Acc ==> 2.944 F1 ==> 2.944
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.101 Acc ==> 2.853 F1 ==> 2.853
# [7 Valid ] Loss ==> 0.932 Acc ==> 2.920 F1 ==> 2.920
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 0.966 Acc ==> 2.906 F1 ==> 2.906
# [8 Valid ] Loss ==> 0.733 Acc ==> 3.002 F1 ==> 3.002
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.777 Acc ==> 2.978 F1 ==> 2.978
# [9 Valid ] Loss ==> 0.520 Acc ==> 3.091 F1 ==> 3.091
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.600 Acc ==> 3.055 F1 ==> 3.055
# [10 Valid ] Loss ==> 0.363 Acc ==> 3.153 F1 ==> 3.153
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.455 Acc ==> 3.109 F1 ==> 3.109
# [11 Valid ] Loss ==> 0.288 Acc ==> 3.178 F1 ==> 3.178
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.399 Acc ==> 3.126 F1 ==> 3.126
# [12 Valid ] Loss ==> 0.284 Acc ==> 3.157 F1 ==> 3.157
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.360 Acc ==> 3.131 F1 ==> 3.131
# [13 Valid ] Loss ==> 0.315 Acc ==> 3.154 F1 ==> 3.154
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.346 Acc ==> 3.136 F1 ==> 3.136
# [14 Valid ] Loss ==> 0.347 Acc ==> 3.131 F1 ==> 3.131
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.267 Acc ==> 3.162 F1 ==> 3.162
# [15 Valid ] Loss ==> 0.187 Acc ==> 3.197 F1 ==> 3.197
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.328 Acc ==> 3.145 F1 ==> 3.145
# [16 Valid ] Loss ==> 0.272 Acc ==> 3.165 F1 ==> 3.165
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.321 Acc ==> 3.131 F1 ==> 3.131
# [17 Valid ] Loss ==> 0.237 Acc ==> 3.165 F1 ==> 3.165
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.263 Acc ==> 3.162 F1 ==> 3.162
# [18 Valid ] Loss ==> 0.105 Acc ==> 3.219 F1 ==> 3.219
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.186 Acc ==> 3.191 F1 ==> 3.191
# [19 Valid ] Loss ==> 0.105 Acc ==> 3.219 F1 ==> 3.219
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.215 Acc ==> 3.176 F1 ==> 3.176
# [20 Valid ] Loss ==> 0.147 Acc ==> 3.200 F1 ==> 3.200
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.155 Acc ==> 3.199 F1 ==> 3.199
# [21 Valid ] Loss ==> 0.111 Acc ==> 3.217 F1 ==> 3.217
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.276 Acc ==> 3.155 F1 ==> 3.155
# [22 Valid ] Loss ==> 0.087 Acc ==> 3.227 F1 ==> 3.227
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.190 Acc ==> 3.184 F1 ==> 3.184
# [23 Valid ] Loss ==> 0.113 Acc ==> 3.214 F1 ==> 3.214
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.128 Acc ==> 3.209 F1 ==> 3.209
# [24 Valid ] Loss ==> 0.064 Acc ==> 3.228 F1 ==> 3.228
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.101 Acc ==> 3.216 F1 ==> 3.216
# [25 Valid ] Loss ==> 0.091 Acc ==> 3.219 F1 ==> 3.219
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.150 Acc ==> 3.195 F1 ==> 3.195
# [26 Valid ] Loss ==> 0.077 Acc ==> 3.227 F1 ==> 3.227
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.173 Acc ==> 3.189 F1 ==> 3.189
# [27 Valid ] Loss ==> 0.340 Acc ==> 3.141 F1 ==> 3.141
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.246 Acc ==> 3.159 F1 ==> 3.159
# [28 Valid ] Loss ==> 0.121 Acc ==> 3.201 F1 ==> 3.201
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.204 Acc ==> 3.172 F1 ==> 3.172
# [29 Valid ] Loss ==> 0.131 Acc ==> 3.200 F1 ==> 3.200
#
# Early stopping at epoch 28
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.043 Acc ==> 1.679 F1 ==> 1.679
# [1 Valid ] Loss ==> 3.065 Acc ==> 2.012 F1 ==> 2.012
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.055 Acc ==> 2.074 F1 ==> 2.074
# [2 Valid ] Loss ==> 2.304 Acc ==> 2.385 F1 ==> 2.385
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.551 Acc ==> 2.265 F1 ==> 2.265
# [3 Valid ] Loss ==> 1.802 Acc ==> 2.588 F1 ==> 2.588
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.033 Acc ==> 2.474 F1 ==> 2.474
# [4 Valid ] Loss ==> 1.373 Acc ==> 2.750 F1 ==> 2.750
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.663 Acc ==> 2.604 F1 ==> 2.604
# [5 Valid ] Loss ==> 1.149 Acc ==> 2.845 F1 ==> 2.845
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.322 Acc ==> 2.758 F1 ==> 2.758
# [6 Valid ] Loss ==> 0.925 Acc ==> 2.924 F1 ==> 2.924
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.238 Acc ==> 2.783 F1 ==> 2.783
# [7 Valid ] Loss ==> 0.660 Acc ==> 3.034 F1 ==> 3.034
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 0.918 Acc ==> 2.912 F1 ==> 2.912
# [8 Valid ] Loss ==> 0.729 Acc ==> 2.990 F1 ==> 2.990
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.772 Acc ==> 2.960 F1 ==> 2.960
# [9 Valid ] Loss ==> 0.479 Acc ==> 3.091 F1 ==> 3.091
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.674 Acc ==> 2.992 F1 ==> 2.992
# [10 Valid ] Loss ==> 0.420 Acc ==> 3.099 F1 ==> 3.099
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.555 Acc ==> 3.043 F1 ==> 3.043
# [11 Valid ] Loss ==> 0.362 Acc ==> 3.124 F1 ==> 3.124
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.513 Acc ==> 3.064 F1 ==> 3.064
# [12 Valid ] Loss ==> 0.273 Acc ==> 3.153 F1 ==> 3.153
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.463 Acc ==> 3.065 F1 ==> 3.065
# [13 Valid ] Loss ==> 0.288 Acc ==> 3.146 F1 ==> 3.146
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.418 Acc ==> 3.103 F1 ==> 3.103
# [14 Valid ] Loss ==> 0.255 Acc ==> 3.158 F1 ==> 3.158
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.336 Acc ==> 3.123 F1 ==> 3.123
# [15 Valid ] Loss ==> 0.245 Acc ==> 3.159 F1 ==> 3.159
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.333 Acc ==> 3.123 F1 ==> 3.123
# [16 Valid ] Loss ==> 0.173 Acc ==> 3.187 F1 ==> 3.187
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.320 Acc ==> 3.131 F1 ==> 3.131
# [17 Valid ] Loss ==> 0.128 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.331 Acc ==> 3.126 F1 ==> 3.126
# [18 Valid ] Loss ==> 0.154 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.274 Acc ==> 3.148 F1 ==> 3.148
# [19 Valid ] Loss ==> 0.127 Acc ==> 3.204 F1 ==> 3.204
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.278 Acc ==> 3.146 F1 ==> 3.146
# [20 Valid ] Loss ==> 0.105 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.211 Acc ==> 3.172 F1 ==> 3.172
# [21 Valid ] Loss ==> 0.083 Acc ==> 3.216 F1 ==> 3.216
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.169 Acc ==> 3.181 F1 ==> 3.181
# [22 Valid ] Loss ==> 0.051 Acc ==> 3.228 F1 ==> 3.228
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.185 Acc ==> 3.180 F1 ==> 3.180
# [23 Valid ] Loss ==> 0.109 Acc ==> 3.209 F1 ==> 3.209
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.222 Acc ==> 3.169 F1 ==> 3.169
# [24 Valid ] Loss ==> 0.218 Acc ==> 3.158 F1 ==> 3.158
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.280 Acc ==> 3.141 F1 ==> 3.141
# [25 Valid ] Loss ==> 0.093 Acc ==> 3.209 F1 ==> 3.209
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.242 Acc ==> 3.164 F1 ==> 3.164
# [26 Valid ] Loss ==> 0.174 Acc ==> 3.178 F1 ==> 3.178
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.221 Acc ==> 3.166 F1 ==> 3.166
# [27 Valid ] Loss ==> 0.104 Acc ==> 3.206 F1 ==> 3.206
#
# Early stopping at epoch 26
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 3.992 Acc ==> 1.703 F1 ==> 1.703
# [1 Valid ] Loss ==> 3.105 Acc ==> 2.018 F1 ==> 2.018
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.049 Acc ==> 2.072 F1 ==> 2.072
# [2 Valid ] Loss ==> 2.308 Acc ==> 2.398 F1 ==> 2.398
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.498 Acc ==> 2.306 F1 ==> 2.306
# [3 Valid ] Loss ==> 1.870 Acc ==> 2.574 F1 ==> 2.574
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.134 Acc ==> 2.451 F1 ==> 2.451
# [4 Valid ] Loss ==> 1.479 Acc ==> 2.705 F1 ==> 2.705
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.771 Acc ==> 2.578 F1 ==> 2.578
# [5 Valid ] Loss ==> 1.137 Acc ==> 2.850 F1 ==> 2.850
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.518 Acc ==> 2.680 F1 ==> 2.680
# [6 Valid ] Loss ==> 1.089 Acc ==> 2.831 F1 ==> 2.831
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.281 Acc ==> 2.764 F1 ==> 2.764
# [7 Valid ] Loss ==> 0.793 Acc ==> 2.975 F1 ==> 2.975
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.077 Acc ==> 2.840 F1 ==> 2.840
# [8 Valid ] Loss ==> 0.716 Acc ==> 2.993 F1 ==> 2.993
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 0.901 Acc ==> 2.901 F1 ==> 2.901
# [9 Valid ] Loss ==> 0.557 Acc ==> 3.048 F1 ==> 3.048
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.813 Acc ==> 2.948 F1 ==> 2.948
# [10 Valid ] Loss ==> 0.535 Acc ==> 3.060 F1 ==> 3.060
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.622 Acc ==> 3.018 F1 ==> 3.018
# [11 Valid ] Loss ==> 0.334 Acc ==> 3.132 F1 ==> 3.132
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.603 Acc ==> 3.022 F1 ==> 3.022
# [12 Valid ] Loss ==> 0.373 Acc ==> 3.122 F1 ==> 3.122
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.531 Acc ==> 3.043 F1 ==> 3.043
# [13 Valid ] Loss ==> 0.276 Acc ==> 3.146 F1 ==> 3.146
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.477 Acc ==> 3.072 F1 ==> 3.072
# [14 Valid ] Loss ==> 0.308 Acc ==> 3.137 F1 ==> 3.137
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.368 Acc ==> 3.114 F1 ==> 3.114
# [15 Valid ] Loss ==> 0.186 Acc ==> 3.185 F1 ==> 3.185
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.389 Acc ==> 3.107 F1 ==> 3.107
# [16 Valid ] Loss ==> 0.144 Acc ==> 3.201 F1 ==> 3.201
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.345 Acc ==> 3.124 F1 ==> 3.124
# [17 Valid ] Loss ==> 0.346 Acc ==> 3.125 F1 ==> 3.125
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.352 Acc ==> 3.121 F1 ==> 3.121
# [18 Valid ] Loss ==> 0.142 Acc ==> 3.199 F1 ==> 3.199
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.368 Acc ==> 3.104 F1 ==> 3.104
# [19 Valid ] Loss ==> 0.171 Acc ==> 3.186 F1 ==> 3.186
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.351 Acc ==> 3.110 F1 ==> 3.110
# [20 Valid ] Loss ==> 0.163 Acc ==> 3.189 F1 ==> 3.189
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.305 Acc ==> 3.136 F1 ==> 3.136
# [21 Valid ] Loss ==> 0.127 Acc ==> 3.203 F1 ==> 3.203
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.260 Acc ==> 3.152 F1 ==> 3.152
# [22 Valid ] Loss ==> 0.106 Acc ==> 3.207 F1 ==> 3.207
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.248 Acc ==> 3.154 F1 ==> 3.154
# [23 Valid ] Loss ==> 0.120 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.224 Acc ==> 3.158 F1 ==> 3.158
# [24 Valid ] Loss ==> 0.102 Acc ==> 3.208 F1 ==> 3.208
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.236 Acc ==> 3.165 F1 ==> 3.165
# [25 Valid ] Loss ==> 0.089 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.215 Acc ==> 3.163 F1 ==> 3.163
# [26 Valid ] Loss ==> 0.162 Acc ==> 3.187 F1 ==> 3.187
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.254 Acc ==> 3.156 F1 ==> 3.156
# [27 Valid ] Loss ==> 0.112 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.181 Acc ==> 3.184 F1 ==> 3.184
# [28 Valid ] Loss ==> 0.057 Acc ==> 3.225 F1 ==> 3.225
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.284 Acc ==> 3.142 F1 ==> 3.142
# [29 Valid ] Loss ==> 0.174 Acc ==> 3.183 F1 ==> 3.183
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.196 Acc ==> 3.168 F1 ==> 3.168
# [30 Valid ] Loss ==> 0.105 Acc ==> 3.203 F1 ==> 3.203
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.116 Acc ==> 1.653 F1 ==> 1.653
# [1 Valid ] Loss ==> 3.256 Acc ==> 1.949 F1 ==> 1.949
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.132 Acc ==> 2.039 F1 ==> 2.039
# [2 Valid ] Loss ==> 2.456 Acc ==> 2.346 F1 ==> 2.346
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.637 Acc ==> 2.234 F1 ==> 2.234
# [3 Valid ] Loss ==> 1.968 Acc ==> 2.540 F1 ==> 2.540
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.224 Acc ==> 2.404 F1 ==> 2.404
# [4 Valid ] Loss ==> 1.552 Acc ==> 2.688 F1 ==> 2.688
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 1.919 Acc ==> 2.522 F1 ==> 2.522
# [5 Valid ] Loss ==> 1.325 Acc ==> 2.769 F1 ==> 2.769
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.626 Acc ==> 2.629 F1 ==> 2.629
# [6 Valid ] Loss ==> 1.023 Acc ==> 2.896 F1 ==> 2.896
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.396 Acc ==> 2.726 F1 ==> 2.726
# [7 Valid ] Loss ==> 0.975 Acc ==> 2.903 F1 ==> 2.903
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.158 Acc ==> 2.808 F1 ==> 2.808
# [8 Valid ] Loss ==> 0.593 Acc ==> 3.058 F1 ==> 3.058
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.043 Acc ==> 2.866 F1 ==> 2.866
# [9 Valid ] Loss ==> 0.649 Acc ==> 3.027 F1 ==> 3.027
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 0.985 Acc ==> 2.882 F1 ==> 2.882
# [10 Valid ] Loss ==> 0.454 Acc ==> 3.100 F1 ==> 3.100
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.735 Acc ==> 2.987 F1 ==> 2.987
# [11 Valid ] Loss ==> 0.545 Acc ==> 3.059 F1 ==> 3.059
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.787 Acc ==> 2.951 F1 ==> 2.951
# [12 Valid ] Loss ==> 0.452 Acc ==> 3.086 F1 ==> 3.086
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.619 Acc ==> 3.029 F1 ==> 3.029
# [13 Valid ] Loss ==> 0.259 Acc ==> 3.163 F1 ==> 3.163
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.543 Acc ==> 3.048 F1 ==> 3.048
# [14 Valid ] Loss ==> 0.334 Acc ==> 3.132 F1 ==> 3.132
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.542 Acc ==> 3.052 F1 ==> 3.052
# [15 Valid ] Loss ==> 0.255 Acc ==> 3.159 F1 ==> 3.159
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.474 Acc ==> 3.077 F1 ==> 3.077
# [16 Valid ] Loss ==> 0.280 Acc ==> 3.154 F1 ==> 3.154
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.447 Acc ==> 3.083 F1 ==> 3.083
# [17 Valid ] Loss ==> 0.199 Acc ==> 3.180 F1 ==> 3.180
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.387 Acc ==> 3.102 F1 ==> 3.102
# [18 Valid ] Loss ==> 0.245 Acc ==> 3.154 F1 ==> 3.154
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.370 Acc ==> 3.115 F1 ==> 3.115
# [19 Valid ] Loss ==> 0.134 Acc ==> 3.196 F1 ==> 3.196
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.343 Acc ==> 3.128 F1 ==> 3.128
# [20 Valid ] Loss ==> 0.160 Acc ==> 3.193 F1 ==> 3.193
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.337 Acc ==> 3.127 F1 ==> 3.127
# [21 Valid ] Loss ==> 0.204 Acc ==> 3.172 F1 ==> 3.172
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.340 Acc ==> 3.121 F1 ==> 3.121
# [22 Valid ] Loss ==> 0.118 Acc ==> 3.210 F1 ==> 3.210
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.319 Acc ==> 3.124 F1 ==> 3.124
# [23 Valid ] Loss ==> 0.131 Acc ==> 3.204 F1 ==> 3.204
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.325 Acc ==> 3.132 F1 ==> 3.132
# [24 Valid ] Loss ==> 0.146 Acc ==> 3.199 F1 ==> 3.199
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.371 Acc ==> 3.108 F1 ==> 3.108
# [25 Valid ] Loss ==> 0.176 Acc ==> 3.181 F1 ==> 3.181
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.284 Acc ==> 3.140 F1 ==> 3.140
# [26 Valid ] Loss ==> 0.107 Acc ==> 3.207 F1 ==> 3.207
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.296 Acc ==> 3.132 F1 ==> 3.132
# [27 Valid ] Loss ==> 0.116 Acc ==> 3.204 F1 ==> 3.204
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.201 Acc ==> 3.181 F1 ==> 3.181
# [28 Valid ] Loss ==> 0.078 Acc ==> 3.217 F1 ==> 3.217
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.167 Acc ==> 3.184 F1 ==> 3.184
# [29 Valid ] Loss ==> 0.063 Acc ==> 3.222 F1 ==> 3.222
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.221 Acc ==> 3.156 F1 ==> 3.156
# [30 Valid ] Loss ==> 0.090 Acc ==> 3.215 F1 ==> 3.215
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.317 Acc ==> 1.590 F1 ==> 1.590
# [1 Valid ] Loss ==> 3.242 Acc ==> 2.028 F1 ==> 2.028
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.308 Acc ==> 1.961 F1 ==> 1.961
# [2 Valid ] Loss ==> 2.621 Acc ==> 2.291 F1 ==> 2.291
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 2.874 Acc ==> 2.167 F1 ==> 2.167
# [3 Valid ] Loss ==> 2.172 Acc ==> 2.487 F1 ==> 2.487
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.419 Acc ==> 2.343 F1 ==> 2.343
# [4 Valid ] Loss ==> 1.854 Acc ==> 2.600 F1 ==> 2.600
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.099 Acc ==> 2.462 F1 ==> 2.462
# [5 Valid ] Loss ==> 1.396 Acc ==> 2.781 F1 ==> 2.781
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 1.846 Acc ==> 2.554 F1 ==> 2.554
# [6 Valid ] Loss ==> 1.295 Acc ==> 2.805 F1 ==> 2.805
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.571 Acc ==> 2.676 F1 ==> 2.676
# [7 Valid ] Loss ==> 1.079 Acc ==> 2.890 F1 ==> 2.890
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.434 Acc ==> 2.724 F1 ==> 2.724
# [8 Valid ] Loss ==> 0.915 Acc ==> 2.937 F1 ==> 2.937
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.288 Acc ==> 2.770 F1 ==> 2.770
# [9 Valid ] Loss ==> 0.926 Acc ==> 2.901 F1 ==> 2.901
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.074 Acc ==> 2.859 F1 ==> 2.859
# [10 Valid ] Loss ==> 0.714 Acc ==> 3.011 F1 ==> 3.011
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 0.991 Acc ==> 2.880 F1 ==> 2.880
# [11 Valid ] Loss ==> 0.521 Acc ==> 3.072 F1 ==> 3.072
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 0.931 Acc ==> 2.905 F1 ==> 2.905
# [12 Valid ] Loss ==> 0.547 Acc ==> 3.060 F1 ==> 3.060
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 0.791 Acc ==> 2.959 F1 ==> 2.959
# [13 Valid ] Loss ==> 0.650 Acc ==> 3.027 F1 ==> 3.027
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.774 Acc ==> 2.962 F1 ==> 2.962
# [14 Valid ] Loss ==> 0.445 Acc ==> 3.079 F1 ==> 3.079
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.631 Acc ==> 3.014 F1 ==> 3.014
# [15 Valid ] Loss ==> 0.327 Acc ==> 3.140 F1 ==> 3.140
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.541 Acc ==> 3.053 F1 ==> 3.053
# [16 Valid ] Loss ==> 0.255 Acc ==> 3.159 F1 ==> 3.159
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.533 Acc ==> 3.052 F1 ==> 3.052
# [17 Valid ] Loss ==> 0.266 Acc ==> 3.153 F1 ==> 3.153
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.574 Acc ==> 3.040 F1 ==> 3.040
# [18 Valid ] Loss ==> 0.349 Acc ==> 3.122 F1 ==> 3.122
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.505 Acc ==> 3.062 F1 ==> 3.062
# [19 Valid ] Loss ==> 0.208 Acc ==> 3.181 F1 ==> 3.181
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.412 Acc ==> 3.103 F1 ==> 3.103
# [20 Valid ] Loss ==> 0.186 Acc ==> 3.184 F1 ==> 3.184
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.398 Acc ==> 3.104 F1 ==> 3.104
# [21 Valid ] Loss ==> 0.192 Acc ==> 3.184 F1 ==> 3.184
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.418 Acc ==> 3.097 F1 ==> 3.097
# [22 Valid ] Loss ==> 0.183 Acc ==> 3.181 F1 ==> 3.181
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.314 Acc ==> 3.141 F1 ==> 3.141
# [23 Valid ] Loss ==> 0.185 Acc ==> 3.183 F1 ==> 3.183
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.401 Acc ==> 3.105 F1 ==> 3.105
# [24 Valid ] Loss ==> 0.213 Acc ==> 3.174 F1 ==> 3.174
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.307 Acc ==> 3.128 F1 ==> 3.128
# [25 Valid ] Loss ==> 0.133 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.336 Acc ==> 3.125 F1 ==> 3.125
# [26 Valid ] Loss ==> 0.257 Acc ==> 3.157 F1 ==> 3.157
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.316 Acc ==> 3.134 F1 ==> 3.134
# [27 Valid ] Loss ==> 0.168 Acc ==> 3.185 F1 ==> 3.185
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.275 Acc ==> 3.150 F1 ==> 3.150
# [28 Valid ] Loss ==> 0.131 Acc ==> 3.194 F1 ==> 3.194
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.284 Acc ==> 3.141 F1 ==> 3.141
# [29 Valid ] Loss ==> 0.114 Acc ==> 3.204 F1 ==> 3.204
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.251 Acc ==> 3.154 F1 ==> 3.154
# [30 Valid ] Loss ==> 0.121 Acc ==> 3.204 F1 ==> 3.204
#
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 4.718 Acc ==> 1.496 F1 ==> 1.496
# [1 Valid ] Loss ==> 3.567 Acc ==> 1.932 F1 ==> 1.932
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.591 Acc ==> 1.882 F1 ==> 1.882
# [2 Valid ] Loss ==> 2.851 Acc ==> 2.213 F1 ==> 2.213
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.103 Acc ==> 2.078 F1 ==> 2.078
# [3 Valid ] Loss ==> 2.350 Acc ==> 2.429 F1 ==> 2.429
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.660 Acc ==> 2.271 F1 ==> 2.271
# [4 Valid ] Loss ==> 2.121 Acc ==> 2.478 F1 ==> 2.478
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.339 Acc ==> 2.371 F1 ==> 2.371
# [5 Valid ] Loss ==> 1.624 Acc ==> 2.670 F1 ==> 2.670
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.017 Acc ==> 2.499 F1 ==> 2.499
# [6 Valid ] Loss ==> 1.452 Acc ==> 2.734 F1 ==> 2.734
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 1.800 Acc ==> 2.596 F1 ==> 2.596
# [7 Valid ] Loss ==> 1.234 Acc ==> 2.822 F1 ==> 2.822
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.670 Acc ==> 2.630 F1 ==> 2.630
# [8 Valid ] Loss ==> 1.069 Acc ==> 2.877 F1 ==> 2.877
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.430 Acc ==> 2.733 F1 ==> 2.733
# [9 Valid ] Loss ==> 0.962 Acc ==> 2.924 F1 ==> 2.924
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.281 Acc ==> 2.786 F1 ==> 2.786
# [10 Valid ] Loss ==> 0.727 Acc ==> 3.007 F1 ==> 3.007
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.165 Acc ==> 2.833 F1 ==> 2.833
# [11 Valid ] Loss ==> 0.795 Acc ==> 2.985 F1 ==> 2.985
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.088 Acc ==> 2.865 F1 ==> 2.865
# [12 Valid ] Loss ==> 0.766 Acc ==> 2.974 F1 ==> 2.974
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.003 Acc ==> 2.900 F1 ==> 2.900
# [13 Valid ] Loss ==> 0.516 Acc ==> 3.083 F1 ==> 3.083
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 0.835 Acc ==> 2.942 F1 ==> 2.942
# [14 Valid ] Loss ==> 0.482 Acc ==> 3.085 F1 ==> 3.085
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.773 Acc ==> 2.975 F1 ==> 2.975
# [15 Valid ] Loss ==> 0.373 Acc ==> 3.120 F1 ==> 3.120
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.717 Acc ==> 2.994 F1 ==> 2.994
# [16 Valid ] Loss ==> 0.536 Acc ==> 3.052 F1 ==> 3.052
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.634 Acc ==> 3.020 F1 ==> 3.020
# [17 Valid ] Loss ==> 0.310 Acc ==> 3.150 F1 ==> 3.150
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.623 Acc ==> 3.022 F1 ==> 3.022
# [18 Valid ] Loss ==> 0.263 Acc ==> 3.164 F1 ==> 3.164
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.555 Acc ==> 3.058 F1 ==> 3.058
# [19 Valid ] Loss ==> 0.210 Acc ==> 3.182 F1 ==> 3.182
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.558 Acc ==> 3.038 F1 ==> 3.038
# [20 Valid ] Loss ==> 0.247 Acc ==> 3.164 F1 ==> 3.164
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.576 Acc ==> 3.032 F1 ==> 3.032
# [21 Valid ] Loss ==> 0.589 Acc ==> 3.029 F1 ==> 3.029
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.487 Acc ==> 3.077 F1 ==> 3.077
# [22 Valid ] Loss ==> 0.158 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.409 Acc ==> 3.096 F1 ==> 3.096
# [23 Valid ] Loss ==> 0.169 Acc ==> 3.196 F1 ==> 3.196
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.401 Acc ==> 3.108 F1 ==> 3.108
# [24 Valid ] Loss ==> 0.182 Acc ==> 3.185 F1 ==> 3.185
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.346 Acc ==> 3.126 F1 ==> 3.126
# [25 Valid ] Loss ==> 0.129 Acc ==> 3.206 F1 ==> 3.206
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.434 Acc ==> 3.088 F1 ==> 3.088
# [26 Valid ] Loss ==> 0.202 Acc ==> 3.178 F1 ==> 3.178
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.354 Acc ==> 3.127 F1 ==> 3.127
# [27 Valid ] Loss ==> 0.397 Acc ==> 3.113 F1 ==> 3.113
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.320 Acc ==> 3.138 F1 ==> 3.138
# [28 Valid ] Loss ==> 0.138 Acc ==> 3.198 F1 ==> 3.198
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.341 Acc ==> 3.124 F1 ==> 3.124
# [29 Valid ] Loss ==> 0.170 Acc ==> 3.188 F1 ==> 3.188
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.348 Acc ==> 3.122 F1 ==> 3.122
# [30 Valid ] Loss ==> 0.165 Acc ==> 3.190 F1 ==> 3.190
#
# Early stopping at epoch 29
# Done!
# [Epoch 1/30] ....
# [1 Train ] Loss ==> 5.301 Acc ==> 1.410 F1 ==> 1.410
# [1 Valid ] Loss ==> 4.032 Acc ==> 1.889 F1 ==> 1.889
#
# [Epoch 2/30] ....
# [2 Train ] Loss ==> 3.955 Acc ==> 1.840 F1 ==> 1.840
# [2 Valid ] Loss ==> 3.249 Acc ==> 2.140 F1 ==> 2.140
#
# [Epoch 3/30] ....
# [3 Train ] Loss ==> 3.393 Acc ==> 2.013 F1 ==> 2.013
# [3 Valid ] Loss ==> 2.782 Acc ==> 2.271 F1 ==> 2.271
#
# [Epoch 4/30] ....
# [4 Train ] Loss ==> 2.952 Acc ==> 2.176 F1 ==> 2.176
# [4 Valid ] Loss ==> 2.421 Acc ==> 2.401 F1 ==> 2.401
#
# [Epoch 5/30] ....
# [5 Train ] Loss ==> 2.625 Acc ==> 2.309 F1 ==> 2.309
# [5 Valid ] Loss ==> 2.061 Acc ==> 2.527 F1 ==> 2.527
#
# [Epoch 6/30] ....
# [6 Train ] Loss ==> 2.319 Acc ==> 2.413 F1 ==> 2.413
# [6 Valid ] Loss ==> 1.674 Acc ==> 2.701 F1 ==> 2.701
#
# [Epoch 7/30] ....
# [7 Train ] Loss ==> 2.065 Acc ==> 2.526 F1 ==> 2.526
# [7 Valid ] Loss ==> 1.439 Acc ==> 2.762 F1 ==> 2.762
#
# [Epoch 8/30] ....
# [8 Train ] Loss ==> 1.930 Acc ==> 2.554 F1 ==> 2.554
# [8 Valid ] Loss ==> 1.336 Acc ==> 2.814 F1 ==> 2.814
#
# [Epoch 9/30] ....
# [9 Train ] Loss ==> 1.679 Acc ==> 2.661 F1 ==> 2.661
# [9 Valid ] Loss ==> 1.382 Acc ==> 2.760 F1 ==> 2.760
#
# [Epoch 10/30] ....
# [10 Train ] Loss ==> 1.595 Acc ==> 2.662 F1 ==> 2.662
# [10 Valid ] Loss ==> 1.294 Acc ==> 2.795 F1 ==> 2.795
#
# [Epoch 11/30] ....
# [11 Train ] Loss ==> 1.375 Acc ==> 2.765 F1 ==> 2.765
# [11 Valid ] Loss ==> 0.914 Acc ==> 2.939 F1 ==> 2.939
#
# [Epoch 12/30] ....
# [12 Train ] Loss ==> 1.239 Acc ==> 2.821 F1 ==> 2.821
# [12 Valid ] Loss ==> 0.835 Acc ==> 2.966 F1 ==> 2.966
#
# [Epoch 13/30] ....
# [13 Train ] Loss ==> 1.090 Acc ==> 2.862 F1 ==> 2.862
# [13 Valid ] Loss ==> 0.648 Acc ==> 3.043 F1 ==> 3.043
#
# [Epoch 14/30] ....
# [14 Train ] Loss ==> 1.111 Acc ==> 2.862 F1 ==> 2.862
# [14 Valid ] Loss ==> 0.639 Acc ==> 3.022 F1 ==> 3.022
#
# [Epoch 15/30] ....
# [15 Train ] Loss ==> 0.960 Acc ==> 2.915 F1 ==> 2.915
# [15 Valid ] Loss ==> 0.529 Acc ==> 3.084 F1 ==> 3.084
#
# [Epoch 16/30] ....
# [16 Train ] Loss ==> 0.911 Acc ==> 2.934 F1 ==> 2.934
# [16 Valid ] Loss ==> 0.393 Acc ==> 3.126 F1 ==> 3.126
#
# [Epoch 17/30] ....
# [17 Train ] Loss ==> 0.767 Acc ==> 2.984 F1 ==> 2.984
# [17 Valid ] Loss ==> 0.418 Acc ==> 3.105 F1 ==> 3.105
#
# [Epoch 18/30] ....
# [18 Train ] Loss ==> 0.790 Acc ==> 2.979 F1 ==> 2.979
# [18 Valid ] Loss ==> 0.376 Acc ==> 3.132 F1 ==> 3.132
#
# [Epoch 19/30] ....
# [19 Train ] Loss ==> 0.708 Acc ==> 2.996 F1 ==> 2.996
# [19 Valid ] Loss ==> 0.308 Acc ==> 3.152 F1 ==> 3.152
#
# [Epoch 20/30] ....
# [20 Train ] Loss ==> 0.689 Acc ==> 3.012 F1 ==> 3.012
# [20 Valid ] Loss ==> 0.372 Acc ==> 3.125 F1 ==> 3.125
#
# [Epoch 21/30] ....
# [21 Train ] Loss ==> 0.613 Acc ==> 3.040 F1 ==> 3.040
# [21 Valid ] Loss ==> 0.317 Acc ==> 3.144 F1 ==> 3.144
#
# [Epoch 22/30] ....
# [22 Train ] Loss ==> 0.569 Acc ==> 3.051 F1 ==> 3.051
# [22 Valid ] Loss ==> 0.285 Acc ==> 3.153 F1 ==> 3.153
#
# [Epoch 23/30] ....
# [23 Train ] Loss ==> 0.571 Acc ==> 3.046 F1 ==> 3.046
# [23 Valid ] Loss ==> 0.266 Acc ==> 3.162 F1 ==> 3.162
#
# [Epoch 24/30] ....
# [24 Train ] Loss ==> 0.514 Acc ==> 3.064 F1 ==> 3.064
# [24 Valid ] Loss ==> 0.242 Acc ==> 3.166 F1 ==> 3.166
#
# [Epoch 25/30] ....
# [25 Train ] Loss ==> 0.558 Acc ==> 3.063 F1 ==> 3.063
# [25 Valid ] Loss ==> 0.202 Acc ==> 3.184 F1 ==> 3.184
#
# [Epoch 26/30] ....
# [26 Train ] Loss ==> 0.411 Acc ==> 3.108 F1 ==> 3.108
# [26 Valid ] Loss ==> 0.183 Acc ==> 3.185 F1 ==> 3.185
#
# [Epoch 27/30] ....
# [27 Train ] Loss ==> 0.398 Acc ==> 3.107 F1 ==> 3.107
# [27 Valid ] Loss ==> 0.151 Acc ==> 3.197 F1 ==> 3.197
#
# [Epoch 28/30] ....
# [28 Train ] Loss ==> 0.380 Acc ==> 3.116 F1 ==> 3.116
# [28 Valid ] Loss ==> 0.118 Acc ==> 3.212 F1 ==> 3.212
#
# [Epoch 29/30] ....
# [29 Train ] Loss ==> 0.357 Acc ==> 3.121 F1 ==> 3.121
# [29 Valid ] Loss ==> 0.187 Acc ==> 3.186 F1 ==> 3.186
#
# [Epoch 30/30] ....
# [30 Train ] Loss ==> 0.417 Acc ==> 3.107 F1 ==> 3.107
# [30 Valid ] Loss ==> 0.141 Acc ==> 3.199 F1 ==> 3.199
#
# Done!

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].plot(loss_list[0], label = "Train Loss")
axes[0].legend(loc="upper left")
axes[0].set_xlabel("Number of hidden layer", size = 15)
axes[0].set_ylabel("Train Loss", size = 15)
axes[0].set_xticks(np.arange(7))
axes[0].set_xticklabels(np.arange(1, 8))
axes[0].grid()
axes2 = axes[0].twinx()
axes2.plot(loss_list[1], label = "Valid Loss", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Loss", size = 15)

axes[1].plot(acc_list[0], label = "Train Accuracy")
axes[1].legend(loc="upper left")
axes[1].set_xlabel("Number of hidden layer", size = 15)
axes[1].set_ylabel("Train Accuracy", size = 15)
axes[1].set_xticks(np.arange(7))
axes[1].set_xticklabels(np.arange(1, 8))
axes[1].grid()
axes2 = axes[1].twinx()
axes2.plot(acc_list[1], label = "Valid Accuracy", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid Accuracy", size = 15)

axes[2].plot(f1_score_list[0], label = "Train F1 score")
axes[2].legend(loc="upper left")
axes[2].set_xlabel("Number of hidden layer", size = 15)
axes[2].set_ylabel("Train F1 score", size = 15)
axes[2].set_xticks(np.arange(7))
axes[2].set_xticklabels(np.arange(1, 8))
axes[2].grid()
axes2 = axes[2].twinx()
axes2.plot(f1_score_list[1], label = "Valid F1 score", color = "red")
axes2.legend(loc="upper right")
axes2.set_ylabel("Valid F1 score", size = 15)
plt.tight_layout()
plt.show()
