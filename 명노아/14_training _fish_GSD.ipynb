# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
# https://www.kaggle.com/datasets/crowww/a-large-scale-fish-dataset

# %%
feature = pd.read_pickle("feature2.pkl")
target = pd.read_pickle("target2.pkl")

# %%
x_train, x_test, y_train, y_test = train_test_split(feature, target, test_size=0.1, random_state=42, stratify=target)
x_valid, x_test, y_valid, y_test = train_test_split(x_test, y_test, test_size=0.1, random_state=42, stratify=y_test)

# %%
x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((8100, 2655), (810, 2655), (90, 2655))

# %%
x_train = torch.tensor(x_train.values, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.long)
x_valid = torch.tensor(x_valid.values, dtype=torch.float32)
y_valid = torch.tensor(y_valid.values, dtype=torch.long)
x_test = torch.tensor(x_test.values, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.long)

# %%
# 데이터셋 생성
import torch.utils.data.dataloader as dataloader
import torch.utils.data.dataset as dataset

class MyDataset(dataset.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __len__(self):
        return len(self.x)
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
dataset_train = MyDataset(x_train, y_train)
dataset_test = MyDataset(x_test, y_test)
dataset_valid = MyDataset(x_valid, y_valid)

# %%
x_train.shape
# Out:
# torch.Size([8100, 2655])

# %%
class model(nn.Module): # 가중치 초기화 
    def __init__(self):
        super(model, self).__init__()
        self.fc1 = nn.Linear(2655, 1000)
        self.fc2 = nn.Linear(1000, 9)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model2 = model()
for name, child in model2.named_children():
    nn.init.kaiming_normal_(child.weight)
optimizer = optim.SGD(model2.parameters())
criterion = nn.CrossEntropyLoss()

train_loader = dataloader.DataLoader(dataset_train, batch_size=100, shuffle=True, drop_last=True)
test_loader = dataloader.DataLoader(dataset_test, batch_size=100, shuffle=True, drop_last=True)
valid_loader = dataloader.DataLoader(dataset_valid, batch_size=100, shuffle=True, drop_last=True)

# %%
from torchmetrics.functional.classification import accuracy, f1_score
model2.train()
valid_score=[]
train_score=[]

for epoch in range(100):
    
    for x,y in train_loader:
        output = model2(x)
        loss = criterion(output, y.squeeze())
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    with torch.no_grad():        
        print(f"================================={epoch}=================================")
        output = model2(x_train)
        acc = accuracy(output, y_train.squeeze(), task="multiclass", num_classes=9, average="macro")
        f1 = f1_score(output, y_train.squeeze(), task="multiclass", num_classes=9, average="macro")
        train_score.append([acc, f1])
        print(f"train => acc : {acc}, f1 : {f1}")
        
        
        output = model2(x_valid)
        print(f"=================================valid score=================================")
        acc2 = accuracy(output, y_valid.squeeze(), task="multiclass", num_classes=9, average="macro")
        f12 = f1_score(output, y_valid.squeeze(), task="multiclass", num_classes=9, average="macro")
        valid_score.append([acc2, f12])
        print(f"valid => acc : {acc2}, f1 : {f12}")
# Out:
# =================================0=================================
# train => acc : 0.13012346625328064, f1 : 0.05111805722117424
# =================================valid score=================================
# valid => acc : 0.1358024775981903, f1 : 0.05649019405245781
# =================================1=================================
# train => acc : 0.13567900657653809, f1 : 0.05244565010070801
# =================================valid score=================================
# valid => acc : 0.1358024626970291, f1 : 0.0507383719086647
# =================================2=================================
# train => acc : 0.14222222566604614, f1 : 0.06535573303699493
# =================================valid score=================================
# valid => acc : 0.14320987462997437, f1 : 0.06566815823316574
# =================================3=================================
# train => acc : 0.1527160406112671, f1 : 0.07513444870710373
# =================================valid score=================================
# valid => acc : 0.15555554628372192, f1 : 0.07629961520433426
# =================================4=================================
# train => acc : 0.1613580286502838, f1 : 0.0837804451584816
# =================================valid score=================================
# valid => acc : 0.16296297311782837, f1 : 0.08968263119459152
# =================================5=================================
# train => acc : 0.17000000178813934, f1 : 0.09504173696041107
# =================================valid score=================================
# valid => acc : 0.17037037014961243, f1 : 0.09748150408267975
# =================================6=================================
# train => acc : 0.18197530508041382, f1 : 0.11023186892271042
# =================================valid score=================================
# valid => acc : 0.18395061790943146, f1 : 0.11329134553670883
# =================================7=================================
# train => acc : 0.19567900896072388, f1 : 0.12912121415138245
# =================================valid score=================================
# valid => acc : 0.20370371639728546, f1 : 0.13238173723220825
# =================================8=================================
# train => acc : 0.21790124475955963, f1 : 0.15590979158878326
# =================================valid score=================================
# valid => acc : 0.2172839641571045, f1 : 0.15158013999462128
# =================================9=================================
# train => acc : 0.24123455584049225, f1 : 0.1800895780324936
# =================================valid score=================================
# valid => acc : 0.22962963581085205, f1 : 0.16729862987995148
# =================================10=================================
# train => acc : 0.26506173610687256, f1 : 0.20248590409755707
# =================================valid score=================================
# valid => acc : 0.2530864179134369, f1 : 0.19166269898414612
# =================================11=================================
# train => acc : 0.2754320800304413, f1 : 0.21090924739837646
# =================================valid score=================================
# valid => acc : 0.26419752836227417, f1 : 0.20241011679172516
# =================================12=================================
# train => acc : 0.2854320704936981, f1 : 0.21748222410678864
# =================================valid score=================================
# valid => acc : 0.2790123224258423, f1 : 0.21384480595588684
# =================================13=================================
# train => acc : 0.3006172776222229, f1 : 0.2319050431251526
# =================================valid score=================================
# valid => acc : 0.2888889014720917, f1 : 0.22327812016010284
# =================================14=================================
# train => acc : 0.30580246448516846, f1 : 0.2350110113620758
# =================================valid score=================================
# valid => acc : 0.2975308299064636, f1 : 0.23046529293060303
# =================================15=================================
# train => acc : 0.3119753301143646, f1 : 0.24048329889774323
# =================================valid score=================================
# valid => acc : 0.29999998211860657, f1 : 0.2330034375190735
# =================================16=================================
# train => acc : 0.3167901039123535, f1 : 0.24446524679660797
# =================================valid score=================================
# valid => acc : 0.3024691343307495, f1 : 0.2345503568649292
# =================================17=================================
# train => acc : 0.3243209719657898, f1 : 0.2537132799625397
# =================================valid score=================================
# valid => acc : 0.31111109256744385, f1 : 0.24645280838012695
# =================================18=================================
# train => acc : 0.3269135653972626, f1 : 0.2568543255329132
# =================================valid score=================================
# valid => acc : 0.31481480598449707, f1 : 0.2501426041126251
# =================================19=================================
# train => acc : 0.3301234543323517, f1 : 0.2608448565006256
# =================================valid score=================================
# valid => acc : 0.31481480598449707, f1 : 0.25472375750541687
# =================================20=================================
# train => acc : 0.33444443345069885, f1 : 0.26615187525749207
# =================================valid score=================================
# valid => acc : 0.32222220301628113, f1 : 0.2615492045879364
# =================================21=================================
# train => acc : 0.33753088116645813, f1 : 0.2702900767326355
# =================================valid score=================================
# valid => acc : 0.32716047763824463, f1 : 0.26896601915359497
# =================================22=================================
# train => acc : 0.3435802459716797, f1 : 0.2803831100463867
# =================================valid score=================================
# valid => acc : 0.3333333432674408, f1 : 0.28143635392189026
# =================================23=================================
# train => acc : 0.3472839593887329, f1 : 0.2866590619087219
# =================================valid score=================================
# valid => acc : 0.3382716178894043, f1 : 0.2879519760608673
# =================================24=================================
# train => acc : 0.35061725974082947, f1 : 0.2919318974018097
# =================================valid score=================================
# valid => acc : 0.33703702688217163, f1 : 0.28719183802604675
# =================================25=================================
# train => acc : 0.35592591762542725, f1 : 0.2995094656944275
# =================================valid score=================================
# valid => acc : 0.3395061790943146, f1 : 0.2898079454898834
# =================================26=================================
# train => acc : 0.3607407510280609, f1 : 0.308698445558548
# =================================valid score=================================
# valid => acc : 0.3444444239139557, f1 : 0.2965668737888336
# =================================27=================================
# train => acc : 0.3650617003440857, f1 : 0.3154718577861786
# =================================valid score=================================
# valid => acc : 0.35185182094573975, f1 : 0.31009867787361145
# =================================28=================================
# train => acc : 0.3719753324985504, f1 : 0.3267446756362915
# =================================valid score=================================
# valid => acc : 0.3580247163772583, f1 : 0.31877854466438293
# =================================29=================================
# train => acc : 0.3735801875591278, f1 : 0.33010610938072205
# =================================valid score=================================
# valid => acc : 0.36666667461395264, f1 : 0.3287736177444458
# =================================30=================================
# train => acc : 0.37827157974243164, f1 : 0.3380506932735443
# =================================valid score=================================
# valid => acc : 0.37037035822868347, f1 : 0.33539384603500366
# =================================31=================================
# train => acc : 0.3808642029762268, f1 : 0.3423098623752594
# =================================valid score=================================
# valid => acc : 0.37160491943359375, f1 : 0.3377515375614166
# =================================32=================================
# train => acc : 0.3827160596847534, f1 : 0.3454318046569824
# =================================valid score=================================
# valid => acc : 0.375308632850647, f1 : 0.3418732285499573
# =================================33=================================
# train => acc : 0.3858024477958679, f1 : 0.34978604316711426
# =================================valid score=================================
# valid => acc : 0.3740741014480591, f1 : 0.3405834138393402
# =================================34=================================
# train => acc : 0.3876543641090393, f1 : 0.3538910150527954
# =================================valid score=================================
# valid => acc : 0.38148149847984314, f1 : 0.35004258155822754
# =================================35=================================
# train => acc : 0.3919752836227417, f1 : 0.36009037494659424
# =================================valid score=================================
# valid => acc : 0.3827160894870758, f1 : 0.35339847207069397
# =================================36=================================
# train => acc : 0.39530864357948303, f1 : 0.3641330301761627
# =================================valid score=================================
# valid => acc : 0.3814815282821655, f1 : 0.35327669978141785
# =================================37=================================
# train => acc : 0.3974074125289917, f1 : 0.367617666721344
# =================================valid score=================================
# valid => acc : 0.38641980290412903, f1 : 0.3584493100643158
# =================================38=================================
# train => acc : 0.40160495042800903, f1 : 0.3736518919467926
# =================================valid score=================================
# valid => acc : 0.38641977310180664, f1 : 0.35958316922187805
# =================================39=================================
# train => acc : 0.40567898750305176, f1 : 0.3791898488998413
# =================================valid score=================================
# valid => acc : 0.3901234567165375, f1 : 0.3639988899230957
# =================================40=================================
# train => acc : 0.4086419343948364, f1 : 0.3831367492675781
# =================================valid score=================================
# valid => acc : 0.39012348651885986, f1 : 0.36407044529914856
# =================================41=================================
# train => acc : 0.4116049110889435, f1 : 0.38732215762138367
# =================================valid score=================================
# valid => acc : 0.39135801792144775, f1 : 0.3661666810512543
# =================================42=================================
# train => acc : 0.41419756412506104, f1 : 0.3901175856590271
# =================================valid score=================================
# valid => acc : 0.3938271701335907, f1 : 0.3689083158969879
# =================================43=================================
# train => acc : 0.41641974449157715, f1 : 0.3936106562614441
# =================================valid score=================================
# valid => acc : 0.40123456716537476, f1 : 0.3796742558479309
# =================================44=================================
# train => acc : 0.41765427589416504, f1 : 0.3951250910758972
# =================================valid score=================================
# valid => acc : 0.404938280582428, f1 : 0.3846796154975891
# =================================45=================================
# train => acc : 0.41864195466041565, f1 : 0.3969214856624603
# =================================valid score=================================
# valid => acc : 0.40617287158966064, f1 : 0.38631725311279297
# =================================46=================================
# train => acc : 0.4193826913833618, f1 : 0.3979291319847107
# =================================valid score=================================
# valid => acc : 0.40740740299224854, f1 : 0.3876411020755768
# =================================47=================================
# train => acc : 0.42135804891586304, f1 : 0.4005468189716339
# =================================valid score=================================
# valid => acc : 0.4098765552043915, f1 : 0.3912096619606018
# =================================48=================================
# train => acc : 0.4245678782463074, f1 : 0.4046775996685028
# =================================valid score=================================
# valid => acc : 0.41234567761421204, f1 : 0.39547106623649597
# =================================49=================================
# train => acc : 0.4270370304584503, f1 : 0.40777745842933655
# =================================valid score=================================
# valid => acc : 0.4148148000240326, f1 : 0.39781108498573303
# =================================50=================================
# train => acc : 0.4276543855667114, f1 : 0.4085531532764435
# =================================valid score=================================
# valid => acc : 0.4185185432434082, f1 : 0.40136536955833435
# =================================51=================================
# train => acc : 0.4287654459476471, f1 : 0.41049492359161377
# =================================valid score=================================
# valid => acc : 0.42098766565322876, f1 : 0.4044806957244873
# =================================52=================================
# train => acc : 0.4311111271381378, f1 : 0.4130338728427887
# =================================valid score=================================
# valid => acc : 0.41728395223617554, f1 : 0.4014737606048584
# =================================53=================================
# train => acc : 0.4314814805984497, f1 : 0.4137652516365051
# =================================valid score=================================
# valid => acc : 0.42222222685813904, f1 : 0.406891793012619
# =================================54=================================
# train => acc : 0.43444445729255676, f1 : 0.4172772169113159
# =================================valid score=================================
# valid => acc : 0.42592594027519226, f1 : 0.4105434715747833
# =================================55=================================
# train => acc : 0.4362963140010834, f1 : 0.41943487524986267
# =================================valid score=================================
# valid => acc : 0.4296296238899231, f1 : 0.4155237674713135
# =================================56=================================
# train => acc : 0.4369135797023773, f1 : 0.42029663920402527
# =================================valid score=================================
# valid => acc : 0.42839503288269043, f1 : 0.41396477818489075
# =================================57=================================
# train => acc : 0.438024640083313, f1 : 0.42196565866470337
# =================================valid score=================================
# valid => acc : 0.4283950924873352, f1 : 0.4153117537498474
# =================================58=================================
# train => acc : 0.43975308537483215, f1 : 0.4236472547054291
# =================================valid score=================================
# valid => acc : 0.434567928314209, f1 : 0.42105090618133545
# =================================59=================================
# train => acc : 0.440740704536438, f1 : 0.42487573623657227
# =================================valid score=================================
# valid => acc : 0.43209877610206604, f1 : 0.41902604699134827
# =================================60=================================
# train => acc : 0.44283947348594666, f1 : 0.4275306463241577
# =================================valid score=================================
# valid => acc : 0.4333333671092987, f1 : 0.420481413602829
# =================================61=================================
# train => acc : 0.4440740644931793, f1 : 0.42879003286361694
# =================================valid score=================================
# valid => acc : 0.43580248951911926, f1 : 0.42261895537376404
# =================================62=================================
# train => acc : 0.44555553793907166, f1 : 0.4308473765850067
# =================================valid score=================================
# valid => acc : 0.4382716119289398, f1 : 0.4257704019546509
# =================================63=================================
# train => acc : 0.4476543068885803, f1 : 0.4331170618534088
# =================================valid score=================================
# valid => acc : 0.43580248951911926, f1 : 0.4233033061027527
# =================================64=================================
# train => acc : 0.44728395342826843, f1 : 0.4328919053077698
# =================================valid score=================================
# valid => acc : 0.43703705072402954, f1 : 0.42455804347991943
# =================================65=================================
# train => acc : 0.44777774810791016, f1 : 0.43343642354011536
# =================================valid score=================================
# valid => acc : 0.44074076414108276, f1 : 0.42851802706718445
# =================================66=================================
# train => acc : 0.4498765468597412, f1 : 0.4359649419784546
# =================================valid score=================================
# valid => acc : 0.4444444477558136, f1 : 0.4328371286392212
# =================================67=================================
# train => acc : 0.4528394937515259, f1 : 0.43925580382347107
# =================================valid score=================================
# valid => acc : 0.4382716119289398, f1 : 0.42674723267555237
# =================================68=================================
# train => acc : 0.4543209969997406, f1 : 0.4410693049430847
# =================================valid score=================================
# valid => acc : 0.4456790089607239, f1 : 0.4350677728652954
# =================================69=================================
# train => acc : 0.4543209969997406, f1 : 0.44141480326652527
# =================================valid score=================================
# valid => acc : 0.4481481611728668, f1 : 0.43704238533973694
# =================================70=================================
# train => acc : 0.45592594146728516, f1 : 0.4431048333644867
# =================================valid score=================================
# valid => acc : 0.44691359996795654, f1 : 0.43554189801216125
# =================================71=================================
# train => acc : 0.456913560628891, f1 : 0.4440307915210724
# =================================valid score=================================
# valid => acc : 0.44691359996795654, f1 : 0.4359988570213318
# =================================72=================================
# train => acc : 0.45814812183380127, f1 : 0.4453549087047577
# =================================valid score=================================
# valid => acc : 0.45061731338500977, f1 : 0.4401337802410126
# =================================73=================================
# train => acc : 0.4604938328266144, f1 : 0.44791078567504883
# =================================valid score=================================
# valid => acc : 0.44814813137054443, f1 : 0.4376828968524933
# =================================74=================================
# train => acc : 0.4601233899593353, f1 : 0.44781869649887085
# =================================valid score=================================
# valid => acc : 0.45185184478759766, f1 : 0.44139498472213745
# =================================75=================================
# train => acc : 0.46222221851348877, f1 : 0.44990071654319763
# =================================valid score=================================
# valid => acc : 0.4481481909751892, f1 : 0.4381507933139801
# =================================76=================================
# train => acc : 0.46296295523643494, f1 : 0.45085689425468445
# =================================valid score=================================
# valid => acc : 0.45185187458992004, f1 : 0.4416603744029999
# =================================77=================================
# train => acc : 0.4641975164413452, f1 : 0.45230185985565186
# =================================valid score=================================
# valid => acc : 0.4506172835826874, f1 : 0.440414160490036
# =================================78=================================
# train => acc : 0.4656790494918823, f1 : 0.4538039565086365
# =================================valid score=================================
# valid => acc : 0.454321026802063, f1 : 0.4442262649536133
# =================================79=================================
# train => acc : 0.46740737557411194, f1 : 0.45551085472106934
# =================================valid score=================================
# valid => acc : 0.4493827521800995, f1 : 0.43942031264305115
# =================================80=================================
# train => acc : 0.46925923228263855, f1 : 0.45732393860816956
# =================================valid score=================================
# valid => acc : 0.45185187458992004, f1 : 0.4417908489704132
# =================================81=================================
# train => acc : 0.4696296453475952, f1 : 0.45776504278182983
# =================================valid score=================================
# valid => acc : 0.45555558800697327, f1 : 0.44540971517562866
# =================================82=================================
# train => acc : 0.47160494327545166, f1 : 0.45994144678115845
# =================================valid score=================================
# valid => acc : 0.4592593014240265, f1 : 0.4489739239215851
# =================================83=================================
# train => acc : 0.4724690914154053, f1 : 0.46091604232788086
# =================================valid score=================================
# valid => acc : 0.4555555582046509, f1 : 0.44551989436149597
# =================================84=================================
# train => acc : 0.47320985794067383, f1 : 0.4615185856819153
# =================================valid score=================================
# valid => acc : 0.4592593014240265, f1 : 0.44861477613449097
# =================================85=================================
# train => acc : 0.4743209779262543, f1 : 0.4628467559814453
# =================================valid score=================================
# valid => acc : 0.45555558800697327, f1 : 0.44541627168655396
# =================================86=================================
# train => acc : 0.47604936361312866, f1 : 0.4646488428115845
# =================================valid score=================================
# valid => acc : 0.4592592716217041, f1 : 0.44867879152297974
# =================================87=================================
# train => acc : 0.4770370423793793, f1 : 0.4659031629562378
# =================================valid score=================================
# valid => acc : 0.4592592716217041, f1 : 0.4489479064941406
# =================================88=================================
# train => acc : 0.47913581132888794, f1 : 0.4679892659187317
# =================================valid score=================================
# valid => acc : 0.4555555582046509, f1 : 0.4461902379989624
# =================================89=================================
# train => acc : 0.478518545627594, f1 : 0.4672854542732239
# =================================valid score=================================
# valid => acc : 0.46172839403152466, f1 : 0.4521314799785614
# =================================90=================================
# train => acc : 0.4793826639652252, f1 : 0.46836209297180176
# =================================valid score=================================
# valid => acc : 0.45679011940956116, f1 : 0.44762080907821655
# =================================91=================================
# train => acc : 0.4812345504760742, f1 : 0.4703684151172638
# =================================valid score=================================
# valid => acc : 0.45802468061447144, f1 : 0.44871288537979126
# =================================92=================================
# train => acc : 0.48049381375312805, f1 : 0.4696498215198517
# =================================valid score=================================
# valid => acc : 0.4604937732219696, f1 : 0.45124486088752747
# =================================93=================================
# train => acc : 0.48271599411964417, f1 : 0.472085565328598
# =================================valid score=================================
# valid => acc : 0.46296292543411255, f1 : 0.4533245265483856
# =================================94=================================
# train => acc : 0.48419755697250366, f1 : 0.4737681746482849
# =================================valid score=================================
# valid => acc : 0.46296292543411255, f1 : 0.45339298248291016
# =================================95=================================
# train => acc : 0.4851852357387543, f1 : 0.4752175211906433
# =================================valid score=================================
# valid => acc : 0.4641975164413452, f1 : 0.4547860622406006
# =================================96=================================
# train => acc : 0.4855555593967438, f1 : 0.4754776060581207
# =================================valid score=================================
# valid => acc : 0.4654320776462555, f1 : 0.4555419087409973
# =================================97=================================
# train => acc : 0.4865432381629944, f1 : 0.47671157121658325
# =================================valid score=================================
# valid => acc : 0.4641975462436676, f1 : 0.45434126257896423
# =================================98=================================
# train => acc : 0.48679012060165405, f1 : 0.4770549535751343
# =================================valid score=================================
# valid => acc : 0.4641975164413452, f1 : 0.4546539783477783
# =================================99=================================
# train => acc : 0.4899999797344208, f1 : 0.4802827835083008
# =================================valid score=================================
# valid => acc : 0.46913576126098633, f1 : 0.45970356464385986

# %%
torch.save(model2,"./SGD_model.pth")

# %%
import torch
from torchmetrics.functional.classification import accuracy, f1_score
model2=model()
model2 = torch.load("./SGD_model.pth")

output = model2(x_test)
print(f"=================================test score=================================")
print(accuracy(output, y_test.squeeze(), task="multiclass", num_classes=9, average="macro"))
print(f1_score(output, y_test.squeeze(), task="multiclass", num_classes=9, average="macro"))
# Out:
# =================================test score=================================
# tensor(0.5222)
# tensor(0.4965)

# %%
train_acc = np.array(train_score)[:,0]
train_f1 = np.array(train_score)[:,1]

valid_acc = np.array(valid_score)[:,0]
valid_f1 = np.array(valid_score)[:,1]

# %%
train_score, valid_score
# Out:
# ([[tensor(0.1301), tensor(0.0511)],
#   [tensor(0.1357), tensor(0.0524)],
#   [tensor(0.1422), tensor(0.0654)],
#   [tensor(0.1527), tensor(0.0751)],
#   [tensor(0.1614), tensor(0.0838)],
#   [tensor(0.1700), tensor(0.0950)],
#   [tensor(0.1820), tensor(0.1102)],
#   [tensor(0.1957), tensor(0.1291)],
#   [tensor(0.2179), tensor(0.1559)],
#   [tensor(0.2412), tensor(0.1801)],
#   [tensor(0.2651), tensor(0.2025)],
#   [tensor(0.2754), tensor(0.2109)],
#   [tensor(0.2854), tensor(0.2175)],
#   [tensor(0.3006), tensor(0.2319)],
#   [tensor(0.3058), tensor(0.2350)],
#   [tensor(0.3120), tensor(0.2405)],
#   [tensor(0.3168), tensor(0.2445)],
#   [tensor(0.3243), tensor(0.2537)],
#   [tensor(0.3269), tensor(0.2569)],
#   [tensor(0.3301), tensor(0.2608)],
#   [tensor(0.3344), tensor(0.2662)],
#   [tensor(0.3375), tensor(0.2703)],
#   [tensor(0.3436), tensor(0.2804)],
#   [tensor(0.3473), tensor(0.2867)],
#   [tensor(0.3506), tensor(0.2919)],
#   [tensor(0.3559), tensor(0.2995)],
#   [tensor(0.3607), tensor(0.3087)],
#   [tensor(0.3651), tensor(0.3155)],
#   [tensor(0.3720), tensor(0.3267)],
#   [tensor(0.3736), tensor(0.3301)],
#   [tensor(0.3783), tensor(0.3381)],
#   [tensor(0.3809), tensor(0.3423)],
#   [tensor(0.3827), tensor(0.3454)],
#   [tensor(0.3858), tensor(0.3498)],
#   [tensor(0.3877), tensor(0.3539)],
#   [tensor(0.4407), tensor(0.4285)],
#   [tensor(0.4444), tensor(0.4328)],
#   [tensor(0.4383), tensor(0.4267)],
#   [tensor(0.4457), tensor(0.4351)],
#   [tensor(0.4481), tensor(0.4370)],
#   [tensor(0.4469), tensor(0.4355)],
#   [tensor(0.4469), tensor(0.4360)],
#   [tensor(0.4506), tensor(0.4401)],
#   [tensor(0.4481), tensor(0.4377)],
#   [tensor(0.4519), tensor(0.4414)],
#   [tensor(0.4481), tensor(0.4382)],
#   [tensor(0.4519), tensor(0.4417)],
#   [tensor(0.4506), tensor(0.4404)],
#   [tensor(0.4543), tensor(0.4442)],
#   [tensor(0.4494), tensor(0.4394)],
#   [tensor(0.4519), tensor(0.4418)],
#   [tensor(0.4556), tensor(0.4454)],
#   [tensor(0.4593), tensor(0.4490)],
#   [tensor(0.4556), tensor(0.4455)],
#   [tensor(0.4593), tensor(0.4486)],
#   [tensor(0.4556), tensor(0.4454)],
#   [tensor(0.4593), tensor(0.4487)],
#   [tensor(0.4593), tensor(0.4489)],
#   [tensor(0.4556), tensor(0.4462)],
#   [tensor(0.4617), tensor(0.4521)],
#   [tensor(0.4568), tensor(0.4476)],
#   [tensor(0.4580), tensor(0.4487)],
#   [tensor(0.4605), tensor(0.4512)],
#   [tensor(0.4630), tensor(0.4533)],
#   [tensor(0.4630), tensor(0.4534)],
#   [tensor(0.4642), tensor(0.4548)],
#   [tensor(0.4654), tensor(0.4555)],
#   [tensor(0.4642), tensor(0.4543)],
#   [tensor(0.4642), tensor(0.4547)],
#   [tensor(0.4691), tensor(0.4597)]])

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot(train_acc, label="train_acc")
plt.plot(valid_acc, label="valid_acc")
plt.bar(range(100),train_acc-valid_acc, label="정확도 차이")
plt.legend()
plt.title("SGD최적화 모델의 정확도 변화")
plt.text(np.argmax(train_acc), np.max(train_acc), f"{np.max(train_acc):.2f}")
plt.text(np.argmax(valid_acc), np.max(valid_acc), f"{np.max(valid_acc):.2f}")
plt.xlabel("반복횟수")
plt.ylabel("정확도")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot(train_f1, label="train_f1")
plt.plot(valid_f1, label="valid_f1")
plt.bar(range(100),train_acc-valid_acc, label="정확도 차이")
plt.legend()
plt.title("SGD최적화 모델의 f1 변화")
plt.xlabel("반복횟수")
plt.ylabel("정확도")
plt.text(np.argmax(train_f1), np.max(train_f1), f"{np.max(train_f1):.2f}")
plt.text(np.argmax(valid_f1), np.max(valid_f1), f"{np.max(valid_f1):.2f}")
plt.grid()
plt.show()

# %%
plt.plot(np.abs(train_acc[:-1]-train_acc[1:]), label="train_acc")
plt.plot(np.abs(train_f1[:-1]-train_f1[1:]), label="train_f1")
plt.title("SGD 모델의 train 정확도 변화량")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(np.abs(valid_acc[:-1]-valid_acc[1:]), label="valid_acc")
plt.plot(np.abs(valid_f1[:-1]-valid_f1[1:]), label="valid_f1")
plt.title("SGD 모델의 valid 정확도 변화량")
plt.legend()
plt.grid()
plt.show()
