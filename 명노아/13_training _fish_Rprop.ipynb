# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
# https://www.kaggle.com/datasets/crowww/a-large-scale-fish-dataset

# %%
feature = pd.read_pickle("feature2.pkl")
target = pd.read_pickle("target2.pkl")

# %%
x_train, x_test, y_train, y_test = train_test_split(feature, target, test_size=0.1, random_state=42, stratify=target)
x_valid, x_test, y_valid, y_test = train_test_split(x_test, y_test, test_size=0.1, random_state=42, stratify=y_test)

# %%
x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((8100, 2655), (810, 2655), (90, 2655))

# %%
x_train = torch.tensor(x_train.values, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.long)
x_valid = torch.tensor(x_valid.values, dtype=torch.float32)
y_valid = torch.tensor(y_valid.values, dtype=torch.long)
x_test = torch.tensor(x_test.values, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.long)

# %%
# 데이터셋 생성
import torch.utils.data.dataloader as dataloader
import torch.utils.data.dataset as dataset

class MyDataset(dataset.Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __len__(self):
        return len(self.x)
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
dataset_train = MyDataset(x_train, y_train)
dataset_test = MyDataset(x_test, y_test)
dataset_valid = MyDataset(x_valid, y_valid)

# %%
x_train.shape
# Out:
# torch.Size([8100, 2655])

# %%
class model(nn.Module): # 가중치 초기화 
    def __init__(self):
        super(model, self).__init__()
        self.fc1 = nn.Linear(2655, 1000)
        self.fc2 = nn.Linear(1000, 9)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model2 = model()
for name, child in model2.named_children():
    nn.init.kaiming_normal_(child.weight)
optimizer = optim.Rprop(model2.parameters())
criterion = nn.CrossEntropyLoss()

train_loader = dataloader.DataLoader(dataset_train, batch_size=100, shuffle=True, drop_last=True)
test_loader = dataloader.DataLoader(dataset_test, batch_size=100, shuffle=True, drop_last=True)
valid_loader = dataloader.DataLoader(dataset_valid, batch_size=100, shuffle=True, drop_last=True)

# %%
from torchmetrics.functional.classification import accuracy, f1_score
from torch.optim.lr_scheduler import ReduceLROnPlateau
model2.train()
valid_score=[]
train_score=[]

scheduler = ReduceLROnPlateau(optimizer, 'min', patience=10, verbose=True)

for epoch in range(100):
    
    for x,y in train_loader:
        output = model2(x)
        loss = criterion(output, y.squeeze())
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    with torch.no_grad():        
        print(f"================================={epoch}=================================")
        output = model2(x_train)
        acc = accuracy(output, y_train.squeeze(), task="multiclass", num_classes=9, average="macro")
        f1 = f1_score(output, y_train.squeeze(), task="multiclass", num_classes=9, average="macro")
        train_score.append([acc, f1])
        print(f"train => acc : {acc}, f1 : {f1}")
        
        
        output = model2(x_valid)
        print(f"=================================valid score=================================")
        acc2 = accuracy(output, y_valid.squeeze(), task="multiclass", num_classes=9, average="macro")
        f12 = f1_score(output, y_valid.squeeze(), task="multiclass", num_classes=9, average="macro")
        valid_score.append([acc2, f12])
        print(f"valid => acc : {acc2}, f1 : {f12}")
    
    scheduler.step(loss)
    if scheduler.num_bad_epochs >= scheduler.patience:
        print(f"Early stopping at epoch {epoch}")
        break
# Out:
# =================================0=================================
# train => acc : 0.585802435874939, f1 : 0.5854948163032532
# =================================valid score=================================
# valid => acc : 0.5419752597808838, f1 : 0.538051187992096
# =================================1=================================
# train => acc : 0.6188888549804688, f1 : 0.6189936995506287
# =================================valid score=================================
# valid => acc : 0.5407407283782959, f1 : 0.5400761365890503
# =================================2=================================
# train => acc : 0.6185185313224792, f1 : 0.6192209124565125
# =================================valid score=================================
# valid => acc : 0.5382716059684753, f1 : 0.538469672203064
# =================================3=================================
# train => acc : 0.6249383091926575, f1 : 0.6254051327705383
# =================================valid score=================================
# valid => acc : 0.5370370745658875, f1 : 0.5372796654701233
# =================================4=================================
# train => acc : 0.6286419630050659, f1 : 0.6289949417114258
# =================================valid score=================================
# valid => acc : 0.5283950567245483, f1 : 0.5287705659866333
# =================================5=================================
# train => acc : 0.6329629421234131, f1 : 0.633698582649231
# =================================valid score=================================
# valid => acc : 0.53580242395401, f1 : 0.5368402004241943
# =================================6=================================
# train => acc : 0.6370370388031006, f1 : 0.6374921798706055
# =================================valid score=================================
# valid => acc : 0.5320987701416016, f1 : 0.5335742831230164
# =================================7=================================
# train => acc : 0.636913537979126, f1 : 0.6373580098152161
# =================================valid score=================================
# valid => acc : 0.5320987701416016, f1 : 0.5327454805374146
# =================================8=================================
# train => acc : 0.6354320645332336, f1 : 0.6356998682022095
# =================================valid score=================================
# valid => acc : 0.5333333611488342, f1 : 0.5331043601036072
# =================================9=================================
# train => acc : 0.6293826699256897, f1 : 0.6298378109931946
# =================================valid score=================================
# valid => acc : 0.5185185074806213, f1 : 0.5184511542320251
# =================================10=================================
# train => acc : 0.6375308632850647, f1 : 0.6375263929367065
# =================================valid score=================================
# valid => acc : 0.5234568119049072, f1 : 0.5228261947631836
# =================================11=================================
# train => acc : 0.6382715702056885, f1 : 0.6387127637863159
# =================================valid score=================================
# valid => acc : 0.509876549243927, f1 : 0.5098075866699219
# =================================12=================================
# train => acc : 0.6435801982879639, f1 : 0.643866240978241
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.5110546946525574
# =================================13=================================
# train => acc : 0.639012336730957, f1 : 0.6393437385559082
# =================================valid score=================================
# valid => acc : 0.5074073672294617, f1 : 0.5074821710586548
# =================================14=================================
# train => acc : 0.6427160501480103, f1 : 0.6429209113121033
# =================================valid score=================================
# valid => acc : 0.5037037134170532, f1 : 0.503809928894043
# =================================15=================================
# train => acc : 0.645061731338501, f1 : 0.6453521251678467
# =================================valid score=================================
# valid => acc : 0.509876549243927, f1 : 0.5103428363800049
# =================================16=================================
# train => acc : 0.6466667056083679, f1 : 0.6470434069633484
# =================================valid score=================================
# valid => acc : 0.5123456716537476, f1 : 0.5126239061355591
# =================================17=================================
# train => acc : 0.6492592692375183, f1 : 0.6495815515518188
# =================================valid score=================================
# valid => acc : 0.5111111402511597, f1 : 0.5111625790596008
# =================================18=================================
# train => acc : 0.6517283916473389, f1 : 0.6520431041717529
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.5108035206794739
# =================================19=================================
# train => acc : 0.6548147797584534, f1 : 0.6550160646438599
# =================================valid score=================================
# valid => acc : 0.5135802626609802, f1 : 0.5134471654891968
# =================================20=================================
# train => acc : 0.6579012274742126, f1 : 0.6582103967666626
# =================================valid score=================================
# valid => acc : 0.5123457312583923, f1 : 0.5122899413108826
# =================================21=================================
# train => acc : 0.6616049408912659, f1 : 0.6619279980659485
# =================================valid score=================================
# valid => acc : 0.519753098487854, f1 : 0.51960688829422
# =================================22=================================
# train => acc : 0.661111056804657, f1 : 0.6615983247756958
# =================================valid score=================================
# valid => acc : 0.519753098487854, f1 : 0.5195872187614441
# =================================23=================================
# train => acc : 0.6634567975997925, f1 : 0.6639333963394165
# =================================valid score=================================
# valid => acc : 0.5160493850708008, f1 : 0.5157641768455505
# =================================24=================================
# train => acc : 0.6658024787902832, f1 : 0.6664087772369385
# =================================valid score=================================
# valid => acc : 0.5160494446754456, f1 : 0.5161734819412231
# =================================25=================================
# train => acc : 0.66209876537323, f1 : 0.6626803874969482
# =================================valid score=================================
# valid => acc : 0.5123456716537476, f1 : 0.5128387212753296
# =================================26=================================
# train => acc : 0.6651851534843445, f1 : 0.6656372547149658
# =================================valid score=================================
# valid => acc : 0.5148148536682129, f1 : 0.5150464177131653
# =================================27=================================
# train => acc : 0.6648147702217102, f1 : 0.6651890277862549
# =================================valid score=================================
# valid => acc : 0.5160493850708008, f1 : 0.5160565376281738
# =================================28=================================
# train => acc : 0.665925920009613, f1 : 0.6663112044334412
# =================================valid score=================================
# valid => acc : 0.5185185670852661, f1 : 0.518347442150116
# =================================29=================================
# train => acc : 0.6681481599807739, f1 : 0.6686230897903442
# =================================valid score=================================
# valid => acc : 0.5148147940635681, f1 : 0.5146788358688354
# =================================30=================================
# train => acc : 0.6700000166893005, f1 : 0.6704519987106323
# =================================valid score=================================
# valid => acc : 0.5135802626609802, f1 : 0.5139679312705994
# =================================31=================================
# train => acc : 0.6707407236099243, f1 : 0.6712505221366882
# =================================valid score=================================
# valid => acc : 0.5061728358268738, f1 : 0.5063556432723999
# =================================32=================================
# train => acc : 0.6727160215377808, f1 : 0.673283040523529
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.5114579200744629
# =================================33=================================
# train => acc : 0.6672839522361755, f1 : 0.6676867008209229
# =================================valid score=================================
# valid => acc : 0.5037037134170532, f1 : 0.5033622980117798
# =================================34=================================
# train => acc : 0.672345757484436, f1 : 0.6728258728981018
# =================================valid score=================================
# valid => acc : 0.5061728358268738, f1 : 0.5059558153152466
# =================================35=================================
# train => acc : 0.669259250164032, f1 : 0.6698092222213745
# =================================valid score=================================
# valid => acc : 0.4987654387950897, f1 : 0.49877315759658813
# =================================36=================================
# train => acc : 0.6704937815666199, f1 : 0.6710291504859924
# =================================valid score=================================
# valid => acc : 0.5061728358268738, f1 : 0.5057876110076904
# =================================37=================================
# train => acc : 0.6711111068725586, f1 : 0.6715831756591797
# =================================valid score=================================
# valid => acc : 0.5012345910072327, f1 : 0.5010382533073425
# =================================38=================================
# train => acc : 0.6740740537643433, f1 : 0.6745530366897583
# =================================valid score=================================
# valid => acc : 0.5012345910072327, f1 : 0.5009315609931946
# =================================39=================================
# train => acc : 0.6737037301063538, f1 : 0.674148440361023
# =================================valid score=================================
# valid => acc : 0.5024691224098206, f1 : 0.5021187663078308
# =================================40=================================
# train => acc : 0.6713579893112183, f1 : 0.6717860102653503
# =================================valid score=================================
# valid => acc : 0.5037037134170532, f1 : 0.5037658214569092
# =================================41=================================
# train => acc : 0.6746913194656372, f1 : 0.6750898361206055
# =================================valid score=================================
# valid => acc : 0.5111111402511597, f1 : 0.5110994577407837
# =================================42=================================
# train => acc : 0.6713581085205078, f1 : 0.6718003749847412
# =================================valid score=================================
# valid => acc : 0.5135802626609802, f1 : 0.5133699178695679
# =================================43=================================
# train => acc : 0.6738271713256836, f1 : 0.6743420958518982
# =================================valid score=================================
# valid => acc : 0.5123456716537476, f1 : 0.5119622945785522
# =================================44=================================
# train => acc : 0.6755555272102356, f1 : 0.6760367751121521
# =================================valid score=================================
# valid => acc : 0.5086419582366943, f1 : 0.5081413388252258
# =================================45=================================
# train => acc : 0.6770370006561279, f1 : 0.6776097416877747
# =================================valid score=================================
# valid => acc : 0.5123456716537476, f1 : 0.5122536420822144
# =================================46=================================
# train => acc : 0.6790122985839844, f1 : 0.679503321647644
# =================================valid score=================================
# valid => acc : 0.5074074268341064, f1 : 0.5075612664222717
# =================================47=================================
# train => acc : 0.6808642148971558, f1 : 0.6813747882843018
# =================================valid score=================================
# valid => acc : 0.5086419582366943, f1 : 0.508851945400238
# =================================48=================================
# train => acc : 0.6814814209938049, f1 : 0.6819697618484497
# =================================valid score=================================
# valid => acc : 0.5123457312583923, f1 : 0.5118811130523682
# =================================49=================================
# train => acc : 0.6819753646850586, f1 : 0.6824832558631897
# =================================valid score=================================
# valid => acc : 0.5074074268341064, f1 : 0.507146418094635
# =================================50=================================
# train => acc : 0.6817284226417542, f1 : 0.6821696758270264
# =================================valid score=================================
# valid => acc : 0.5123457312583923, f1 : 0.5122098922729492
# =================================51=================================
# train => acc : 0.6813579797744751, f1 : 0.6818329691886902
# =================================valid score=================================
# valid => acc : 0.5049382448196411, f1 : 0.5046916007995605
# =================================52=================================
# train => acc : 0.6837037801742554, f1 : 0.6841138601303101
# =================================valid score=================================
# valid => acc : 0.5086419582366943, f1 : 0.5081957578659058
# =================================53=================================
# train => acc : 0.6838272213935852, f1 : 0.6842076778411865
# =================================valid score=================================
# valid => acc : 0.5074074268341064, f1 : 0.5069890022277832
# =================================54=================================
# train => acc : 0.6828394532203674, f1 : 0.6833048462867737
# =================================valid score=================================
# valid => acc : 0.5086420178413391, f1 : 0.5084813237190247
# =================================55=================================
# train => acc : 0.684567928314209, f1 : 0.6850544810295105
# =================================valid score=================================
# valid => acc : 0.5111111402511597, f1 : 0.5108181238174438
# =================================56=================================
# train => acc : 0.6855555176734924, f1 : 0.6860660314559937
# =================================valid score=================================
# valid => acc : 0.5111111402511597, f1 : 0.5108824968338013
# =================================57=================================
# train => acc : 0.6865432262420654, f1 : 0.6869747638702393
# =================================valid score=================================
# valid => acc : 0.5111111402511597, f1 : 0.5108476877212524
# =================================58=================================
# train => acc : 0.6867900490760803, f1 : 0.6872236728668213
# =================================valid score=================================
# valid => acc : 0.5061728954315186, f1 : 0.5060722231864929
# =================================59=================================
# train => acc : 0.6861728429794312, f1 : 0.686640202999115
# =================================valid score=================================
# valid => acc : 0.5061728358268738, f1 : 0.5061142444610596
# =================================60=================================
# train => acc : 0.6867901086807251, f1 : 0.6872968673706055
# =================================valid score=================================
# valid => acc : 0.5086419582366943, f1 : 0.508594810962677
# =================================61=================================
# train => acc : 0.6850616931915283, f1 : 0.6855944991111755
# =================================valid score=================================
# valid => acc : 0.5086420178413391, f1 : 0.5085307955741882
# =================================62=================================
# train => acc : 0.6867901086807251, f1 : 0.6872572302818298
# =================================valid score=================================
# valid => acc : 0.5086420178413391, f1 : 0.5084589123725891
# =================================63=================================
# train => acc : 0.6864197850227356, f1 : 0.6869397163391113
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.5109049081802368
# =================================64=================================
# train => acc : 0.685679018497467, f1 : 0.6862389445304871
# =================================valid score=================================
# valid => acc : 0.509876549243927, f1 : 0.5097526907920837
# =================================65=================================
# train => acc : 0.6872839331626892, f1 : 0.6877050995826721
# =================================valid score=================================
# valid => acc : 0.5111111402511597, f1 : 0.5108329653739929
# =================================66=================================
# train => acc : 0.6895061731338501, f1 : 0.6899384260177612
# =================================valid score=================================
# valid => acc : 0.5148148536682129, f1 : 0.5145139694213867
# =================================67=================================
# train => acc : 0.6882715821266174, f1 : 0.6887547969818115
# =================================valid score=================================
# valid => acc : 0.5074074268341064, f1 : 0.5072202086448669
# =================================68=================================
# train => acc : 0.690123438835144, f1 : 0.6905468106269836
# =================================valid score=================================
# valid => acc : 0.5061728358268738, f1 : 0.5062975287437439
# =================================69=================================
# train => acc : 0.6872839331626892, f1 : 0.6877247095108032
# =================================valid score=================================
# valid => acc : 0.5074074268341064, f1 : 0.5073285102844238
# =================================70=================================
# train => acc : 0.6885185241699219, f1 : 0.6889739036560059
# =================================valid score=================================
# valid => acc : 0.509876549243927, f1 : 0.5095943212509155
# =================================71=================================
# train => acc : 0.6907407641410828, f1 : 0.691184401512146
# =================================valid score=================================
# valid => acc : 0.5074073672294617, f1 : 0.5072982907295227
# =================================72=================================
# train => acc : 0.6923456788063049, f1 : 0.6927897930145264
# =================================valid score=================================
# valid => acc : 0.5074073672294617, f1 : 0.5072492957115173
# =================================73=================================
# train => acc : 0.6930863857269287, f1 : 0.6936250329017639
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.5117820501327515
# =================================74=================================
# train => acc : 0.6935802698135376, f1 : 0.69413822889328
# =================================valid score=================================
# valid => acc : 0.5086419582366943, f1 : 0.5094102621078491
# =================================75=================================
# train => acc : 0.6949383020401001, f1 : 0.6953809857368469
# =================================valid score=================================
# valid => acc : 0.5086419582366943, f1 : 0.509037435054779
# =================================76=================================
# train => acc : 0.6943210363388062, f1 : 0.6947439312934875
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.511250913143158
# =================================77=================================
# train => acc : 0.6940740942955017, f1 : 0.6944611072540283
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.5114213824272156
# =================================78=================================
# train => acc : 0.6932098865509033, f1 : 0.6936837434768677
# =================================valid score=================================
# valid => acc : 0.5111110806465149, f1 : 0.5113584995269775
# =================================79=================================
# train => acc : 0.6938271522521973, f1 : 0.6943572163581848
# =================================valid score=================================
# valid => acc : 0.5135802626609802, f1 : 0.5140019655227661
# =================================80=================================
# train => acc : 0.6959259510040283, f1 : 0.696331262588501
# =================================valid score=================================
# valid => acc : 0.5148147940635681, f1 : 0.5150982141494751
# =================================81=================================
# train => acc : 0.6954321265220642, f1 : 0.6959441900253296
# =================================valid score=================================
# valid => acc : 0.5148147940635681, f1 : 0.5153551697731018
# =================================82=================================
# train => acc : 0.6951851844787598, f1 : 0.6956519484519958
# =================================valid score=================================
# valid => acc : 0.5148147940635681, f1 : 0.5152209997177124
# =================================83=================================
# train => acc : 0.6969135999679565, f1 : 0.6974071860313416
# =================================valid score=================================
# valid => acc : 0.5148147940635681, f1 : 0.515378475189209
# =================================84=================================
# train => acc : 0.6970370411872864, f1 : 0.6975265741348267
# =================================valid score=================================
# valid => acc : 0.5135802626609802, f1 : 0.5142232179641724
# =================================85=================================
# train => acc : 0.6985185146331787, f1 : 0.6989930272102356
# =================================valid score=================================
# valid => acc : 0.519753098487854, f1 : 0.5208280086517334
# =================================86=================================
# train => acc : 0.6980247497558594, f1 : 0.6984670162200928
# =================================valid score=================================
# valid => acc : 0.5172839164733887, f1 : 0.5187162160873413
# =================================87=================================
# train => acc : 0.6974074244499207, f1 : 0.6978920698165894
# =================================valid score=================================
# valid => acc : 0.5185185074806213, f1 : 0.5199966430664062
# =================================88=================================
# train => acc : 0.6985185146331787, f1 : 0.6989690065383911
# =================================valid score=================================
# valid => acc : 0.5209876894950867, f1 : 0.5224645137786865
# =================================89=================================
# train => acc : 0.698888897895813, f1 : 0.6992982625961304
# =================================valid score=================================
# valid => acc : 0.5222222805023193, f1 : 0.5237202048301697
# =================================90=================================
# train => acc : 0.6980246901512146, f1 : 0.6985563039779663
# =================================valid score=================================
# valid => acc : 0.5234568119049072, f1 : 0.5251362919807434
# =================================91=================================
# train => acc : 0.6993827819824219, f1 : 0.6999069452285767
# =================================valid score=================================
# valid => acc : 0.5234568119049072, f1 : 0.5250565409660339
# =================================92=================================
# train => acc : 0.699259340763092, f1 : 0.699728786945343
# =================================valid score=================================
# valid => acc : 0.5246913433074951, f1 : 0.526300311088562
# =================================93=================================
# train => acc : 0.6998765468597412, f1 : 0.7003797292709351
# =================================valid score=================================
# valid => acc : 0.5222222208976746, f1 : 0.5239250659942627
# =================================94=================================
# train => acc : 0.6979012489318848, f1 : 0.6984813809394836
# =================================valid score=================================
# valid => acc : 0.5259259343147278, f1 : 0.5275262594223022
# =================================95=================================
# train => acc : 0.6980246901512146, f1 : 0.6985269784927368
# =================================valid score=================================
# valid => acc : 0.5246914029121399, f1 : 0.526137113571167
# =================================96=================================
# train => acc : 0.699999988079071, f1 : 0.7004262804985046
# =================================valid score=================================
# valid => acc : 0.5209876894950867, f1 : 0.5223388075828552
# =================================97=================================
# train => acc : 0.7000000476837158, f1 : 0.7004807591438293
# =================================valid score=================================
# valid => acc : 0.5234568119049072, f1 : 0.5251694321632385
# =================================98=================================
# train => acc : 0.6977778077125549, f1 : 0.6982660293579102
# =================================valid score=================================
# valid => acc : 0.5222222208976746, f1 : 0.5239580869674683
# =================================99=================================
# train => acc : 0.6992592811584473, f1 : 0.6997568011283875
# =================================valid score=================================
# valid => acc : 0.5209876894950867, f1 : 0.5225021839141846

# %%
torch.save(model2,"./Rprop_model.pth")

# %%
import torch
from torchmetrics.functional.classification import accuracy, f1_score
model2=model()
model2 = torch.load("./Rprop_model.pth")

output = model2(x_test)
print(f"=================================test score=================================")
print(accuracy(output, y_test.squeeze(), task="multiclass", num_classes=9, average="macro"))
print(f1_score(output, y_test.squeeze(), task="multiclass", num_classes=9, average="macro"))
# Out:
# =================================test score=================================
# tensor(0.5222)
# tensor(0.5287)

# %%
train_acc = np.array(train_score)[:,0]
train_f1 = np.array(train_score)[:,1]

valid_acc = np.array(valid_score)[:,0]
valid_f1 = np.array(valid_score)[:,1]

# %%
train_score, valid_score
# Out:
# ([[tensor(0.5858), tensor(0.5855)],
#   [tensor(0.6189), tensor(0.6190)],
#   [tensor(0.6185), tensor(0.6192)],
#   [tensor(0.6249), tensor(0.6254)],
#   [tensor(0.6286), tensor(0.6290)],
#   [tensor(0.6330), tensor(0.6337)],
#   [tensor(0.6370), tensor(0.6375)],
#   [tensor(0.6369), tensor(0.6374)],
#   [tensor(0.6354), tensor(0.6357)],
#   [tensor(0.6294), tensor(0.6298)],
#   [tensor(0.6375), tensor(0.6375)],
#   [tensor(0.6383), tensor(0.6387)],
#   [tensor(0.6436), tensor(0.6439)],
#   [tensor(0.6390), tensor(0.6393)],
#   [tensor(0.6427), tensor(0.6429)],
#   [tensor(0.6451), tensor(0.6454)],
#   [tensor(0.6467), tensor(0.6470)],
#   [tensor(0.6493), tensor(0.6496)],
#   [tensor(0.6517), tensor(0.6520)],
#   [tensor(0.6548), tensor(0.6550)],
#   [tensor(0.6579), tensor(0.6582)],
#   [tensor(0.6616), tensor(0.6619)],
#   [tensor(0.6611), tensor(0.6616)],
#   [tensor(0.6635), tensor(0.6639)],
#   [tensor(0.6658), tensor(0.6664)],
#   [tensor(0.6621), tensor(0.6627)],
#   [tensor(0.6652), tensor(0.6656)],
#   [tensor(0.6648), tensor(0.6652)],
#   [tensor(0.6659), tensor(0.6663)],
#   [tensor(0.6681), tensor(0.6686)],
#   [tensor(0.6700), tensor(0.6705)],
#   [tensor(0.6707), tensor(0.6713)],
#   [tensor(0.6727), tensor(0.6733)],
#   [tensor(0.6673), tensor(0.6677)],
#   [tensor(0.6723), tensor(0.6728)],
#   [tensor(0.6693), tensor(0.6698)],
#   [tensor(0.6705), tensor(0.6710)],
#   [tensor(0.6711), tensor(0.6716)],
#   [tensor(0.6741), tensor(0.6746)],
#   [tensor(0.6737), tensor(0.6741)],
#   [tensor(0.6714), tensor(0.6718)],
#   [tensor(0.6747), tensor(0.6751)],
#   [tensor(0.6714), tensor(0.6718)],
#   [tensor(0.6738), tensor(0.6743)],
#   [tensor(0.6756), tensor(0.6760)],
#   [tensor(0.6770), tensor(0.6776)],
#   [tensor(0.6790), tensor(0.6795)],
#   [tensor(0.6809), tensor(0.6814)],
#   [tensor(0.6815), tensor(0.6820)],
#   [tensor(0.6820), tensor(0.6825)],
#   [tensor(0.6817), tensor(0.6822)],
#   [tensor(0.6814), tensor(0.6818)],
#   [tensor(0.6837), tensor(0.6841)],
#   [tensor(0.6838), tensor(0.6842)],
#   [tensor(0.6828), tensor(0.6833)],
#   [tensor(0.6846), tensor(0.6851)],
#   [tensor(0.6856), tensor(0.6861)],
#   [tensor(0.6865), tensor(0.6870)],
#   [tensor(0.6868), tensor(0.6872)],
#   [tensor(0.6862), tensor(0.6866)],
#   [tensor(0.6868), tensor(0.6873)],
#   [tensor(0.6851), tensor(0.6856)],
#   [tensor(0.6868), tensor(0.6873)],
#   [tensor(0.6864), tensor(0.6869)],
#   [tensor(0.6857), tensor(0.6862)],
#   [tensor(0.6873), tensor(0.6877)],
#   [tensor(0.6895), tensor(0.6899)],
#   [tensor(0.6883), tensor(0.6888)],
#   [tensor(0.6901), tensor(0.6905)],
#   [tensor(0.6873), tensor(0.6877)],
#   [tensor(0.6885), tensor(0.6890)],
#   [tensor(0.6907), tensor(0.6912)],
#   [tensor(0.6923), tensor(0.6928)],
#   [tensor(0.6931), tensor(0.6936)],
#   [tensor(0.6936), tensor(0.6941)],
#   [tensor(0.6949), tensor(0.6954)],
#   [tensor(0.6943), tensor(0.6947)],
#   [tensor(0.6941), tensor(0.6945)],
#   [tensor(0.6932), tensor(0.6937)],
#   [tensor(0.6938), tensor(0.6944)],
#   [tensor(0.6959), tensor(0.6963)],
#   [tensor(0.6954), tensor(0.6959)],
#   [tensor(0.6952), tensor(0.6957)],
#   [tensor(0.6969), tensor(0.6974)],
#   [tensor(0.6970), tensor(0.6975)],
#   [tensor(0.6985), tensor(0.6990)],
#   [tensor(0.6980), tensor(0.6985)],
#   [tensor(0.6974), tensor(0.6979)],
#   [tensor(0.6985), tensor(0.6990)],
#   [tensor(0.6989), tensor(0.6993)],
#   [tensor(0.6980), tensor(0.6986)],
#   [tensor(0.6994), tensor(0.6999)],
#   [tensor(0.6993), tensor(0.6997)],
#   [tensor(0.6999), tensor(0.7004)],
#   [tensor(0.6979), tensor(0.6985)],
#   [tensor(0.6980), tensor(0.6985)],
#   [tensor(0.7000), tensor(0.7004)],
#   [tensor(0.7000), tensor(0.7005)],
#   [tensor(0.6978), tensor(0.6983)],
#   [tensor(0.6993), tensor(0.6998)]],
#  [[tensor(0.5420), tensor(0.5381)],
#   [tensor(0.5407), tensor(0.5401)],
#   [tensor(0.5383), tensor(0.5385)],
#   [tensor(0.5370), tensor(0.5373)],
#   [tensor(0.5284), tensor(0.5288)],
#   [tensor(0.5358), tensor(0.5368)],
#   [tensor(0.5321), tensor(0.5336)],
#   [tensor(0.5321), tensor(0.5327)],
#   [tensor(0.5333), tensor(0.5331)],
#   [tensor(0.5185), tensor(0.5185)],
#   [tensor(0.5235), tensor(0.5228)],
#   [tensor(0.5099), tensor(0.5098)],
#   [tensor(0.5111), tensor(0.5111)],
#   [tensor(0.5074), tensor(0.5075)],
#   [tensor(0.5037), tensor(0.5038)],
#   [tensor(0.5099), tensor(0.5103)],
#   [tensor(0.5123), tensor(0.5126)],
#   [tensor(0.5111), tensor(0.5112)],
#   [tensor(0.5111), tensor(0.5108)],
#   [tensor(0.5136), tensor(0.5134)],
#   [tensor(0.5123), tensor(0.5123)],
#   [tensor(0.5198), tensor(0.5196)],
#   [tensor(0.5198), tensor(0.5196)],
#   [tensor(0.5160), tensor(0.5158)],
#   [tensor(0.5160), tensor(0.5162)],
#   [tensor(0.5123), tensor(0.5128)],
#   [tensor(0.5148), tensor(0.5150)],
#   [tensor(0.5160), tensor(0.5161)],
#   [tensor(0.5185), tensor(0.5183)],
#   [tensor(0.5148), tensor(0.5147)],
#   [tensor(0.5136), tensor(0.5140)],
#   [tensor(0.5062), tensor(0.5064)],
#   [tensor(0.5111), tensor(0.5115)],
#   [tensor(0.5037), tensor(0.5034)],
#   [tensor(0.5062), tensor(0.5060)],
#   [tensor(0.4988), tensor(0.4988)],
#   [tensor(0.5062), tensor(0.5058)],
#   [tensor(0.5012), tensor(0.5010)],
#   [tensor(0.5012), tensor(0.5009)],
#   [tensor(0.5025), tensor(0.5021)],
#   [tensor(0.5037), tensor(0.5038)],
#   [tensor(0.5111), tensor(0.5111)],
#   [tensor(0.5136), tensor(0.5134)],
#   [tensor(0.5123), tensor(0.5120)],
#   [tensor(0.5086), tensor(0.5081)],
#   [tensor(0.5123), tensor(0.5123)],
#   [tensor(0.5074), tensor(0.5076)],
#   [tensor(0.5086), tensor(0.5089)],
#   [tensor(0.5123), tensor(0.5119)],
#   [tensor(0.5074), tensor(0.5071)],
#   [tensor(0.5123), tensor(0.5122)],
#   [tensor(0.5049), tensor(0.5047)],
#   [tensor(0.5086), tensor(0.5082)],
#   [tensor(0.5074), tensor(0.5070)],
#   [tensor(0.5086), tensor(0.5085)],
#   [tensor(0.5111), tensor(0.5108)],
#   [tensor(0.5111), tensor(0.5109)],
#   [tensor(0.5111), tensor(0.5108)],
#   [tensor(0.5062), tensor(0.5061)],
#   [tensor(0.5062), tensor(0.5061)],
#   [tensor(0.5086), tensor(0.5086)],
#   [tensor(0.5086), tensor(0.5085)],
#   [tensor(0.5086), tensor(0.5085)],
#   [tensor(0.5111), tensor(0.5109)],
#   [tensor(0.5099), tensor(0.5098)],
#   [tensor(0.5111), tensor(0.5108)],
#   [tensor(0.5148), tensor(0.5145)],
#   [tensor(0.5074), tensor(0.5072)],
#   [tensor(0.5062), tensor(0.5063)],
#   [tensor(0.5074), tensor(0.5073)],
#   [tensor(0.5099), tensor(0.5096)],
#   [tensor(0.5074), tensor(0.5073)],
#   [tensor(0.5074), tensor(0.5072)],
#   [tensor(0.5111), tensor(0.5118)],
#   [tensor(0.5086), tensor(0.5094)],
#   [tensor(0.5086), tensor(0.5090)],
#   [tensor(0.5111), tensor(0.5113)],
#   [tensor(0.5111), tensor(0.5114)],
#   [tensor(0.5111), tensor(0.5114)],
#   [tensor(0.5136), tensor(0.5140)],
#   [tensor(0.5148), tensor(0.5151)],
#   [tensor(0.5148), tensor(0.5154)],
#   [tensor(0.5148), tensor(0.5152)],
#   [tensor(0.5148), tensor(0.5154)],
#   [tensor(0.5136), tensor(0.5142)],
#   [tensor(0.5198), tensor(0.5208)],
#   [tensor(0.5173), tensor(0.5187)],
#   [tensor(0.5185), tensor(0.5200)],
#   [tensor(0.5210), tensor(0.5225)],
#   [tensor(0.5222), tensor(0.5237)],
#   [tensor(0.5235), tensor(0.5251)],
#   [tensor(0.5235), tensor(0.5251)],
#   [tensor(0.5247), tensor(0.5263)],
#   [tensor(0.5222), tensor(0.5239)],
#   [tensor(0.5259), tensor(0.5275)],
#   [tensor(0.5247), tensor(0.5261)],
#   [tensor(0.5210), tensor(0.5223)],
#   [tensor(0.5235), tensor(0.5252)],
#   [tensor(0.5222), tensor(0.5240)],
#   [tensor(0.5210), tensor(0.5225)]])

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot(train_acc, label="train_acc")
plt.plot(valid_acc, label="valid_acc")
plt.bar(range(100),train_acc-valid_acc, label="정확도 차이")
plt.legend()
plt.title("Rprop최적화 모델의 정확도 변화")
plt.text(np.argmax(train_acc), np.max(train_acc), f"{np.max(train_acc):.2f}")
plt.text(np.argmax(valid_acc), np.max(valid_acc), f"{np.max(valid_acc):.2f}")
plt.xlabel("반복횟수")
plt.ylabel("정확도")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot(train_f1, label="train_f1")
plt.plot(valid_f1, label="valid_f1")
plt.bar(range(100),train_acc-valid_acc, label="정확도 차이")
plt.legend()
plt.title("Rprop최적화 모델의 f1 변화")
plt.xlabel("반복횟수")
plt.ylabel("정확도")
plt.text(np.argmax(train_f1), np.max(train_f1), f"{np.max(train_f1):.2f}")
plt.text(np.argmax(valid_f1), np.max(valid_f1), f"{np.max(valid_f1):.2f}")
plt.grid()
plt.show()

# %%
plt.plot(np.abs(train_acc[:-1]-train_acc[1:]), label="train_acc")
plt.plot(np.abs(train_f1[:-1]-train_f1[1:]), label="train_f1")
plt.title("Rprop 모델의 train 정확도 변화량")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(np.abs(valid_acc[:-1]-valid_acc[1:]), label="valid_acc")
plt.plot(np.abs(valid_f1[:-1]-valid_f1[1:]), label="valid_f1")
plt.title("Rprop 모델의 valid 정확도 변화량")
plt.legend()
plt.grid()
plt.show()
